# %%
import stanza
# stanza.download('hi', processors='tokenize,mwt,pos')

# %%
# !pip3 install ipywidgets
# !jupyter nbextension enable --py widgetsnbextension

# %%
nlp = stanza.Pipeline('mr', processors='tokenize,mwt,pos')
# tok = stanza.Pipeline('mr', processors='tokenize')
# Out:
# 2021-07-27 18:14:56 INFO: Loading these models for language: mr (Marathi):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | ufal    |
# | mwt       | ufal    |
# | pos       | ufal    |
# ...
#
# 2021-07-27 18:14:56 INFO: Use device: cpu
# 2021-07-27 18:14:56 INFO: Loading: tokenize
# 2021-07-27 18:14:56 INFO: Loading: mwt
# 2021-07-27 18:14:56 INFO: Loading: pos
# 2021-07-27 18:14:57 INFO: Done loading processors!

# %%
doc = nlp('मी रोटी खाल्ली।')

# %%
print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# word: मी 	upos: PRON	xpos: None
# word: रोटी 	upos: NOUN	xpos: None
# word: खाल्ली 	upos: VERB	xpos: None
# word: । 	upos: PUNCT	xpos: None

# %%
# morph_file = open("marathi_data/mr/mr.tok.txt").read().split("\n")[800:850]
data = open("marathi_data/mr/mr.segmented.EOLmarked.txt", "r").read().split("E O L")[700:750]
data = [re.split(' |\n', ss)[1:-1] for ss in data]


for line in data:
    word = " ".join(line)
    doc = nlp(word)
    print([token.text for sent in doc.sentences for token in sent.tokens])
    print(word)
#     print(doc.sentences[0].words[0].text, "\t", doc.sentences[0].words[0].upos)
    print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for token in sent.tokens for word in token.words], sep='\n')
    print("\n")
# Out:
# ['मि', 'निम', 'म', 'बॅल', 'न्स', 'खात्या', 'त', 'ठेव', 'ू', 'शकत', 'नाहीत', 'असे', 'लोक', 'कोण', 'आहेत', '.', '.', '.', 'हे', 'सगळे', 'गरीब', 'मध्यमवर्गीय', 'लोक', 'आहेत', '.']
# मि निम म बॅल न्स खात्या त ठेव ू शकत नाहीत असे लोक कोण आहेत . . . हे सगळे गरीब मध्यमवर्गीय लोक आहेत .
# word: मि 	upos: VERB	xpos: None
# word: निम 	upos: ADJ	xpos: None
# word: म 	upos: ADJ	xpos: None
# word: बॅल 	upos: NOUN	xpos: None
# word: न्स 	upos: PUNCT	xpos: None
# word: खात्या 	upos: PUNCT	xpos: None
# word: त 	upos: ADV	xpos: None
# word: ठेव 	upos: VERB	xpos: None
# word: ू 	upos: PRON	xpos: None
# word: शकत 	upos: VERB	xpos: None
# word: नाहीत 	upos: AUX	xpos: None
# word: असे 	upos: SCONJ	xpos: None
# word: लोक 	upos: NOUN	xpos: None
# word: कोण 	upos: PRON	xpos: None
# word: आहेत 	upos: AUX	xpos: None
# word: . 	upos: PUNCT	xpos: None
# word: . 	upos: PUNCT	xpos: None
# word: . 	upos: PUNCT	xpos: None
# word: हे 	upos: DET	xpos: None
# word: सगळे 	upos: ADJ	xpos: None
# ...

# %%
morph_file = open("marathi_data/mr/mr.tok.txt").read().split("\n")[700:750]
print("\n\n".join(morph_file))

for sent in morph_file:
    doc = nlp(sent)
    print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# मिनिमम बॅलन्स खात्यात ठेवू शकत नाहीत असे लोक कोण आहेत . . . हे सगळे गरीब मध्यमवर्गीय लोक आहेत .
#
# त्यामुळे मायावतींनी पाठिंबा काढू असे धमकावल्यानंतर मुख्यमंत्री कमलनाथ यांनी राजकीय द्वेषातून भरण्यात आलेले खटले मागे घेण्यात येणार असल्याचे जाहीर केले .
#
# वेंगुर्ले : पावसाळ्य़ात जमीनदोस्त झालेले भुजनाकवाडी येथील गरीब महिलेचे घर दानशूर व्यक्तींच्या मदतीतून बांधल्यानंतर घराचा ताबा देताना नगराध्यक्ष दिलीप गिरप व अन्य .
#
# सध्या फ्लिपकार्ट आघाडीवर असली तरी भविष्यातील आव्हाने लक्षात घेत कंपनीने मिंट्राचे अधिग्रहण केले असून यामुळे तयार आणि फॅशनेबल कपडयांच्या विभागात फ्लिपकार्टला मुसंडी मारता येईल .
#
# मृत्यूच्या दिशेने सुरु असलेला त्याचा हा प्रवास त्याला जाणवला होता .
#
# बिल्डरने सोसायटी हॅंडओव्हर केलेली नसल्याने संरक्षण भिंतीच्या दुरूस्तीची जबाबदारी ही बिल्डरची आहे .
#
# आमच्या वर्गाला क्रिकेटचं भारी वेड !
#
# दुसर्या दिवशी पहाटे लवकर उठून जागेश्वरला जायला निघालो .
#
# कोरडा नदी पात्र क्षेत्रात गेल्या दोन ते तीन वर्षांपासून दमदार पाऊस झाला नाही .
#
# ...

# %%
import re
data = open("marathi_data/mr/mr.segmented.EOLmarked.txt", "r").read().split("E O L")[700:750]
data = [re.split(' |\n', ss)[1:-1] for ss in data]

# %%
tagged_data = open("marathi_data/mr/mr.segmented.gold_tagged.txt", "w")
for sent in data:
    tagged_data.write(" ".join(sent)+"\n")
    for word in sent:
        tagged_data.write(word+"\n")
    tagged_data.write("E O L\n")
tagged_data.close()

# %%
nlp = stanza.Pipeline('hi', processors='tokenize,pos')
# Out:
# 2021-07-22 14:25:11 INFO: Loading these models for language: hi (Hindi):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# ...
#
# 2021-07-22 14:25:11 INFO: Use device: cpu
# 2021-07-22 14:25:11 INFO: Loading: tokenize
# 2021-07-22 14:25:11 INFO: Loading: pos
# 2021-07-22 14:25:12 INFO: Done loading processors!

# %%
nlp = stanza.Pipeline(lang="hi", processors='tokenize,pos')
s = "होता".split()
for word in s:
    doc = nlp(word)
    print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# 2021-07-23 17:29:39 INFO: Loading these models for language: hi (Hindi):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | hdtb    |
# | pos       | hdtb    |
# ...
#
# 2021-07-23 17:29:39 INFO: Use device: cpu
# 2021-07-23 17:29:39 INFO: Loading: tokenize
# 2021-07-23 17:29:39 INFO: Loading: pos
# 2021-07-23 17:29:40 INFO: Done loading processors!
# word: होता 	upos: VERB	xpos: VM
