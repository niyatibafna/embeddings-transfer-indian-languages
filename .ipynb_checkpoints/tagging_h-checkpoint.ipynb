# %%
import stanfordnlp

# %%
# !pip3 install stanfordnlp

# %%
stanfordnlp.download('hi')

# %%
nlp = stanfordnlp.Pipeline(lang="hi", processors='tokenize,mwt,pos')
s = "दूसरा घर अच्छा है".split()
for word in s:
    doc = nlp(word)
    print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/Users/mitalibafna/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tokenizer.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/Users/mitalibafna/stanfordnlp_resources/hi_hdtb_models/hi_hdtb_tagger.pt', 'pretrain_path': '/Users/mitalibafna/stanfordnlp_resources/hi_hdtb_models/hi_hdtb.pretrain.pt', 'lang': 'hi', 'shorthand': 'hi_hdtb', 'mode': 'predict'}
# Done loading processors!
# ---
# word: दूसरा 	upos: ADJ	xpos: QO
# word: घर 	upos: NOUN	xpos: NN
# word: अच्छा 	upos: ADJ	xpos: JJ
# word: है 	upos: AUX	xpos: VM

# %%
morph_file = open("hindi_data/hin.tok.txt").read().split("\n")
for line in morph_file:
    word = line.strip("\n")
    doc = nlp(word)
#     print(doc.sentences[0].words[0].text, "\t", doc.sentences[0].words[0].upos)
    print(*[f'word: {word.text+" "}\tupos: {word.upos}\txpos: {word.xpos}' for sent in doc.sentences for word in sent.words], sep='\n')
    print("\n")
# Out:
# word: लेकिन 	upos: CCONJ	xpos: CC
#
#
# word: गांव 	upos: NOUN	xpos: NN
#
#
# word: के 	upos: PUNCT	xpos: SYM
#
#
# word: जगदीश 	upos: PROPN	xpos: NNP
#
#
# word: मेघ 	upos: PROPN	xpos: NNP
# word: वाल 	upos: PUNCT	xpos: SYM
#
#
# word: , 	upos: PUNCT	xpos: SYM
#
#
# word: मोहन 	upos: PROPN	xpos: NNP
#
#
# word: . 	upos: PUNCT	xpos: SYM
#
#
# word: . 	upos: PUNCT	xpos: SYM
#
#
# word: . 	upos: PUNCT	xpos: SYM
#
#
# word: इन 	upos: DET	xpos: DEM
#
#
# word: बोतल 	upos: NOUN	xpos: NN
# word: ों 	upos: PUNCT	xpos: SYM
#
#
# word: के 	upos: PUNCT	xpos: SYM
#
#
# word: बहुत 	upos: DET	xpos: QF
#
#
# word: कम 	upos: DET	xpos: QF
#
#
# word: पैसे 	upos: NOUN	xpos: NN
#
#
# word: मिलते 	upos: VERB	xpos: VM
#
#
# word: हैं 	upos: AUX	xpos: VM
#
#
# word: । 	upos: PUNCT	xpos: SYM
#
#
# word: प्रखर 	upos: PUNCT	xpos: SYM
#
#
# word: बुद्धि 	upos: NOUN	xpos: NN
#
#
# word: तेजस् 	upos: PROPN	xpos: NNP
# word: वी 	upos: PUNCT	xpos: SYM
#
#
# word: बालक 	upos: NOUN	xpos: NN
#
#
# ...

# %%
tok_sent_file = open("hindi_data/hin.tok.txt").read().split("\n")

# %%
morph_file = open("hindi_data/hin.segmented.txt").read().split("\nE O L\n")
