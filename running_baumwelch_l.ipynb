# %%
import nltk
import pickle
import random
import re
import time

# %%
#small example
trainer = nltk.tag.hmm.HiddenMarkovModelTrainer()
s = """"मेरी मा आ रही है। तेरा नही पता। ऒर बता।"""
sentences = s.split('।')[:-1]
print(sentences)
seq = [list(map(lambda x:(x,''), ss.split(' '))) for ss in sentences]
print(seq[0][0])
symbols = list(set([ss[0] for sss in seq for ss in sss]))
print(symbols)
states = range(5)
trainer = nltk.tag.hmm.HiddenMarkovModelTrainer(states=states,symbols=symbols)
m = trainer.train(unlabeled_sequences = seq)
f = open('my_classifier.pickle', 'wb')
pickle.dump(m, f)
f.close()
g = open('my_classifier.pickle', 'rb')
m = pickle.load(g)
# print(s.split())
m.best_path(s.split())

# %%
#getting unlabeled segmented data

# data = [re.split(' |\n', ss)[1:-1] for ss in data]
data = open("marathi_data/mr/mr.segmented.EOLmarked.txt").read().split("E O L")
data = [re.split(' |\n', ss)[1:-1] for ss in data]
untagged_data = [list(map(lambda x:(x,''), ss)) for ss in data]

# %%
data[:5]
# Out:
# [['दाखवि',
#   'णे',
#   'आणि',
#   'आश्वासन',
#   'े',
#   'देणार',
#   'े',
#   'नेते',
#   'ही',
#   'लोक',
#   'ांना',
#   'खूप',
#   'आवडत',
#   'ात',
#   '.'],
#  ['मुलां',
#   'सोबतच',
#   'पालक',
#   'ांना',
#   'सांभाळ',
#   'ण्याची',
#   'जबाबदार',
#   'ी',
#   'ही',
#   'विवाह',
#   'ीत',
#   'महिलां',
#   'ची',
#   'ही',
#   'आहे',
#   '.',
#   '.',
#   '.',
#   'के',
#   'वळ',
#   ',',
#   'विवाह',
#   'झाला',
#   'य',
#   'म्हणून',
#   'वृद्ध',
#   'पालक',
#   'ांची',
#   'जबाबदार',
#   'ी',
#   'त्यांना',
#   'झटक',
#   'ता',
#   'येणार',
#   'नाही',
#   'असं',
#   'हाय',
#   'कोर्टा',
#   'नं',
#   'म्हटल',
#   'ंय',
#   '.'],
#  ['पहा',
#   'काय',
#   'बरळ',
#   'ला',
#   'पाकड',
#   '्यांचा',
#   'पंतप्रधान',
#   'इम',
#   'रान',
#   'खान'],
#  ['३',
#   '(',
#   'पीसीबी',
#   ')',
#   '–',
#   'मावळ',
#   'मध्ये',
#   'पवना',
#   'जलवाहिनी',
#   'विरोधात',
#   'आंदोलन',
#   'करणाऱ्या',
#   'आंदोलक',
#   'शेतकऱ',
#   '्यांवर',
#   'गोळीबार',
#   'करण्या',
#   'चे',
#   'आदेश',
#   'मी',
#   'दिल्या',
#   'चा',
#   'पंतप्रधान',
#   'नर',
#   'ेंद्र',
#   'मोदीं',
#   'चा',
#   'आरोप',
#   'चुकीच',
#   'ा',
#   'आहे',
#   '.'],
#  ['वृष',
#   'भ',
#   ':',
#   'क्षुल्ल',
#   'क',
#   'कारणा',
#   'ने',
#   'तुम्ही',
#   'अस्वस्थ',
#   'व्हा',
#   'ल',
#   '.']]

# %%
#taglist
tags = {"NOUN", "VERB", "PROPN", "ADJ", "ADV", "INTJ", \
        "ADP", "AUX", "CCONJ", "SCONJ", "DET", "NUM", "PART", "PRON", "SCONJ", \
        "PUNCT", "SYM", "X", \
        "NSUFF", "VSUFF", "AJSUFF", "PREF"}

# %%
#getting tagged data
tagged_data = open("marathi_data/mr/mr.segmented.gold_tagged.txt", "r").read().split("E O L")
tagged_data = [re.split('\n', ss)[1:-1] for ss in tagged_data]
# tagged_seq = [list(map(lambda x: (x.split("\t")[0], x.split("\t")[1]), sent)) for sent in tagged_data]

# %%
#formatting tagged data
for sentidx, sent in enumerate(tagged_data):
    for wordidx, word in enumerate(sent):
        print(word.split("\t"))
#         assert(len(word.split("\t"))==2)
        tpair = (word.split("\t")[0], word.split("\t")[1])
        assert(word.split("\t")[1] in tags)
        tagged_data[sentidx][wordidx] = tpair
# Out:
# ['निम', 'X']
# ['म', 'X']
# ['बॅल', 'X']
# ['न्स', 'X']
# ['खात्या', 'NOUN']
# ['त', 'ADP']
# ['ठेव', 'VERB']
# ['ू', 'VSUFF']
# ['शकत', 'VERB']
# ['नाहीत', 'PART']
# ['असे', 'SCONJ']
# ['लोक', 'NOUN']
# ['कोण', 'DET']
# ['आहेत', 'VERB']
# ['.', 'PUNCT']
# ['.', 'PUNCT']
# ['.', 'PUNCT']
# ['हे', 'DET']
# ['सगळे', 'ADJ']
# ['गरीब', 'ADJ']
# ['मध्यमवर्गीय', 'ADJ']
# ['लोक', 'NOUN']
# ['आहेत', 'VERB']
# ['.', 'PUNCT']
# ['त्या', 'DET']
# ['मुळे', 'ADV']
# ['मायावती', 'PROPN']
# ['ंनी', 'ADP']
# ['पाठि', 'X']
# ['ंबा', 'X']
# ['काढ', 'VERB']
# ['ू', 'VSUFF']
# ['असे', 'SCONJ']
# ['धमकाव', 'VERB']
# ['ल्यानंतर', 'ADV']
# ['मुख्यमंत्र', 'NOUN']
# ['ी', 'NSUFF']
# ['कमल', 'NOUN']
# ['नाथ', 'PROPN']
# ['यांनी', 'ADP']
# ['राजकीय', 'ADJ']
# ['द्वेष', 'NOUN']
# ['ातून', 'ADP']
# ['भर', 'VERB']
# ['ण्यात', 'VSUFF', '']
# ['आ', 'VERB']
# ['लेले', 'AUX']
# ['खटल', 'NOUN']
# ['े', 'NSUFF']
# ['मागे', 'ADJ']
# ['घेण्या', 'VERB']
# ['त', 'ADP']
# ['येणार', 'VERB']
# ['असल्या', 'VERB']
# ['चे', 'ADP']
# ['जाहीर', 'VERB']
# ['केले', 'VERB']
# ['.', 'PUNCT']
# ['वेंगुर्', 'PROPN']
# ['ले', 'AUX']
# [':', 'PUNCT']
# ['पावसाळ्', 'NOUN']
# ['य़ात', 'ADP']
# ['जमीन', 'NOUN']
# ['दोस्त', 'NOUN']
# ['झाले', 'VERB']
# ['ले', 'AUX']
# ['भुज', 'PROPN']
# ['नाक', 'NOUN']
# ['वाडी', 'NOUN']
# ['येथील', 'ADP']
# ['गरीब', 'ADJ']
# ['महिले', 'NOUN']
# ['चे', 'ADP']
# ['घर', 'NOUN']
# ['दान', 'NOUN']
# ['शूर', 'ADJ']
# ['व्यक्ती', 'NOUN']
# ['ंच्या', 'NSUFF']
# ['मदती', 'NOUN']
# ['तून', 'NSUFF']
# ['बांध', 'VERB']
# ['ल्यानंतर', 'ADV']
# ['घर', 'NOUN']
# ['ाचा', 'ADP']
# ['ता', 'NSUFF']
# ['बा', 'X']
# ['देताना', 'VERB']
# ['नगराध्यक्ष', 'NOUN']
# ['दिली', 'VERB']
# ['प', 'X']
# ['गिर', 'VERB']
# ['प', 'X']
# ['व', 'CCONJ']
# ['अन्य', 'ADJ']
# ['.', 'PUNCT']
# ['सध्या', 'ADP']
# ['फ्लिपकार्ट', 'PROPN']
# ['आघाडी', 'ADP']
# ['वर', 'ADP']
# ['अस', 'VERB']
# ['ली', 'VSUFF']
# ['तरी', 'SCONJ']
# ['भविष्य', 'NOUN']
# ['ातील', 'ADP']
# ['आव्हान', 'NOUN']
# ['े', 'NSUFF']
# ['लक्ष', 'NOUN']
# ['ात', 'NSUFF']
# ['घेत', 'VERB']
# ['कंपनी', 'NOUN']
# ['ने', 'NSUFF']
# ['मिंट', 'NOUN']
# ['्रा', 'X']
# ['चे', 'ADP']
# ['अधि', 'X']
# ['ग्रहण', 'NOUN']
# ['केले', 'VERB']
# ['असून', 'VERB']
# ['यामुळे', 'ADV']
# ['तयार', 'ADJ']
# ['आणि', 'CCONJ']
# ['फॅशन', 'NOUN']
# ['ेबल', 'X']
# ['कपड', 'NOUN']
# ['यांच्या', 'NSUFF']
# ['विभागा', 'NOUN']
# ['त', 'ADP']
# ['फ्लिपकार्ट', 'PROPN']
# ['ला', 'ADP']
# ['मुस', 'X']
# ['ंडी', 'X']
# ['मार', 'VERB']
# ['ता', 'VSUFF']
# ['येईल', 'VERB']
# ['.', 'PUNCT']
# ['मृत्यू', 'NOUN']
# ['च्या', 'ADP']
# ['दिशे', 'NOUN']
# ['ने', 'ADP']
# ['सुरु', 'NOUN']
# ['असले', 'VERB']
# ['ला', 'AUX']
# ['त्या', 'DET']
# ['चा', 'ADP']
# ['हा', 'DET']
# ['प्रवास', 'NOUN']
# ['त्या', 'DET']
# ['ला', 'ADP']
# ['जाणव', 'VERB']
# ['ला', 'AUX']
# ['होता', 'AUX']
# ['.', 'PUNCT']
# ['बिल्डर', 'NOUN']
# ['ने', 'ADP']
# ['सोसायटी', 'NOUN']
# ['हॅंड', 'NOUN']
# ['ओव्हर', 'ADP']
# ['के', 'VERB']
# ['लेली', 'AUX']
# ['नस', 'VERB']
# ['ल्याने', 'AUX']
# ['संरक्षण', 'NOUN']
# ['भिंती', 'NOUN']
# ['च्या', 'ADP']
# ['दुरूस्त', 'ADJ']
# ['ीची', 'ADP']
# ['जबाबदार', 'ADJ']
# ['ी', 'AJSUFF']
# ['ही', 'PART']
# ['बिल्डर', 'NOUN']
# ['ची', 'ADP']
# ['आहे ', 'VERB']
# ['. ', 'PUNCT']
# ['आमच्या', 'NOUN']
# ['वर्ग', 'NOUN']
# ['ाला', 'ADP']
# ['क्रिकेट', 'NOUN']
# ['चं', 'ADP']
# ['भारी', 'ADJ']
# ['वेड', 'NOUN']
# ['!', 'PUNCT']
# ['दुसर्या', 'ADJ']
# ['दिवशी', 'NOUN']
# ['पहाटे', 'NOUN']
# ['लवकर', 'ADJ']
# ['उठ', 'VERB']
# ['ून', 'VSUFF']
# ['जाग', 'VERB']
# ['ेश्वर', 'PROPN']
# ['ला', 'ADP']
# ['जाय', 'VERB']
# ['ला', 'ADP']
# ['निघालो', 'VERB']
# ['.', 'PUNCT']
# ['कोरड', 'PROPN']
# ['ा', 'NSUFF']
# ['नदी', 'NOUN']
# ['पात्र', 'NOUN']
# ['क्षेत्रात', 'NOUN']
# ['गेल्या', 'VERB']
# ['दोन', 'NUM']
# ['ते', 'ADP']
# ['तीन', 'NUM']
# ['वर्षां', 'NOUN']
# ['पासून', 'ADP']
# ['दम', 'NOUN']
# ['दार', 'NSUFF']
# ['पाऊस', 'NOUN']
# ['झाला', 'VERB']
# ['नाही', 'PART']
# ['.', 'PUNCT']
# ['ऐतिहासिक', 'ADJ']
# ['आंदोलना', 'NOUN']
# ['त', 'ADP']
# ['तंबाखू', 'NOUN']
# ['कामगार', 'NOUN']
# ['ांचा', 'ADP']
# ['प्रश्न', 'NOUN']
# ['ही', 'PART']
# ['मांड', 'NOUN']
# ['ण्यात', 'ADP']
# ['आ', 'VERB']
# ['ला', 'VSUFF']
# ['.', 'PUNCT']
# ['(', 'PUNCT']
# ['शक', 'NOUN']
# ['े', 'NSUFF']
# ['१७', 'NUM']
# ['१५', 'NUM']
# ['ज्ये', 'NOUN']
# ['ष्ट', 'X']
# ['शुद्ध', 'ADJ']
# ['२', 'NUM']
# ['सोमवार', 'PROPN', '']
# ['.', 'PUNCT']
# ['नवी', 'ADJ']
# ['दिल्ली', 'PROPN']
# ['मंगळवार', 'PROPN']
# ['ी', 'NSUFF']
# ['यजमान', 'NOUN', '']
# ['इंग्लंड', 'PROPN']
# ['कडून', 'ADP']
# ['150', 'NUM']
# ['धाव', 'NOUN']
# ['ांनी', 'NSUFF']
# ['ला', 'ADP']
# ['जिरवा', 'ADJ']
# ['णा', 'X']
# ['परा', 'NOUN']
# ['भव', 'NSUFF']
# ['स्वीकार', 'VERB']
# ['ावा', 'VSUFF']
# ['लाग', 'VERB']
# ['ल्यानंतर', 'ADP']
# ['अफगाणिस्तान', 'PROPN']
# ['च्या', 'ADP']
# ['संघा', 'NOUN']
# ['त', 'ADP']
# ['उभ', 'VERB']
# ['ी', 'VSUFF']
# ['फूट', 'VERB']
# ['पड', 'AUX']
# ['ली', 'VSUFF']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['(', 'PUNCT']
# ['गॉग', 'PROPN']
# ['चं', 'ADP']
# ['माझ', 'PRON']
# ['ं', 'PART']
# ['आवडत', 'VERB']
# ['ं', 'PART']
# ['चित्र', 'NOUN']
# ['ः', 'PART']
# ['वि', 'X']
# ['कि', 'X']
# ['पी', 'X']
# ['डिया', 'X']
# ['वरून', 'ADP']
# ['सा', 'X']
# ['भार', 'NOUN']
# [')', 'PUNCT']
# ['ति', 'PRON']
# ['चा', 'ADP']
# ['जीव', 'NOUN']
# ['असल्या', 'DET']
# ['मुलां', 'NOUN']
# ['साठी', 'ADP']
# ['कळ', 'VERB']
# ['वळ', 'VERB']
# ['ायचा', 'AUX']
# ['.', 'PUNCT']
# ['"', 'PUNCT']
# ['नवीन', 'ADJ']
# ['पोल', 'PROPN']
# ['िश', 'NSUFF']
# ['स्कूल', 'NOUN']
# ["'", 'PUNCT']
# ['दिशा', 'NOUN']
# ['ने', 'ADP']
# ['ति', 'PRON']
# ['चा', 'ADP']
# ['तारक', 'PROPN']
# ['मेहता', 'PROPN']
# ['का', 'ADP']
# ['उल', 'ADJ']
# ['्टा', 'X']
# ['चष्म', 'NOUN']
# ['ा', 'NSUFF']
# ['या', 'DET']
# ['मालिके', 'NOUN']
# ['तील', 'ADP']
# ['ब्रेक', 'NOUN']
# ['च्या', 'ADP']
# ['आधी', 'ADV']
# ['चा', 'ADP']
# ['शेवट', 'ADJ']
# ['चा', 'ADP']
# ['भाग', 'NOUN']
# ['नुक', 'ADV']
# ['ताच', 'PART']
# ['चित्र', 'NOUN']
# ['ीत', 'ADP']
# ['केला', 'VERB']
# ['.', 'PUNCT']
# ['आज', 'NOUN']
# ['च्या', 'ADP']
# ['सत्कार', 'NOUN']
# ['मूर्ती', 'NOUN']
# ['ंचे', 'ADP']
# ['कार्य', 'NOUN']
# ['नि', 'X']
# ['कोप', 'X']
# ['समाज', 'NOUN']
# ['निर्मिती', 'NOUN']
# ['कर', 'AUX']
# ['त', 'VSUFF']
# ['असून', 'AUX']
# ['या', 'DET']
# ['कार्य', 'NOUN']
# ['ातून', 'ADP']
# ['च', 'PART']
# ['मानव', 'NOUN']
# ['तेची', 'ADP']
# ['जप', 'PROPN']
# ['णूक', 'X']
# ['होत', 'AUX']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['त्या', 'DET']
# ['चा', 'ADP']
# ['अर्थ', 'NOUN']
# ['झाडा', 'NOUN']
# ['ला', 'ADP']
# ['आकार', 'NOUN']
# ['देणे', 'VERB']
# ['किं', 'ADV']
# ['वा', 'PART']
# ['झाडा', 'NOUN']
# ['ची', 'ADP']
# ['गुणवत्ता', 'NOUN']
# ['वाढवण', 'VERB']
# ['े', 'VSUFF']
# ['असा', 'ADJ']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['कोल्हापूर', 'PROPN']
# ['जि', 'PROPN']
# ['.', 'PUNCT']
# ['प', 'PROPN']
# ['.', 'PUNCT']
# ['कर्मचा', 'NOUN']
# ['री', 'NSUFF']
# ['सहकार', 'NOUN']
# ['ी', 'NSUFF']
# ['सोसायटी', 'NOUN']
# ['च्या', 'ADP']
# ['वतीने', 'ADP']
# ['सभासद', 'NOUN']
# ['ांच्या', 'ADP']
# ['गुण', 'NOUN']
# ['वंत', 'NSUFF']
# ['मुला', 'NOUN']
# ['-', 'PUNCT']
# ['मुलीं', 'NOUN']
# ['च्या', 'ADP']
# ['सत्कार', 'NOUN']
# ['करण्या', 'VERB']
# ['त', 'VSUFF']
# ['आ', 'VERB']
# ['ला', 'VSUFF']
# ['.', 'PUNCT']
# ['दापोली', 'PROPN']
# ['तील', 'ADP']
# ['ब्राह्मण', 'NOUN']
# ['हित', 'NOUN']
# ['वर्ध', 'NOUN']
# ['िनी', 'X']
# ['पत', 'NOUN']
# ['संस्थे', 'NOUN']
# ['चे', 'ADP']
# ['विद्य', 'NOUN']
# ['मान', 'NSUFF']
# ['अध्यक्ष', 'NOUN']
# [',', 'PUNCT']
# ['कोकण', 'PROPN']
# ['ातील', 'ADP']
# ['सहकार', 'NOUN']
# ['ातील', 'ADP']
# ['ज्येष्ठ', 'ADJ']
# ['व', 'SCONJ']
# ['तज्ञ', 'NOUN']
# ['सहकार', 'NOUN']
# ['मह', 'NOUN']
# ['र्षी', 'NSUFF']
# [',', 'PUNCT']
# ['दापोली', 'PROPN']
# ['तील', 'ADP']
# ['ज्येष्ठ', 'ADJ']
# ['व्यापार', 'NOUN']
# ['ी', 'NSUFF']
# [',', 'PUNCT']
# ['दापोली', 'PROPN']
# ['शिक्षण', 'NOUN']
# ['संस्थे', 'NOUN']
# ['चे', 'ADP']
# ['माजी', 'ADJ']
# ['कार्यवाह', 'NOUN']
# ['अनिल', 'PROPN']
# ['सदाशिव', 'PROPN']
# ['जोशी', 'PROPN']
# ['यांचे', 'DET']
# ['हृदयविकार', 'NOUN']
# ['ाच्या', 'ADP']
# ['तीव्र', 'ADJ']
# ['झटक', 'VERB']
# ['्याने', 'ADP']
# ['शनिवार', 'PROPN']
# ['ी', 'NSUFF']
# ['सायंकाळ', 'NOUN', '']
# ['ी', 'NSUFF']
# ['नि', 'PREF']
# ['धन', 'NOUN']
# ['झाले', 'VERB']
# ['.', 'PUNCT']
# ['औरंगाबाद', 'PROPN']
# [':', 'PUNCT']
# ['पोलीस', 'NOUN']
# ['नामा', 'NSUFF']
# ['ऑनलाइन', 'ADJ']
# ['–', 'PUNCT']
# ['हिंग', 'PROPN']
# ['ण', 'X']
# ['घाट', 'NOUN']
# [',', 'PUNCT']
# ['नांदेड', 'PROPN']
# ['येथील', 'ADP']
# ['प्रकरण', 'NOUN']
# ['े', 'NSUFF']
# ['ता', 'X']
# ['जी', 'X']
# ['असताना', 'VERB']
# ['च', 'PART']
# ['औरंगाबाद', 'PROPN']
# ['मधील', 'ADP']
# ['सिडको', 'PROPN']
# ['त', 'ADP']
# ['असलेल्या', 'VERB']
# ['मु', 'PART']
# ['कुल', 'PART']
# ['मंदिर', 'NOUN']
# ['शाळे', 'NOUN']
# ['तील', 'ADP']
# ['सातव', 'ADJ']
# ['ीच्या', 'ADP']
# ['विद्यार्थिनी', 'NOUN']
# ['ंना', 'ADP']
# ['शाळे', 'NOUN']
# ['तील', 'ADP']
# ['च', 'PART']
# ['शिक्षक', 'NOUN']
# ['ांनी', 'ADP']
# ['अश्', 'ADJ']
# ['लिल', 'ADJ']
# ['व्हिडिओ', 'NOUN']
# ['दाखवि', 'VERB']
# ['ल्या', 'AUX']
# ['चा', 'ADP']
# ['गंभीर', 'ADJ']
# ['प्रकार', 'NOUN']
# ['समोर', 'ADJ']
# ['आ', 'VERB']
# ['ला', 'VSUFF']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['त', 'X']
# ['संच', 'ADV']
# ['मग', 'CCONJ']
# ['तुम्हा', 'PRON']
# ['ला', 'ADP']
# ['पुढ', 'ADJ']
# ['चा', 'ADP']
# ['सीन', 'NOUN']
# ['सांग', 'VERB']
# ['ून', 'AUX']
# ['त्यात', 'DET']
# ['लं', 'ADP']
# ['आश्चर्य', 'NOUN']
# ['का', 'ADP']
# ['कमी', 'ADJ']
# ['कर', 'VERB']
# ['ायचं', 'VSUFF']
# ['?', 'PUNCT']
# ['आयुष्य', 'NOUN']
# ['भर', 'ADJ']
# ['सती', 'NOUN']
# ['चं', 'ADP']
# ['वाण', 'ADJ']
# ['समज', 'VERB', '']
# ['ून', 'VSUFF']
# ['ज्या', 'PRON']
# ['ंनी', 'ADP']
# ['पत्रकार', 'NOUN']
# ['िता', 'NSUFF']
# ['केली', 'VERB']
# ['असे', 'DET']
# ['शंभर', 'NUM']
# ['पत्रकार', 'NOUN']
# ['तरी', 'ADV']
# ['आज', 'NOUN']
# ['अत्यंत', 'ADJ']
# ['हलाखी', 'NOUN']
# ['च्या', 'ADP']
# ['स्थिती', 'NOUN']
# ['त', 'ADP']
# ['जीवन', 'NOUN']
# ['जग', 'VERB']
# ['त', 'VSUFF']
# ['आहेत', 'AUX']
# ['.', 'PUNCT']
# ['आणि', 'CCONJ']
# ['पाश', 'ADJ']
# ['्', 'X']
# ['चा', 'X']
# ['त्य', 'X']
# ['लोक', 'NOUN']
# ['अनेक', 'ADJ']
# ['दा', 'NOUN']
# ['म्हणून', 'VERB']
# ['पूर्व', 'ADJ']
# ['युरोप', 'PROPN']
# ['पासून', 'ADP']
# ['बायका', 'NOUN']
# ['निवड', 'VERB']
# ['ा', 'X']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['5', 'NUM']
# ['-', 'PUNCT']
# ['10', 'NUM']
# ['दिवसां', 'NOUN']
# ['नंतर', 'ADP']
# [',', 'PUNCT']
# ['आपण', 'PRON']
# ['आधी', 'ADJ']
# ['पासूनच', 'ADP']
# ['प्रथम', 'ADJ']
# ['शूट', 'NOUN']
# ['पाह', 'VERB']
# ['ू', 'VSUFF']
# ['शकता', 'VERB']
# ['उष्ण', 'ADJ']
# ['ता', 'NSUFF']
# ['आणि', 'CCONJ']
# ['पाणी', 'NOUN']
# ['पिण्या', 'VERB']
# ['ची', 'ADP']
# ['उत्', 'ADJ']
# ['कृष्ट', 'ADJ']
# ['गुणोत्तर', 'NOUN', '']
# ['ाने', 'ADP']
# [',', 'PUNCT']
# ['लॉ', 'NOUN']
# ['न', 'NOUN']
# ['साइट', 'NOUN']
# ['2', 'NUM']
# ['-', 'PUNCT']
# ['3', 'NUM']
# ['आठवड्या', 'NOUN']
# ['त', 'ADP']
# ['क', 'X']
# ['व्हर', 'NOUN']
# ['कर', 'VERB']
# ['ेल', 'VSUFF']
# ['.', 'PUNCT']
# ['परंतु', 'CCONJ']
# ['त्या', 'DET']
# ['ची', 'ADP']
# ['दुरुस्ती', 'NOUN']
# ['के', 'VERB']
# ['लेली', 'AUX']
# ['नाही', 'PART']
# ['.', 'PUNCT']
# ['हात', 'NOUN']
# ['ी', 'NSUFF']
# ['आ', 'VERB']
# ['लेल्या', 'AUX']
# ['माहीत', 'NOUN']
# ['ी', 'NSUFF']
# ['नुसार', 'ADP']
# [',', 'PUNCT']
# ['परभणी', 'NOUN']
# ['येथे', 'DET']
# ['‘', 'PUNCT']
# ['सय्यद', 'PROPN']
# ['शाह', 'PROPN']
# ['तुरा', 'PROPN']
# ['बूल', 'PROPN']
# ['हक', 'NOUN']
# ['रहे', 'VERB']
# ['’', 'PUNCT']
# ['दर्ग', 'NOUN']
# ['्याचा', 'ADP']
# ['उर', 'NOUN']
# ['्स', 'X']
# ['सुरु', 'ADJ']
# ['आहे', 'VERB']
# ['.', 'PUNCT']
# ['इंग्लंड', 'PROPN']
# ['चा', 'ADP']
# ['माजी', 'ADJ']
# ['सलामीवीर', 'PROPN']
# ['ट्रेस', 'PROPN']
# ['्कोथिक', 'PROPN']
# ['एक', 'DET']
# ['लोकप्रिय', 'ADJ']
# ['खेळाडू', 'NOUN']
# ['होता', 'VERB']
# ['.', 'PUNCT']
# ['आता', 'ADV']
# ['एजाज', 'PROPN']
# ['शेख', 'PROPN']
# ['हे', 'DET']
# ['नवे', 'ADJ']
# ['नाव', 'NOUN']
# ['पुढे', 'ADV']
# ['आले', 'VERB']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['योजने', 'NOUN']
# ['चे', 'ADP']
# ['स्वागत', 'NOUN']
# ['केले', 'VERB']
# [',', 'PUNCT']
# ['त्या', 'DET']
# ['चे', 'ADP']
# ['समाधान', 'NOUN']
# ['असल्या', 'VERB']
# ['चे', 'ADP']
# ['मुख्यमंत्र', 'NOUN']
# ['ी', 'NSUFF']
# ['म्हणा', 'VERB']
# ['ले', 'VSUFF']
# ['.', 'PUNCT']
# ['पोलीस', 'NOUN']
# ['त्या', 'PRON']
# ['चा', 'ADP']
# ['शोध', 'NOUN']
# ['घेत', 'VERB']
# ['असून', 'AUX']
# ['त्या', 'PRON']
# ['ने', 'NSUFF']
# ['हे', 'DET']
# ['कृत्य', 'NOUN']
# ['का', 'X']
# ['केले', 'VERB']
# ['हा', 'DET']
# ['प्रश्न', 'NOUN']
# ['पोलिस', 'NOUN']
# ['ांसह', 'ADP']
# ['त्याच्या', 'PRON']
# ['आईवडिल', 'NOUN']
# ['ांना', 'ADP']
# ['ही', 'PART']
# ['पड', 'VERB']
# ['ला', 'VSUFF']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['पावसा', 'NOUN']
# ['नं', 'ADP']
# ['द', 'X']
# ['डी', 'X']
# ['मारल्या', 'VERB']
# ['मुळे', 'ADV']
# ['धरणा', 'NOUN']
# ['ंचा', 'ADP']
# ['पाणी', 'NOUN']
# ['साठा', 'NOUN']
# ['घट', 'VERB']
# ['ला', 'VSUFF']
# ['20', 'NUM']
# ['11', 'NUM']
# ['च्या', 'ADP']
# ['जनगणने', 'NOUN']
# ['प्रमाणे', 'ADV']
# ['1', 'NUM']
# ['कोटी', 'NUM']
# ['70', 'NUM']
# ['लाख', 'NUM']
# ['लोक', 'NOUN']
# ['संख्या', 'NOUN']
# ['असलेल्या', 'VERB']
# ['बुर', 'PROPN']
# ['्किन', 'PROPN']
# ['ा', 'X']
# ['फॅ', 'X']
# ['सो', 'X']
# ['मध्ये', 'ADP']
# ['मोस्सी', 'PROPN']
# [',', 'PUNCT']
# ['फुल', 'PROPN']
# ['ानी', 'X']
# [',', 'PUNCT']
# ['मांड', 'PROPN']
# ['े', 'NSUFF']
# [',', 'PUNCT']
# ['बो', 'PROPN']
# ['बो', 'PROPN']
# [',', 'PUNCT']
# ['से', 'X']
# ['नु', 'X']
# ['फो', 'X']
# ['आणि', 'CCONJ']
# ['हौस', 'PROPN']
# ['ा', 'X']
# ['या', 'SCONJ']
# ['वंश', 'NOUN']
# ['समूह', 'NOUN']
# ['ांचे', 'ADP']
# ['लोक', 'NOUN']
# ['राह', 'VERB']
# ['तात', 'VSUFF']
# [',', 'PUNCT']
# ['मुस्लीम', 'PROPN']
# ['व', 'CCONJ']
# ['ख्रिस्त', 'PROPN', '']
# ['ी', 'NSUFF']
# ['धर्मिय', 'ADJ']
# ['ांबरोबर', 'ADP']
# ['च', 'PART']
# ['पारंपरिक', 'ADJ']
# ['धार', 'ADJ']
# ['्मिक', 'AJSUFF']
# ['विचार', 'NOUN']
# ['ांवर', 'ADP']
# ['श्रद्धा', 'NOUN']
# ['असणाऱया', 'VERB']
# ['ंमध्ये', 'ADP']
# ['हे', 'DET']
# ['समूह', 'NOUN']
# ['विभाग', 'NOUN']
# ['ले', 'VSUFF']
# ['गेले', 'VERB']
# ['आहेत', 'AUX']
# ['.', 'PUNCT']
# ['रोमांच', 'NOUN']
# ['क', 'X']
# ['सामन्या', 'ADJ']
# ['त', 'ADP']
# ['भारतीय', 'ADJ']
# ['संघा', 'NOUN']
# ['ने', 'ADP']
# ['कट्टर', 'ADJ']
# ['प्रतिस्पर्ध', 'NOUN']
# ['ी', 'NSUFF']
# ['पाकिस्तान', 'PROPN']
# ['ला', 'ADP']
# ['(', 'PUNCT']
# ['Pa', 'X']
# ['ki', 'X']
# ['st', 'X']
# ['an', 'X']
# [')', 'PUNCT']
# ['5', 'NUM']
# ['धाव', 'NOUN']
# ['ांनी', 'ADP']
# ['परा', 'NOUN']
# ['भूत', 'NOUN']
# ['केले', 'VERB']
# ['.', 'PUNCT']
# ['गोड', 'ADJ']
# ['म', 'X']
# ['का', 'NOUN']
# ['वाण', 'NOUN']
# ['अनेक', 'ADJ']
# ['आहेत', 'VERB']
# ['.', 'PUNCT']
# ['या', 'DET']
# ['विनंती', 'NOUN']
# ['ला', 'ADP']
# ['क्षण', 'NOUN']
# ['ाचा', 'ADP']
# ['ही', 'PART']
# ['विलंब', 'ADJ']
# ['न', 'PART']
# ['करता', 'VERB']
# ['उद्धव', 'PROPN']
# ['ठाकरे', 'PROPN']
# ['यांनी', 'PRON']
# ['मान्य', 'NOUN']
# ['ता', 'NSUFF']
# ['दिली', 'VERB']
# ['असून', 'VERB']
# ['लवकर', 'ADV']
# ['च', 'PART']
# ['या', 'DET']
# ['संदर्भात', 'NOUN']
# ['ला', 'ADP']
# ['जी', 'PROPN']
# ['आर', 'PROPN']
# ['निघ', 'VERB']
# ['णार', 'VSUFF']
# ['आहे', 'VERB']
# ['.', 'PUNCT']
# ['प्रा', 'PROPN']
# ['कृत', 'PROPN']
# ['भाषा', 'NOUN']
# ['ंचा', 'ADP']
# ['कित्येक', 'DET']
# ['दुर', 'PREF']
# ['भिमा', 'PROPN']
# ['नी', 'ADP']
# ['विद्वान', 'ADJ']
# ['्', 'X']
# ['ब्राह्मण', 'NOUN']
# ['पूर्वी', 'ADJ']
# ['केवढा', 'DET']
# ['धि', 'X']
# ['ः', 'X']
# ['कार', 'NSUFF']
# ['कर', 'VERB']
# ['ीत', 'VSUFF']
# ['अस', 'VERB']
# ['त', 'VSUFF']
# ['हे', 'DET']
# ['खाली', 'ADP']
# ['लिहि', 'VERB']
# ['लेल्या', 'AUX']
# ['संस्कृत', 'PROPN']
# ['वचन', 'NOUN']
# ['ांवरून', 'ADP']
# ['दिस', 'VERB']
# ['ून', 'VSUFF']
# ['येईल', 'VERB']
# ['.', 'PUNCT']
# ['या', 'DET']
# ['भोंग', 'NOUN']
# ['्यांच्या', 'ADP']
# ['आवाजा', 'NOUN']
# ['मुळे', 'ADV']
# ['परीक्षे', 'NOUN']
# ['च्या', 'ADP']
# ['काळात', 'NOUN']
# ['विद्यार्थ्', 'NOUN']
# ['यांचे', 'ADP']
# ['नकुसा', 'NOUN']
# ['न', 'X']
# ['होऊ', 'VERB']
# ['नये', 'PART']
# ['म्हणून', 'VERB']
# ['कार्यकर्त्या', 'NOUN']
# ['ंनी', 'ADP']
# ['ही', 'PART']
# ['मागणी', 'NOUN']
# ['केली', 'VERB']
# ['आहे', 'VERB']
# ['.', 'PUNCT']
# ['राजा', 'NOUN']
# ['मूळ', 'ADJ']
# ['आवृत्ती', 'NOUN']
# ['दिमित्री', 'PROPN']
# ['युसूफ', 'PROPN']
# ['व्य', 'ADJ']
# ['स्त', 'ADJ']
# ['फक्त', 'ADJ']
# ['थिएटर', 'NOUN']
# ['मध्ये', 'ADP']
# ['कार्य', 'NOUN']
# ['करणार', 'VERB']
# ['नाही', 'PART']
# ['.', 'PUNCT']
# ['त्या', 'PRON']
# ['नंतर', 'ADV']
# ['दाभोलकर', 'PROPN']
# ['ांवर', 'ADP']
# ['गोळ्या', 'NOUN']
# ['झाड', 'VERB']
# ['णारे', 'AUX']
# ['दुसर', 'ADJ']
# ['े', 'X']
# ['तिस', 'ADJ']
# ['रे', 'X']
# ['कोणी', 'PRON']
# ['नाही', 'PART']
# ['तर', 'PART']
# ['अंदुरे', 'PROPN']
# ['आणि', 'CCONJ']
# ['कळस', 'PROPN']
# ['कर', 'X']
# ['हे', 'DET']
# ['च', 'PART']
# ['दोघे', 'PROPN']
# ['असल्या', 'VERB']
# ['ची', 'ADP']
# ['क', 'X']
# ['बुल', 'NOUN']
# ['ी', 'X']
# ['खुद्द', 'PRON']
# ['आरोपी', 'NOUN']
# ['ंनी', 'ADP']
# ['दिल्या', 'VERB']
# ['ची', 'ADP']
# ['माहिती', 'NOUN']
# ['समोर', 'ADJ']
# ['आली', 'VERB']
# ['होती', 'AUX']
# ['.', 'PUNCT']
# ['अ', 'PREF']
# ['कृषी', 'NOUN', '']
# ['विद्यापीठ', 'NOUN']
# ['े', 'NSUFF']
# [',', 'PUNCT']
# ['शासकीय', 'ADJ']
# [',', 'PUNCT']
# ['अ', 'PREF']
# ['शासकीय', 'ADJ']
# ['अनुदान', 'NOUN']
# ['ित', 'NSUFF']
# [',', 'PUNCT']
# ['अंश', 'NOUN']
# ['तः', 'PART']
# ['अनुदान', 'NOUN']
# ['ित', 'NSUFF']
# ['महाविद्यालय', 'NOUN']
# ['े', 'NSUFF']
# [',', 'PUNCT']
# ['त', 'X']
# ['से', 'X']
# ['च', 'X']
# ['कायम', 'ADJ']
# ['विना', 'PREF']
# ['अनुदान', 'NOUN']
# ['ित', 'NSUFF']
# ['महाविद्यालय', 'NOUN']
# ['ांतील', 'ADP']
# ['या', 'DET']
# ['विषय', 'NOUN']
# ['ांच्या', 'ADP']
# ['विद्यार्थ्', 'NOUN']
# ['यांना', 'ADP']
# ['शिक्षण', 'NOUN']
# ['शुल्क', 'NOUN']
# ['ात', 'ADP']
# ['पूर्ण', 'ADJ']
# ['सूट', 'NOUN']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['बंद', 'ADJ']
# ['िस्त', 'AJSUFF']
# ['पाईपलाईन', 'NOUN']
# ['मधून', 'ADP']
# ['शेतकऱ', 'NOUN']
# ['यांच्या', 'ADP']
# ['बांध', 'NOUN', '']
# ['ापर्यंत', 'ADP']
# ['पाणी', 'NOUN']
# ['देण्या', 'VERB']
# ['चे', 'ADP']
# ['आम', 'PRON']
# ['चे', 'PRON']
# ['धोरण', 'NOUN']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['धाव', 'VERB']
# ['त्या', 'AUX']
# ['रेल्वे', 'NOUN']
# ['तील', 'ADP']
# ['चोर', 'NOUN']
# ['्यांमध्ये', 'ADP']
# ['मोठ्या', 'ADJ']
# ['प्रमाणात', 'NOUN']
# ['वाढ', 'NOUN']
# ['झाली', 'VERB']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['चाल', 'VERB']
# ['णे', 'VSUFF']
# ['सरासरी', 'ADJ']
# ['दर', 'NOUN']
# ['-', 'PUNCT']
# ['प्रति', 'PART', '']
# ['तास', 'NOUN']
# ['5', 'NUM']
# ['किमी', 'NOUN']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['आम्ही', 'PRON']
# ['तिघं', 'NUM']
# ['त्या', 'DET']
# ['औषध', 'NOUN']
# ['कंपनी', 'NOUN']
# ['च्या', 'ADP']
# ['दिशे', 'NOUN']
# ['ने', 'ADP']
# ['जाऊ', 'VERB']
# ['लाग', 'VERB']
# ['लो', 'VSUFF']
# ['.', 'PUNCT']
# ['त्याच्या', 'PRON']
# ['इच्छे', 'NOUN']
# ['ने', 'ADP']
# ['ति', 'PRON']
# ['चा', 'ADP']
# ['भोग', 'NOUN']
# ['घ्य', 'VERB']
# ['ायला', 'ADP']
# ['प्रत्येक', 'ADJ']
# ['जण', 'PRON']
# ['स्वतंत्र', 'ADJ']
# ['होता', 'AUX']
# ['.', 'PUNCT']
# ['उन्हाळ', 'NOUN']
# ['्याचे', 'ADP']
# ['दिवस', 'NOUN']
# ['सुरू', 'NOUN']
# ['झाले', 'VERB']
# ['की', 'PART']
# ['सुट्ट', 'NOUN']
# ['्या', 'NSUFF']
# [',', 'PUNCT']
# ['मज्जा', 'NOUN']
# ['मस्ती', 'NOUN']
# ['चे', 'ADP']
# ['दिवस', 'NOUN']
# ['सुरू', 'NOUN']
# ['होतात', 'AUX']
# ['.', 'PUNCT']
# ['सध्या', 'NOUN']
# ['राज्यात', 'NOUN']
# ['सर्व', 'ADJ']
# ['च', 'X']
# ['कोरडे', 'ADJ']
# ['हवामान', 'NOUN', '']
# ['असून', 'AUX']
# [',', 'PUNCT']
# ['उत्तरे', 'NOUN']
# ['कडून', 'ADP']
# ['थंड', 'ADJ']
# ['वार्या', 'NOUN']
# ['चा', 'ADP']
# ['प्रवाह', 'NOUN']
# ['सुरू', 'NOUN']
# ['आहे', 'AUX']
# ['.', 'PUNCT']
# ['पृथक्', 'ADJ']
# ['निवड', 'NOUN', '']
# ['गृह', 'NOUN']
# ['निर्माण', 'NOUN']
# [',', 'PUNCT']
# ['पर्यावरण', 'NOUN']
# ['ीय', 'NSUFF']
# ['परिस्थिती', 'NOUN']
# [',', 'PUNCT']
# ['st', 'X']
# ['or', 'X']
# ['ey', 'X']
# ['s', 'X']
# ['आणि', 'CCONJ']
# ['लोड', 'NOUN']
# ['त्यांची', 'PRON']
# ['संख्या', 'NOUN']
# ['तयार', 'ADJ']
# ['कर', 'VERB']
# ['ण्यासाठी', 'VSUFF']
# ['जे', 'PRON']
# ['साहित्य', 'NOUN']
# ['अवलंब', 'NOUN']
# ['ून', 'NSUFF']
# ['असते', 'VERB']
# ['.', 'PUNCT']

# %%
# print(tagged_data[:5])

# %%
#Training
#7:    10
start = time.time()
symbols = list(set([ss[0] for sss in untagged_data for ss in sss]))
print(len(symbols))
states = list(tags)
trainer = nltk.tag.hmm.HiddenMarkovModelTrainer(states=states,symbols=symbols)
hmm_tagged = trainer.train_supervised(tagged_data) 
print("Tagged trained!")
hmm_all = trainer.train_unsupervised(untagged_data, model = hmm_tagged, max_iterations=100)
end = time.time()
print("Fully trained!")
print("Time take: ", end-start)
# Out:
# Tagged trained!
# iteration 0 logprob -6.027949999999301e+305
# iteration 1 logprob -1.3999161707086247e+294
# iteration 2 logprob -13293543.052937528
# iteration 3 logprob -12314384.334014881
# iteration 4 logprob -12204953.12023687
# iteration 5 logprob -12088962.453261444
# iteration 6 logprob -11988326.890268086
# iteration 7 logprob -11912186.192758031
# iteration 8 logprob -11855235.794733532
# iteration 9 logprob -11811711.144262718
# iteration 10 logprob -11777691.282846304
# iteration 11 logprob -11750957.066613251
# iteration 12 logprob -11729812.348699365
# iteration 13 logprob -11712619.145432454
# iteration 14 logprob -11698191.481072046
# iteration 15 logprob -11685936.90470146
# iteration 16 logprob -11675583.047305644
# iteration 17 logprob -11666863.115232347
# iteration 18 logprob -11659447.170365455
# iteration 19 logprob -11653056.071799709
# iteration 20 logprob -11647504.616321772
# iteration 21 logprob -11642637.38013993
# iteration 22 logprob -11638288.583334658
# iteration 23 logprob -11634339.871234957
# iteration 24 logprob -11630696.417863451
# iteration 25 logprob -11627300.13028313
# iteration 26 logprob -11624162.363217501
# iteration 27 logprob -11621277.050664984
# iteration 28 logprob -11618615.60845359
# iteration 29 logprob -11616149.484140031
# iteration 30 logprob -11613824.815416357
# iteration 31 logprob -11611832.866540218
# iteration 32 logprob -11610063.265883906
# iteration 33 logprob -11608478.701011999
# iteration 34 logprob -11607047.038733687
# iteration 35 logprob -11605739.518920999
# iteration 36 logprob -11604533.459710663
# iteration 37 logprob -11603395.02607577
# iteration 38 logprob -11602314.687658986
# iteration 39 logprob -11601292.546334377
# iteration 40 logprob -11600328.328513764
# iteration 41 logprob -11599437.374354394
# iteration 42 logprob -11598610.124523131
# iteration 43 logprob -11597835.18227243
# iteration 44 logprob -11597106.188992126
# iteration 45 logprob -11596398.039169328
# iteration 46 logprob -11595699.862497108
# iteration 47 logprob -11595036.941546107
# iteration 48 logprob -11594413.733117724
# iteration 49 logprob -11593815.897234354
# iteration 50 logprob -11593247.405636707
# iteration 51 logprob -11592718.933473049
# iteration 52 logprob -11592222.834175015
# iteration 53 logprob -11591756.178459411
# iteration 54 logprob -11591326.394768309
# iteration 55 logprob -11590921.391319906
# iteration 56 logprob -11590532.070400937
# iteration 57 logprob -11590164.937205823
# iteration 58 logprob -11589827.840731725
# iteration 59 logprob -11589514.775761515
# iteration 60 logprob -11589211.967599006
# iteration 61 logprob -11588920.228919711
# iteration 62 logprob -11588652.804966656
# iteration 63 logprob -11588404.704617431
# iteration 64 logprob -11588170.514055911
# iteration 65 logprob -11587945.22825176
# iteration 66 logprob -11587729.701269
# iteration 67 logprob -11587521.529736158
# iteration 68 logprob -11587309.647952335
# iteration 69 logprob -11587079.59526929
# iteration 70 logprob -11586829.746207565
# iteration 71 logprob -11586573.80185106
# iteration 72 logprob -11586320.962666877
# iteration 73 logprob -11586084.12984183
# iteration 74 logprob -11585882.561521932
# iteration 75 logprob -11585711.51447736
# iteration 76 logprob -11585559.59214939
# iteration 77 logprob -11585417.326446692
# iteration 78 logprob -11585283.353604607
# iteration 79 logprob -11585156.09253471
# iteration 80 logprob -11585038.497584295
# iteration 81 logprob -11584923.380645514
# iteration 82 logprob -11584808.059437148
# iteration 83 logprob -11584693.266773416
# iteration 84 logprob -11584581.094487494
# iteration 85 logprob -11584472.256280579
# iteration 86 logprob -11584363.869584257
# iteration 87 logprob -11584257.13049009
# iteration 88 logprob -11584148.53581025
# iteration 89 logprob -11584034.623627033
# iteration 90 logprob -11583916.06888338
# iteration 91 logprob -11583801.178314166
# iteration 92 logprob -11583693.884861773
# iteration 93 logprob -11583593.076982442
# iteration 94 logprob -11583495.808054537
# iteration 95 logprob -11583398.385215014
# iteration 96 logprob -11583303.253748527
# iteration 97 logprob -11583214.826477451
# iteration 98 logprob -11583128.293698527
# iteration 99 logprob -11583045.339226685
# Fully trained!
# Time take:  172264.40307283401

# %%
#Saving model
f = open('hmm_tagger_l.pickle', 'wb')
pickle.dump(hmm_all, f)
f.close()

# %%
g = open('hmm_tagger_l.pickle', 'rb')
m = pickle.load(g)
# s = data[0]
# print(m.best_path(data[0]))
# print(data[0])
for idx in range(10):
    print(list(zip(data[idx], m.best_path(data[idx]))))
# Out:
# [('दाखवि', 'VERB'), ('णे', 'VSUFF'), ('आणि', 'DET'), ('आश्वासन', 'NOUN'), ('े', 'NSUFF'), ('देणार', 'NOUN'), ('े', 'NSUFF'), ('नेते', 'DET'), ('ही', 'DET'), ('लोक', 'NOUN'), ('ांना', 'ADP'), ('खूप', 'NOUN'), ('आवडत', 'NOUN'), ('ात', 'NSUFF'), ('.', 'PUNCT')]
# [('मुलां', 'NOUN'), ('सोबतच', 'ADP'), ('पालक', 'NOUN'), ('ांना', 'ADP'), ('सांभाळ', 'VERB'), ('ण्याची', 'VSUFF'), ('जबाबदार', 'ADJ'), ('ी', 'NSUFF'), ('ही', 'PART'), ('विवाह', 'NOUN'), ('ीत', 'VSUFF'), ('महिलां', 'PRON'), ('ची', 'ADP'), ('ही', 'VERB'), ('आहे', 'AUX'), ('.', 'PUNCT'), ('.', 'PUNCT'), ('.', 'PUNCT'), ('के', 'ADJ'), ('वळ', 'VERB'), (',', 'PUNCT'), ('विवाह', 'ADJ'), ('झाला', 'VERB'), ('य', 'AUX'), ('म्हणून', 'ADJ'), ('वृद्ध', 'AJSUFF'), ('पालक', 'NOUN'), ('ांची', 'NSUFF'), ('जबाबदार', 'ADJ'), ('ी', 'NSUFF'), ('त्यांना', 'PART'), ('झटक', 'VERB'), ('ता', 'VSUFF'), ('येणार', 'VERB'), ('नाही', 'AUX'), ('असं', 'PUNCT'), ('हाय', 'DET'), ('कोर्टा', 'PRON'), ('नं', 'ADP'), ('म्हटल', 'VERB'), ('ंय', 'AUX'), ('.', 'PUNCT')]
# [('पहा', 'X'), ('काय', 'SCONJ'), ('बरळ', 'VERB'), ('ला', 'VSUFF'), ('पाकड', 'PRON'), ('्यांचा', 'ADP'), ('पंतप्रधान', 'DET'), ('इम', 'PREF'), ('रान', 'PROPN'), ('खान', 'PROPN')]
# [('३', 'NUM'), ('(', 'PUNCT'), ('पीसीबी', 'PROPN'), (')', 'PROPN'), ('–', 'PROPN'), ('मावळ', 'PROPN'), ('मध्ये', 'ADP'), ('पवना', 'DET'), ('जलवाहिनी', 'PRON'), ('विरोधात', 'ADP'), ('आंदोलन', 'PART'), ('करणाऱ्या', 'PART'), ('आंदोलक', 'NOUN'), ('शेतकऱ', 'NOUN'), ('्यांवर', 'NSUFF'), ('गोळीबार', 'PART'), ('करण्या', 'VERB'), ('चे', 'ADP'), ('आदेश', 'ADV'), ('मी', 'ADJ'), ('दिल्या', 'VERB'), ('चा', 'ADP'), ('पंतप्रधान', 'DET'), ('नर', 'ADJ'), ('ेंद्र', 'AJSUFF'), ('मोदीं', 'NOUN'), ('चा', 'ADP'), ('आरोप', 'ADV'), ('चुकीच', 'NOUN'), ('ा', 'NSUFF'), ('आहे', 'VERB'), ('.', 'PUNCT')]
# [('वृष', 'PREF'), ('भ', 'PROPN'), (':', 'PUNCT'), ('क्षुल्ल', 'X'), ('क', 'X'), ('कारणा', 'PRON'), ('ने', 'ADP'), ('तुम्ही', 'DET'), ('अस्वस्थ', 'PART'), ('व्हा', 'PART'), ('ल', 'X'), ('.', 'PUNCT')]
# [('तो', 'DET'), ('किती', 'PART'), ('बद्दल', 'PART'), (',', 'DET'), ('आम्ही', 'ADJ'), ('नंतर', 'ADP'), ('तुम्हा', 'NOUN'), ('ं', 'NSUFF'), ('ला', 'ADP'), ('सांग', 'VERB'), ('तो', 'AUX'), ('.', 'PUNCT')]
# [('मुख्य', 'DET'), ('पान', 'NOUN'), ('चालू', 'NSUFF'), ('घडामोडी', 'PART'), ('शेतकऱ', 'PRON'), ('यांना', 'ADP'), ('कर्जमाफी', 'ADV'), ('किं', 'PART'), ('वा', 'PART'), ('भरपाई', 'SCONJ')]
# [('मुलां', 'NOUN'), ('मध्ये', 'ADP'), ('भेद', 'ADV'), ('भाव', 'ADJ'), ('पालक', 'NOUN'), ('ांनी', 'NSUFF'), ('करू', 'PART'), ('नये', 'PART'), (',', 'DET'), ('मिठाई', 'ADV'), ('आण', 'VERB'), ('ली', 'AUX'), ('असेल', 'PUNCT'), ('तर', 'DET'), ('सर्व', 'ADJ'), ('ाना', 'NSUFF'), ('द्याव', 'NOUN'), ('ी', 'NSUFF'), (',', 'PUNCT'), ('फक्त', 'DET'), ('एका', 'DET'), ('च', 'PART'), ('मुला', 'NOUN'), ('ला', 'AUX'), ('/', 'PUNCT'), ('मुली', 'NOUN'), ('ला', 'ADP'), ('आणि', 'DET'), ('इतरां', 'PRON'), ('ना', 'ADP'), ('नाही', 'PART'), ('असे', 'ADJ'), ('नको', 'X'), ('.', 'PUNCT')]
# [('राज्यात', 'ADJ'), ('लं', 'ADP'), ('सरकार', 'PRON'), ('आणि', 'ADP'), ('मुख्यमंत्र', 'NOUN'), ('ी', 'NSUFF'), ('चांग', 'VERB'), ('लं', 'ADP'), ('काम', 'ADV'), ('कर', 'VERB'), ('त', 'VSUFF'), ('आहेत', 'AUX'), ('.', 'PUNCT')]
# [('चित्रपट', 'NOUN'), ('ातील', 'ADP'), ('गा', 'VERB'), ('णं', 'VSUFF'), ('रि', 'ADJ'), ('मेक', 'AJSUFF'), ('जरी', 'PART'), ('अस', 'VERB'), ('लं', 'ADP'), ('तरी', 'PART'), ('त्यात', 'DET'), ('बॉलिवूड', 'DET'), ('स्टाईल', 'PART'), ('वापर', 'VERB'), ('ली', 'VSUFF'), ('असल्या', 'VERB'), ('ने', 'ADP'), ('प्रेक्षक', 'PRON'), ('ांना', 'ADP'), ('ते', 'ADJ'), ('फार', 'PART'), ('आवडत', 'VERB'), ('आहे', 'AUX'), ('.', 'PUNCT')]

# %%
collected = {tag:dict() for tag in tags}
for n in range(len(data)):
    for idx, tag in enumerate(m.best_path(data[n])):
        collected[tag][data[n][idx]] = collected[tag].get(data[n][idx],0)+1 
    if n%1000==0:
        print(n)
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-130-70939c7c8be6> in <module>
#       1 collected = {tag:dict() for tag in tags}
#       2 for n in range(len(data)):
# ----> 3     for idx, tag in enumerate(m.best_path(data[n])):
#       4         collected[tag][data[n][idx]] = collected[tag].get(data[n][idx],0)+1
#       5     if n%1000==0:
#
# /usr/local/lib/python3.8/site-packages/nltk/tag/hmm.py in best_path(self, unlabeled_sequence)
#     384         """
#     385         unlabeled_sequence = self._transform(unlabeled_sequence)
# --> 386         return self._best_path(unlabeled_sequence)
#     387
#     388     def _best_path(self, unlabeled_sequence):
#
# /usr/local/lib/python3.8/site-packages/nltk/tag/hmm.py in _best_path(self, unlabeled_sequence)
#     396         B = -np.ones((T, N), np.int)
#     397
# --> 398         V[0] = P + O[:, S[unlabeled_sequence[0]]]
#     399         for t in range(1, T):
#     400             for j in range(N):
#
# IndexError: list index out of range

# %%
collected["NOUN"].intersection(collected["VERB"])
# Out:
# {'तिथ',
#  'मिळव',
#  'प्राधान्यक्रम',
#  'गुपित',
#  'ट',
#  'कऱ',
#  'डय़',
#  'इथ',
#  'समस्या',
#  'नियंत्रण',
#  'माज',
#  'घे',
#  'वठ',
#  'ठेवायच',
#  'गडबड',
#  'पाहणार',
#  'कामगिरी',
#  'डांबर',
#  'खेळ',
#  'निषेध',
#  'नाका',
#  'कांड',
#  'शिवसेने',
#  'लिंब',
#  'माह',
#  'द्याव',
#  '२०',
#  'मंदीर',
#  'मे',
#  'श्रेय',
#  'विश्रांती',
#  'मु',
#  'कलाकार',
#  'सिम',
#  'हाण',
#  'गार',
#  'पिशव्या',
#  'नसत',
#  'वर्तन',
#  'भाजी',
#  'दिख',
#  'सिद्धांत',
#  'द्विशतक',
#  'ख्यात',
#  'चोरी',
#  'हुकुम',
#  'तंत्र',
#  'पलट',
#  'उड',
#  'चुक',
#  'इस्रायल',
#  'दाळ',
#  'संपत्ती',
#  'धिक',
#  'कोर्टा',
#  'गैरसोय',
#  'मा',
#  'खटक',
#  'थक',
#  'ारस',
#  'टंचाई',
#  'थंडी',
#  'शिष्टाचार',
#  'पकड',
#  'वाच्य',
#  'मुलं',
#  'टप्प्या',
#  'भवितव्य',
#  'देव',
#  'उल्लंघन',
#  'कमाल',
#  'टन',
#  'उग',
#  'दुखापती',
#  'नाहीय',
#  'शक',
#  'चढ',
#  'निसटत',
#  'सुट',
#  'झट',
#  'भूष',
#  'बुडाले',
#  'दिप',
#  'जुळव',
#  'खटाटोप',
#  'क्ष',
#  'पुत',
#  'पाव',
#  'खेच',
#  'पांड',
#  'बोल',
#  'कक्षा',
#  'सुचव',
#  'संशोधक',
#  'व्यवस्थे',
#  'भांड',
#  'वास्तव',
#  'फेड',
#  'खच',
#  'दैव',
#  'ह्मण',
#  'क्षेत्र',
#  'जन्म',
#  'सम्राट',
#  'प्रेक्ष',
#  'ग्',
#  'छाप',
#  'बाध',
#  'स्टाईल',
#  'सोडवल',
#  'अमेरिके',
#  'सांगितल',
#  'पटल',
#  'जरुर',
#  'राहील',
#  'जप',
#  'वैभव',
#  'लढवणार',
#  'जास्त',
#  'एकजूट',
#  'राख',
#  'नसल्यामुळ',
#  'दृश्य',
#  'टेबल',
#  'आठवत',
#  'जाग',
#  'कोंड',
#  'नुस्',
#  'पाण्या',
#  'भिकार',
#  'ार्थ',
#  'संमेलन',
#  'बजावणार',
#  'साप',
#  'िव्ह',
#  'थाप',
#  'एकात्म',
#  'स्फोट',
#  'पेट',
#  'घटना',
#  'िम',
#  'स्माईल',
#  'रंग',
#  'मास',
#  'त्र',
#  'खाल्ल्यान',
#  'तळ',
#  'सुर',
#  'साठ',
#  'वैशिष्ट्य',
#  'लाभ',
#  'सार',
#  'धजावत',
#  'दिल',
#  'व्हाय',
#  'देणार',
#  'हलवाव',
#  'खुल',
#  'झपाट',
#  'पर्यटक',
#  'घडवत',
#  'फूट',
#  'मुर',
#  'राज्यकर्',
#  'श्र',
#  'निवार',
#  'प्रशासक',
#  'किंमती',
#  'झार',
#  'अप',
#  'स्थान',
#  'छेड',
#  'झळकणार',
#  'सापडत',
#  'तुम्हा',
#  'शिकव',
#  'भाजप',
#  'भिती',
#  'बैठकी',
#  'नासा',
#  'कश्यप',
#  'संपादन',
#  'भास',
#  'घाबर',
#  'चक्रा',
#  'लोट',
#  'सत्य',
#  'कोठडी',
#  'खव',
#  'फसव',
#  'वर्ष',
#  'बटन',
#  'पाऊल',
#  'एक्स',
#  'टिक',
#  'रित',
#  'कोर',
#  'मुक्त',
#  'संबध',
#  'अभिमान',
#  'वर्चस्व',
#  'चौकशी',
#  'घुम',
#  'नट',
#  'इंजिनियर',
#  'परिक्षे',
#  'मालमत्ता',
#  'सावली',
#  'विजे',
#  'जा',
#  'बस',
#  'कळव',
#  'बाळग',
#  'ण्या',
#  'म्ह',
#  'वाढवत',
#  'हम',
#  'उलगड',
#  'चाकू',
#  'धास्त',
#  'निरिक्षण',
#  'चुकीच',
#  'राह',
#  'सचिव',
#  'बॅ',
#  'येण्या',
#  'उत',
#  'कास',
#  'पट्टे',
#  'दुधा',
#  'ली',
#  'भानगड',
#  'मोदक',
#  'घोर',
#  'बोच',
#  'जेव',
#  'माख',
#  'सुधारणा',
#  'गोंधळ',
#  'वधार',
#  'पदावर',
#  'किमंत',
#  'ांश',
#  'गज',
#  'होऊन',
#  'अग्रलेख',
#  'ासह',
#  'बाण',
#  'देशभरात',
#  'कर्तव्य',
#  'फास',
#  'जर्न',
#  'कमजोर',
#  'म्हन',
#  'भाज',
#  'मृद',
#  'बारबाला',
#  'जमिनी',
#  'मंदा',
#  'मुरड',
#  'बजावत',
#  'पर्याय',
#  'टप',
#  'ढाक',
#  'समर्थन',
#  'पट',
#  'स्थानी',
#  'साम्य',
#  'राज्यसभे',
#  'सारव',
#  'कायद्या',
#  'आहात',
#  'हेतू',
#  'फुल्ल',
#  'आदर',
#  'बाह',
#  'कमव',
#  'सुरूवात',
#  'गाय',
#  'उजाड',
#  'ताप',
#  'बुड',
#  'दिसत',
#  'काऱण',
#  'ध्या',
#  'उघड',
#  'धु',
#  'उपाय',
#  'होणार',
#  'आख',
#  'अनुभव',
#  'मेळ',
#  'र',
#  'काम',
#  'संभाव्य',
#  'द्रविड',
#  'वणार',
#  'कोंडी',
#  'घोट',
#  'तक्रार',
#  'वात',
#  'हवेल',
#  'देहबोली',
#  'बाहेर',
#  'महोदय',
#  'संघ',
#  'शंकर',
#  'सावर',
#  'जंग',
#  'प्रक्रिये',
#  'समजूत',
#  'सहाय्य',
#  'सामान्य',
#  'डाग',
#  'चिरंजीव',
#  'स्त',
#  'वार्ताहर',
#  'सोबत',
#  'बाद',
#  'अजीज',
#  'सामोर',
#  'वाड्या',
#  'लप',
#  'उत्तेजक',
#  'अद',
#  'मुंबई',
#  'ग्रास',
#  'जळ',
#  'चिन्ह',
#  'शिंप',
#  'खैर',
#  'ताज',
#  'अधिवेशन',
#  'ांतर',
#  'चलना',
#  'जाण्या',
#  'गुळ',
#  'साधन',
#  'हल',
#  'यंत्रणे',
#  'क्षार',
#  'कुणा',
#  'हर',
#  'ऱ्या',
#  'बाट',
#  'जाहिराती',
#  'झर',
#  'वापर',
#  'धाव',
#  'खेळणार',
#  'देख',
#  'गोलाकार',
#  'हट्ट',
#  'हजर',
#  'अवघड',
#  'माल',
#  'पेर',
#  'अंगण',
#  'मुक',
#  'झेप',
#  'आवळ',
#  'समाजा',
#  'फेरी',
#  'आकारा',
#  'राहण्या',
#  'अधिक',
#  'ावर',
#  'पैलवान',
#  'गाढ',
#  'गण',
#  'मॅक्युलम',
#  'मांडव',
#  'भिर',
#  'पारितोषिक',
#  'पन्न',
#  'असणार',
#  'वेश',
#  'तफावत',
#  'हटाव',
#  'वाफ',
#  'निकड',
#  'परिणाम',
#  'युग',
#  'खोळंब',
#  'नियोजन',
#  'पोह',
#  'सत्ते',
#  'किलक',
#  '्रेज',
#  'मजे',
#  'लांब',
#  'गोठ',
#  'नोएडा',
#  'स',
#  'सतावत',
#  'जाळ',
#  'पूजा',
#  'लोकसभे',
#  'संदर्भ',
#  'बाव',
#  'बंदी',
#  'नेरळ',
#  'धारावी',
#  'भगवद्गी',
#  'गौरव',
#  'हिंदू',
#  'विक',
#  'नाराजी',
#  'असहमत',
#  'निसर्ग',
#  'आग',
#  'भूमी',
#  'रहस्य',
#  'एवढी',
#  'क्वाल',
#  'तरतूद',
#  'केशकर्तनालय',
#  'निवासस्थान',
#  'टिप',
#  'थंब',
#  'मटा',
#  'दुर्लक्ष',
#  'म्हटल',
#  'उट',
#  'डक',
#  'भुत',
#  'लकाक',
#  'सार्थक',
#  'रुपांतर',
#  'कथानक',
#  'बनव',
#  'सांगीतल',
#  'सुरवात',
#  'मत',
#  'दीपा',
#  'उभ',
#  'घालणार',
#  'जंतुनाशक',
#  'भंग',
#  'आखड',
#  'वेळे',
#  'अवकाश',
#  'रिंक',
#  'वकील',
#  'स्रोत',
#  'कल',
#  'नागरिकत्व',
#  'भान',
#  'दाखव',
#  'जुळ',
#  'साध',
#  'फेक',
#  'भटक',
#  'वेगळ',
#  'ऑफिस',
#  'मुख',
#  'निवड',
#  'व्यवस्थापन',
#  'वापरकर्',
#  'नम',
#  'मशिन',
#  'झिंग',
#  'मीडिया',
#  'सांग',
#  'मोडणार',
#  'ढवळ',
#  '्यात',
#  'पाळ',
#  'पिल्ल',
#  'आजार',
#  'म्हण',
#  'वाट',
#  'ओशाळ',
#  'कुलगुरू',
#  'हापस',
#  'भुल',
#  'साक्षर',
#  'घटक',
#  'ंक',
#  'कळप',
#  'जोग',
#  'फवार',
#  'पालन',
#  'माग',
#  'खांब',
#  'मुश्क',
#  'जाहीर',
#  'आपट',
#  'उमदेवार',
#  'सामना',
#  'द्वार',
#  'कळस',
#  'पंचक्रोशी',
#  'भावना',
#  'समृध्द',
#  'सौम्य',
#  'कुर',
#  'नांगर',
#  'रूढ',
#  'अक्कल',
#  'कडू',
#  'सेवे',
#  'एम',
#  'स्ट',
#  'सुट्टी',
#  'रिंग',
#  'पाप',
#  'गन',
#  'ति',
#  'विकार',
#  'तीर',
#  'कलंक',
#  'संधी',
#  'चिकट',
#  'सिध्द',
#  'ओढ',
#  'आदरातिथ्य',
#  'डिनर',
#  'मार्ग',
#  'रुळ',
#  'गढ',
#  'वाचक',
#  'ओ',
#  'राशी',
#  'लक्षण',
#  'तपास',
#  'प्रदेशाध्यक्ष',
#  'असण्या',
#  'याजपासी',
#  'पच',
#  'तळमळ',
#  'खात',
#  'आण',
#  'ओव्हन',
#  'विचारसरणी',
#  'ताण',
#  'मागासलेपण',
#  'घड',
#  'परवड',
#  '्य़',
#  'वस',
#  'दौऱ',
#  'फिरत',
#  'बागडण',
#  'लक्ष्य',
#  'लुक',
#  'युक्त',
#  'रेल',
#  'जथ',
#  'लपव',
#  'चर्चे',
#  'घेणार',
#  'पास',
#  'अभिनंदन',
#  'एचडीआयएल',
#  'आरंभ',
#  'कौशल्य',
#  'चिर',
#  'मात',
#  'धाडस',
#  'हीन',
#  'जवळ',
#  'बघणार',
#  'शो',
#  'पोकळ',
#  'लेख',
#  'पाह',
#  'शिव',
#  'सोस',
#  'शहरा',
#  'चुर',
#  'लौकिक',
#  'झुडुप',
#  'फड',
#  'वादी',
#  'मूल',
#  'श्रुत',
#  'रांगे',
#  'घो',
#  'चाळिशी',
#  'कस',
#  'बडव',
#  'प्रयत्न',
#  'समाप्त',
#  'शुध्द',
#  'कर्जदार',
#  'झोक',
#  'वाच',
#  'सावरकर',
#  'स्टुडिओ',
#  'योज',
#  'शोभ',
#  'राज्यभरात',
#  'गुहे',
#  'साय',
#  'ऑड',
#  'वातावरण',
#  'बोलाव',
#  'लेखक',
#  'संकेत',
#  'चव',
#  'मिसळ',
#  '़',
#  'गुंत',
#  'कृत',
#  'जनरल',
#  'भय',
#  'वेढ',
#  'प्रवेश',
#  'हानी',
#  'शेर',
#  'शर्यती',
#  'कंटाळ',
#  'प्रकल्पग्रस्त',
#  'मळ',
#  'पट्टी',
#  'मैत्रीण',
#  'दुप्पट',
#  'फ़ोड',
#  'विश्वास',
#  'काप',
#  'बंदोबस्त',
#  'सिनेमॅट',
#  'समजाव',
#  'सांभाळ',
#  'खाण्या',
#  'ध्वनि',
#  '्यंतर',
#  'आठवणी',
#  'पांग',
#  'आपाप',
#  'दाब',
#  'डोस',
#  'प्रतीक',
#  'झाड',
#  'पोखर',
#  'बदलेल',
#  'अग्रक्रम',
#  'नांद',
#  'गर्दी',
#  'लिख',
#  'बॉब',
#  'गुर',
#  'शिर',
#  'पडणार',
#  'काढ',
#  'सह',
#  'घबर',
#  'वाह',
#  'गा',
#  'खण',
#  'पाड',
#  'कारकीर्द',
#  'आचरण',
#  'ऑपरेट',
#  'वार',
#  'थाट',
#  'झोप',
#  'आच्छादन',
#  'गजा',
#  'खोद',
#  'चळवळ',
#  'पोशाख',
#  'गदारोळ',
#  'राजकारण',
#  'आ',
#  'द्वितीय',
#  'येत',
#  'वंजार',
#  'अफजल',
#  'संग्रह',
#  'भाकीत',
#  'दिल्ली',
#  'खास',
#  'अर्पण',
#  'संचालक',
#  'बाजु',
#  'पसंती',
#  'बाज',
#  'भूमिके',
#  'ठोक',
#  'जनक',
#  'सायना',
#  'हट',
#  'आम्हा',
#  'राजकारणा',
#  'वावग',
#  'रोपण',
#  'कारस्थान',
#  'प्रकल्प',
#  'जिर',
#  'गुंफ',
#  'ज्ञान',
#  'कृती',
#  'पटकाविल',
#  'दगड',
#  'घोळ',
#  'कारवाई',
#  'जात',
#  'न्याहाळ',
#  'पंक्ती',
#  'जमाव',
#  'साखळी',
#  'स्वप्न',
#  'श्रेष्ठ',
#  'आजमावत',
#  'डाॅक्टर',
#  'पदार्थ',
#  'ताकद',
#  'कोड',
#  'संताप',
#  'जिल्ह्या',
#  'लढ',
#  'प्रगती',
#  'साक्षीदार',
#  'नावे',
#  'संबंध',
#  'मुले',
#  'यंत्रणा',
#  'काकू',
#  'धडक',
#  'भ्यास',
#  'घास',
#  'बल',
#  'अधिनियम',
#  'उभार',
#  'ुर',
#  'कार्टून',
#  'सापडल',
#  'पेठे',
#  'कामा',
#  'वाढविणार',
#  'हलव',
#  'बेत',
#  'सोडवत',
#  'जाम',
#  'पुकार',
#  'य़',
#  'वर्ण',
#  'वाक',
#  'रोष',
#  '्म',
#  'आवडत',
#  'रोझ',
#  'आभाळ',
#  'जाण',
#  'गाळ',
#  'छळ',
#  'चालणार',
#  'लेखन',
#  'बागेत',
#  'सोल',
#  'घसर',
#  'मिच',
#  'जागा',
#  'ठरवत',
#  'मावळ',
#  'टाळ',
#  'विरोध',
#  'इंग्रजी',
#  'दिसणार',
#  'रॉक',
#  'मंडळ',
#  'धारक',
#  'बहुमत',
#  'शिकार',
#  'ठाण्या',
#  'अंदाज',
#  'पोळ',
#  'विक्री',
#  'अधिकार',
#  'उत्पन्न',
#  'वाक्य',
#  'चक',
#  'हवे',
#  'झोपडी',
#  'एन्ट्री',
#  'हुशार',
#  'हाल',
#  'ड्युटी',
#  'मजल्यावर',
#  'अड',
#  'पातळीवर',
#  'ट्रस्ट',
#  'सोने',
#  'वेध',
#  'चाचणी',
#  'रुम',
#  'संभ्रम',
#  'सर',
#  'संप',
#  'म्याव',
#  'फुट',
#  'अस्त',
#  'अध्याय',
#  'वर्णन',
#  'किस',
#  'व्याप',
#  'धारण',
#  'फुग',
#  'प्रणाली',
#  'मॅच',
#  'चमक',
#  'वाटायच',
#  'पुर',
#  'पडताळ',
#  'गंध',
#  'आजी',
#  'मिळाल',
#  'रुबाब',
#  'कुठ',
#  'नांव',
#  'धावणार',
#  'व्यसन',
#  'ओरड',
#  'टोपणनाव',
#  'गरजू',
#  'जम',
#  'विनव',
#  'ववि',
#  'संप्रदाय',
#  'पार्श्वभूमी',
#  'जण',
#  'मेहनत',
#  'बदल',
#  'ान्त',
#  'गजब',
#  'र्थ',
#  'भेद',
#  'गॅस',
#  'वगळ',
#  'अभ्यास',
#  'गरज',
#  'बिघाड',
#  'सावट',
#  'शिंग',
#  'भांडण',
#  'चालव',
#  'मिळालेल',
#  'धम्म',
#  'व्हय',
#  'मापन',
#  'गाड',
#  'सांध',
#  'खेड',
#  'वांध',
#  'घातक',
#  'अडचणी',
#  'उंची',
#  'धडपड',
#  'घरा',
#  'आवाहन',
#  'काश्मीर',
#  'हाताळ',
#  'पंतप्रधान',
#  'बाजू',
#  'स्वीकार',
#  'डिलिव्हरी',
#  'घाई',
#  'काक',
#  'समिती',
#  'बरोबर',
#  'आदिवासी',
#  'मूल्य',
#  'गमा',
#  'क्षम',
#  'शरीर',
#  'विहीर',
#  'रेट',
#  'बांध',
#  'आजमा',
#  'जनजागृती',
#  'बसव',
#  'वागणार',
#  'टाकणार',
#  'कॉरिडॉर',
#  'दहशत',
#  'प्रचार',
#  'टोम',
#  'दाखवणार',
#  'आकर्षण',
#  'मारणार',
#  'बहर',
#  'टय़',
#  'बहार',
#  'मरत',
#  'गडगड',
#  'स्वस्त',
#  'उद्देश',
#  'गारठ',
#  'सांगणार',
#  'उद्योग',
#  'हटक',
#  'मंडळा',
#  'रडव',
#  'भविक',
#  'मान',
#  'दाट',
#  'राहिल',
#  'खेळव',
#  'हेर',
#  'बक्षीस',
#  'सरस्वती',
#  'अपमान',
#  'यादी',
#  'म्हंटल',
#  'आग्रह',
#  'उत्प',
#  'बुडव',
#  'चक्र',
#  'फिरव',
#  'ांड',
#  'नरसंहार',
#  'ठरविणार',
#  'ओक',
#  'इतकी',
#  'हिसका',
#  'हटव',
#  'गुहा',
#  'उलट',
#  'शाळा',
#  'सिद्ध',
#  'जिकीर',
#  'परिचित',
#  'फोटोशूट',
#  'डोकाव',
#  'बचाव',
#  'रागा',
#  'उठ',
#  'उकड',
#  'किलो',
#  'ऐक',
#  'ठरणार',
#  'भडक',
#  'स्तर',
#  'रेघ',
#  'व्वा',
#  'बॉस',
#  'खळ',
#  'खूण',
#  'प्लॅन',
#  'झटक',
#  'विस्तार',
#  'सर्वनाम',
#  'मागणार',
#  'संत्र',
#  'कोकर',
#  'भुकटी',
#  'सोयी',
#  'समीकरण',
#  'भेट',
#  'स्थळ',
#  'फॅन',
#  'झाकण',
#  'येणार',
#  'स्फ',
#  'इमारती',
#  'दागि',
#  'रेंगाळ',
#  'टापू',
#  'त्याग',
#  'पक्क',
#  'पूर',
#  'सैतान',
#  'विसंगत',
#  'उपयोग',
#  'तोड',
#  'गर',
#  'पार्टी',
#  'समीक्षक',
#  'खिस',
#  'गळ',
#  'पुरव',
#  'फाट',
#  'संबोध',
#  'शपथ',
#  'जोड',
#  'जाव',
#  'थकव',
#  'सरण',
#  'धाड',
#  'देश',
#  'वाटे',
#  'सांगा',
#  'ठेवणार',
#  'लंब',
#  'भराव',
#  'वाज',
#  'उसळ',
#  'गम',
#  'सुनावणी',
#  'बोलव',
#  'लवचिक',
#  'मोज',
#  'अपंग',
#  'झुल',
#  'योगदान',
#  'तटबंदी',
#  'सुविधा',
#  'हितसंबंध',
#  ...}

# %%
collected["VERB"]
# Out:
# {'रक्तपेढ',
#  'तिथ',
#  'आरती',
#  'प्राधान्यक्रम',
#  'वल्या',
#  'कऱ',
#  'ठरविले',
#  'ट',
#  'चंद',
#  'इथ',
#  'समस्या',
#  'कला',
#  'वठ',
#  'ठेवायच',
#  'पाहणार',
#  'कामगिरी',
#  'खेळ',
#  'लब्घ',
#  'निषेध',
#  'माह',
#  'सिरियल',
#  'नाकार',
#  'आई',
#  'फिरक',
#  'हाण',
#  'गहिवर',
#  'शिंदे',
#  'कै',
#  'चोरी',
#  'करायच',
#  'खाल्ले',
#  'संपत्ती',
#  'धिक',
#  'सापडले',
#  'थक',
#  'ारस',
#  '्श्युए',
#  'थंडी',
#  'शाम्पू',
#  'उरले',
#  'न्सर',
#  'टन',
#  'ठाम',
#  'विरोधात',
#  'बरस',
#  'शक',
#  'निसटत',
#  'पू',
#  'दिप',
#  'ढिम्म',
#  'प्रेत',
#  'पाठवल्या',
#  'पांड',
#  'जीर्णोद्धार',
#  'राघवन',
#  'जार',
#  'ठाऊक',
#  'बरे',
#  'ग्',
#  'खसखस',
#  'परिपक्व',
#  'कपा',
#  'उकळ्या',
#  'रिफायनरी',
#  'चाल',
#  'उतर',
#  'नस',
#  'उठव',
#  'सांगितल',
#  'जरुर',
#  'बरोबरी',
#  'वैभव',
#  'विव्हळत',
#  'समवेत',
#  'पटका',
#  'विश्वसनीय',
#  '‘व्हाट३वर्ड',
#  'कोंड',
#  'विनंती',
#  'पाण्या',
#  'भिकार',
#  'ार्थ',
#  'नटूनथट',
#  'योग्य',
#  'रेणोसे',
#  'गॅल',
#  'एकात्म',
#  'वाईट',
#  'कुरकुरीत',
#  'ऑफर',
#  'झडती',
#  'ढु',
#  'निव',
#  'पुण्यतिथी',
#  'कडाड',
#  'तळ',
#  'स्तब्ध',
#  'साठ',
#  '‘डी',
#  'दिल',
#  'ळवाडी',
#  'ठा',
#  'आलि',
#  'झ',
#  'फूट',
#  'ज',
#  'भडकव',
#  'सॅलड',
#  'झार',
#  '्त्झ',
#  'बंगळूर',
#  'फायदा',
#  'नियोक्',
#  'देत',
#  'हुषार',
#  'उलथ',
#  'नासा',
#  'स्वाभाविक',
#  'MGM',
#  'भास',
#  'घाबर',
#  'पसरवि',
#  'सत्य',
#  '्यांसमोर',
#  'कोठडी',
#  'थर्मल',
#  'मज़बूत',
#  'पालट',
#  'पाऊल',
#  'बार्',
#  'एक्स',
#  'देऊ',
#  'रित',
#  'शाॅर्टफाॅर्म',
#  'वळवि',
#  'वर्चस्व',
#  'हाक',
#  'रेठरे',
#  'भारतात',
#  'नुरूपच',
#  'केर्बर',
#  'धिंड',
#  'द्योतक',
#  'विजे',
#  'शंका',
#  'चाकू',
#  'चुकीच',
#  'वर्षे',
#  'राह',
#  'हरप',
#  '१००',
#  'घालाय',
#  'फायदे',
#  'मजबूर',
#  'पट्टे',
#  'ं',
#  'नौका',
#  'लव्ह',
#  'बोच',
#  'असलेल्या',
#  'ठेवी',
#  'पदावर',
#  'त्साही',
#  'किमंत',
#  'जैविक',
#  'धुरी',
#  'खटल्या',
#  'कुठे',
#  'अभिनेत्री',
#  'भाज',
#  'एफ',
#  'चघळत',
#  'निलंबित',
#  'रणगाडास',
#  'आहात',
#  'देताय',
#  'यासारखी',
#  'समृद्ध',
#  'कॅप्टन',
#  'करावा',
#  'कमव',
#  'भयभीत',
#  'र्या',
#  'दिसत',
#  'काऱण',
#  'झाले',
#  'ावस्थेत',
#  'उडव',
#  'कलाकुसर',
#  'चरबी',
#  'झळकल्या',
#  'होणार',
#  'निर्मित',
#  'चोप्रा',
#  'करणाऱया',
#  'कशा',
#  'र',
#  'कुलुप',
#  'गळे',
#  'घोट',
#  'हातात',
#  'वात',
#  'ओझं',
#  'कोमट',
#  'देहबोली',
#  'नियंत्रित',
#  'महोदय',
#  'झडल',
#  'पत्कर',
#  'ऋवंगुणविशेषणविशि',
#  'अगोदर',
#  'होई',
#  'सहाय्य',
#  'उकल',
#  'कार्',
#  'स्त',
#  'अजीज',
#  'व्हेल',
#  'वाड्या',
#  'अद',
#  'जळ',
#  'थकबाकी',
#  'खूश',
#  'पी',
#  'कुणा',
#  'यांची',
#  'ऱ्या',
#  'जाहिराती',
#  'झर',
#  'अडकव',
#  'ऋतु',
#  'लाहौर',
#  'दुमड',
#  'एवढय़ा',
#  'हट्ट',
#  'ढासळ',
#  'माल',
#  'अपरिहार्य',
#  'आवळ',
#  'समाजा',
#  'अकाऊंट',
#  'अधिक',
#  'त्यात',
#  'सारखा',
#  'हापूस',
#  '48',
#  'ठाक',
#  'पन्न',
#  'केले',
#  'फॉरेन',
#  'हटाव',
#  'वाफ',
#  'पोह',
#  'मो',
#  'रोल',
#  'उल्लेख',
#  'कथा',
#  'ङ्गस',
#  'धारावी',
#  'प्राणी',
#  'लावले',
#  'शम',
#  'शाल्मली',
#  'ना',
#  'पड',
#  'भूमी',
#  'क्वाल',
#  'तरतूद',
#  'पुटपुटत',
#  'येई',
#  'भत्',
#  'इतक्या',
#  'म्हटल',
#  'पही',
#  'डक',
#  'भुत',
#  'झालेल्या',
#  'बनव',
#  'ठेऊ',
#  'निवर्त',
#  'गर्गशा',
#  'कळवि',
#  'परंपरे',
#  'निघ',
#  'राहा',
#  'वेळे',
#  'भान',
#  'शेतकरी',
#  'जिवंत',
#  'शाप',
#  'कोथरूड',
#  'चोंद',
#  'डोल्क',
#  'पाठविणार',
#  'वलं',
#  'पोषक',
#  'कार्यक्षम',
#  'मीडिया',
#  'जड',
#  'ढवळ',
#  '्यात',
#  'पाळ',
#  'केविल',
#  'फेम',
#  '्यांवर',
#  'आजार',
#  'म्हण',
#  'कुलगुरू',
#  'छावणी',
#  'अनिश्चित',
#  'अवतर',
#  'अनभिज्ञ',
#  'साक्षर',
#  'घटक',
#  'किपर',
#  'पं',
#  'मूर्ति',
#  'साधू',
#  'यामुळै',
#  'जाबाली',
#  'आपट',
#  'सजवि',
#  'उमदेवार',
#  'तुज',
#  'जाय',
#  'गवस',
#  'यचो',
#  'रूढ',
#  'निर्दिष्ट',
#  'भीषण',
#  'एम',
#  'डिक्टटर',
#  'स्ट',
#  'सुचवि',
#  'पाहुणे',
#  'गन',
#  'वितळ',
#  'विकार',
#  'झुंज',
#  'संधी',
#  'चिकट',
#  'वंशज',
#  'स्वरा',
#  'वाचक',
#  'प्रदेशाध्यक्ष',
#  'असण्या',
#  'वाली',
#  'मंदी',
#  'आव्',
#  'दुखावल्या',
#  'डिकम्पोजीबल',
#  'धडधड',
#  'तंबू',
#  'हवा',
#  'लक्ष्य',
#  'दिसाय',
#  'हस्तक',
#  'रेल',
#  'एचडीआयएल',
#  'सुरुंग',
#  'केली',
#  'सल्',
#  'जवळ',
#  'शिलेदार',
#  'ये',
#  'गेल्या',
#  'शो',
#  'चढव',
#  'सोस',
#  'बग',
#  'शहरा',
#  'े',
#  'फणफणले',
#  'वू',
#  'प्रमाणेच',
#  'फड',
#  'याकरता',
#  'झळकत',
#  ')',
#  'भले',
#  'फस',
#  'शुध्द',
#  'शु',
#  'स्टुडिओ',
#  'खपव',
#  'शोभ',
#  'करता',
#  'झाल्या',
#  'दळ',
#  'साय',
#  'पद्रवी',
#  'संधान',
#  'बोलाव',
#  '72',
#  'संकेत',
#  '़',
#  'जनरल',
#  'बक',
#  'प्रवेश',
#  'रोकड',
#  'भा',
#  'घालव',
#  'प्रकल्पग्रस्त',
#  'इष्ट',
#  'णास्रे',
#  'पट्टी',
#  'डो',
#  'गह',
#  'प्याय',
#  'सिनेमॅट',
#  'निदर्शक',
#  'काय',
#  'कृतज्ञ',
#  '्यंतर',
#  'आठवणी',
#  'आपाप',
#  'गुच्छ',
#  'बदलेल',
#  'भरड',
#  'नांद',
#  'पाज',
#  'गर्दी',
#  'पॅरे',
#  'अविचल',
#  'शिर',
#  'तंदुरुस्त',
#  'सुरळी',
#  'िल',
#  'पडणार',
#  'काढ',
#  'गृहात',
#  'नाही',
#  'तग',
#  'करंडक',
#  'हिंड',
#  'रद्ध',
#  'रिक्त',
#  'वार',
#  'थाट',
#  'ावत',
#  'मिती',
#  'वर्तवि',
#  'गौर',
#  'डिसेंबर',
#  'हवी',
#  'गदारोळ',
#  'द्वितीय',
#  'येत',
#  'वंजार',
#  'हुक',
#  'संग्रह',
#  'भाकीत',
#  'दडले',
#  'पूर्त',
#  'बाज',
#  'सायना',
#  'कम',
#  'राजकारणा',
#  'पाया',
#  'कारस्थान',
#  'ज्ञान',
#  'कृष्ठ',
#  'कृती',
#  'कारवाई',
#  'गल्लीबोळात',
#  'भिजले',
#  'भागात',
#  'गोळा',
#  'जमाव',
#  'स्वप्न',
#  'बचत',
#  'सोंड’',
#  'जुमान',
#  'डाॅक्टर',
#  'ंविरोधात',
#  'शकणार',
#  'लढ',
#  'प्रथा',
#  'प्रगती',
#  'नावे',
#  'ह',
#  'धडक',
#  'पेल',
#  'धुवा',
#  'भ्यास',
#  'बल',
#  'सत्ता',
#  'चूरगा',
#  'कामा',
#  'रुज',
#  'देऊळ',
#  'हलव',
#  'बेत',
#  'आत्मविश्वास',
#  'ल्प',
#  'य़',
#  'दचक',
#  '्म',
#  'जमा',
#  'करताना',
#  'आभाळ',
#  'आकर्षित',
#  'छळ',
#  'चालणार',
#  'घेतल्या',
#  'लेखन',
#  'लखलख',
#  'बागेत',
#  'क्वीन',
#  'चिड',
#  'घसर',
#  'मिच',
#  'जागा',
#  'टाळ',
#  'रॉक',
#  'लगाव',
#  'त्रुटी',
#  'अंदाज',
#  'माणूस',
#  'उत्पन्न',
#  'होस्ट',
#  'चक',
#  'घाब',
#  'होत',
#  'ड्युटी',
#  'पाद',
#  'फुट',
#  'अस्त',
#  'घेऊ',
#  'पिकव',
#  'घातले',
#  'तर',
#  'शिज',
#  'काटा',
#  'व्याप',
#  'धारण',
#  'डिरेक्टरी',
#  'शस्त्रक्रियेत',
#  'क्लाऊड',
#  'चमक',
#  'वाटायच',
#  'आठवडा',
#  'मॅच',
#  'विंचर',
#  'नगरी',
#  'आजी',
#  'जावे',
#  'झोंब',
#  'करणाऱ्या',
#  'गायब',
#  'जम',
#  'खदखद',
#  'पार्श्वभूमी',
#  'बदल',
#  'मर्यादित',
#  'दाद',
#  'र्थ',
#  'सजवले',
#  'ग्रस्त',
#  'वगळ',
#  'सिटि',
#  'गरज',
#  'पाठवा',
#  'नव्हे',
#  'सावट',
#  'शिंग',
#  'ांमधे',
#  'चालव',
#  'उत्स्फूर्त',
#  'मिळालेल',
#  'धम्म',
#  'व्हय',
#  'यामागे',
#  'विधि',
#  'संभा',
#  'वांध',
#  'घरा',
#  'वाढल्या',
#  'निल',
#  'पंतप्रधान',
#  'बाजू',
#  'आक्रमक',
#  'स्वीकार',
#  'पि',
#  'ब्ल',
#  'बरोबर',
#  'गमा',
#  'विहीर',
#  'कमतर',
#  'हल्ला',
#  'ठीक',
#  'सुटी',
#  '‘चैतन्यस्रोत’',
#  'होप्',
#  'बहर',
#  'हेलसिंकी',
#  'जिंदा',
#  'मरत',
#  'गडगड',
#  'द्या',
#  'टब',
#  'हरकत',
#  'गारठ',
#  'सबस्क्रायबर',
#  'शोषण',
#  'भविक',
#  'याकडे',
#  'वर्तक',
#  'हेर',
#  'घुस',
#  'मुलगी',
#  'बुडव',
#  'चेंगराचेंगरी',
#  'क्रिये',
#  'ांड',
#  'येणे',
#  'ठरविणार',
#  'ओक',
#  'मुद्दे',
#  'जागावाटपावर',
#  'युटिलिटी',
#  'जिकीर',
#  'फोटोशूट',
#  'बचाव',
#  'रागा',
#  'उठ',
#  'टीका',
#  'खाईन',
#  'ऐक',
#  'ंग',
#  'बॉस',
#  'ग्राऊंड',
#  'टेन',
#  'वाद्य',
#  'झटक',
#  'मागणार',
#  'सुझान',
#  'कोकर',
#  'लटका',
#  'अली',
#  'विविध',
#  'जाई',
#  'रेंगाळ',
#  'पडेल',
#  'पक्क',
#  'वा',
#  'आस',
#  'राजी',
#  'जातो',
#  'पुरव',
#  'घरी',
#  'शपथ',
#  'कसले',
#  'वाटे',
#  'घूम',
#  'हरव',
#  'शुकशुक',
#  'उमल',
#  'बिंदू',
#  'मितभाषी',
#  'नड',
#  'अल्',
#  'लवचिक',
#  'युजर',
#  'मोज',
#  'शिजव',
#  'नावीन्य',
#  'ंच',
#  'झुल',
#  'फ्रेंड',
#  'दौड',
#  'एप्रिल',
#  'तटबंदी',
#  'पूड',
#  'मोठी',
#  'माथ्यावर',
#  'भोक',
#  '‘क्रील’',
#  'ॅलिट',
#  'परिवार',
#  'अडकल्या',
#  'भोव',
#  'सुंदर',
#  'पालखीत',
#  'दर्शवि',
#  'दिवाळखोर',
#  'खून',
#  'लिपी',
#  'यासारखा',
#  'एवढे',
#  'माफ',
#  'फणस',
#  'गाठ',
#  'येणा',
#  'ीरसेल्वम',
#  'नोंदव',
#  'कल्पना',
#  'झगडत',
#  'कसोटी',
#  'फिर',
#  '१',
#  'अयोध्ये',
#  'सुच',
#  'शिथिल',
#  'चौकटी',
#  'रिपरिप',
#  'डॉ',
#  'झव',
#  'येते',
#  'ताब्यात',
#  'ॅ',
#  'आणणार',
#  'कार',
#  'दु',
#  'जगव',
#  'संचार',
#  'भिड',
#  'उदाहरण',
#  'कालावधी',
#  'अस्सल',
#  'वाचव',
#  'वर्दळ',
#  'क्लब',
#  'अवस्थे',
#  'पेक्षा',
#  'रत',
#  'उडाले',
#  'दुबई',
#  'डावल',
#  'चीन',
#  'सुज',
#  'हाे',
#  'ब्लॉक',
#  'तीत',
#  'देणघेण',
#  'करिष्',
#  'अंत',
#  'वैविध्य',
#  'खोल',
#  'मिळाल्या',
#  'फोर्ट',
#  'वाढदिवस',
#  'कुशल',
#  'शिक्षीका',
#  'भाव',
#  'संभव',
#  'दगा',
#  'मारल्या',
#  'सात',
#  'ओज',
#  'पशू',
#  'दाते',
#  'गेल',
#  'निघाल्या',
#  'सरक',
#  'होऊ',
#  'उपाध्यक्ष',
#  'थांबव',
#  'आघाडी',
#  'लायक',
#  'तत्पर',
#  'ओएनजीसी',
#  'सुक',
#  'पडत',
#  'पाठवले',
#  'वॉशिंग्टन',
#  'सल',
#  'जन्य',
#  'देणगी',
#  'झळकव',
#  'विलीनीकरण',
#  'सुलभ',
#  'मैत्री',
#  'चिन',
#  'मासे',
#  'देईन',
#  'ऊ',
#  'झिजव',
#  'मारण्या',
#  'गिळ',
#  'मक्तेदा',
#  'अट्टाहास',
#  'आवड',
#  'दावा',
#  'बंग',
#  'बघ',
#  'नजर',
#  'तुंब',
#  'धगधग',
#  'खोड',
#  'बाफ',
#  'सभा',
#  'रेखाट',
#  'महान',
#  'ग्राउंड',
#  'जाणव',
#  'पाटी',
#  'बाजारपेठ',
#  'सोयिस्कर',
#  'राबवि',
#  'आíथक',
#  'वेगळे',
#  'उचल',
#  'डय़',
#  'कोणा',
#  'ांसाठी',
#  'नियंत्रण',
#  'शक्ती',
#  'हिंमत',
#  'गडबड',
#  'वास',
#  'डांबर',
#  'ऑफिसर',
#  'करतो',
#  'नाका',
#  'पिळ',
#  'डोळा',
#  'करण्या',
#  'श्रेय',
#  'बायस',
#  'गॅलरी',
#  'फन',
#  'कोमेज',
#  'बाधा',
#  'थेट',
#  'घेतले',
#  'गार',
#  'रेडी',
#  'नसत',
#  'दिस',
#  'दिख',
#  'दुर्बीण',
#  'सत्रात',
#  'हुकुम',
#  'तंत्र',
#  'उड',
#  'चुक',
#  'इस्रायल',
#  'ट्यूषन',
#  'ब',
#  'खटक',
#  'टंचाई',
#  'खांद्यावर',
#  'कॅथेड्रल',
#  'पकड',
#  'पांघरु',
#  'नातलग',
#  'टप्प्या',
#  'घाला',
#  'देव',
#  'भवितव्य',
#  'उग',
#  'दुखापती',
#  'प्रतिष्ठान',
#  'चढ',
#  'सुट',
#  'झट',
#  'भूष',
#  'बुडाले',
#  'जुळव',
#  'खटाटोप',
#  'णार',
#  'खेच',
#  'उदासीन',
#  'थि',
#  'बोल',
#  'सुचव',
#  'ल्ब्ध',
#  'संस्था',
#  'किम',
#  'पाली',
#  'भांड',
#  'वास्तव',
#  'जन्म',
#  'नियमावली',
#  'वाटा',
#  'स्टाईल',
#  'दुनिये',
#  'जीवनात',
#  'सोडवल',
#  'ायची',
#  'ओलांड',
#  'झाप',
#  'राहील',
#  '्ल्',
#  'दंगल',
#  'बोरी',
#  'जास्त',
#  'अपिल',
#  'आणा',
#  'एटीएस',
#  'एकजूट',
#  'चर्वण',
#  'आठवत',
#  'एपीएमसी',
#  'ओरि',
#  'चांग',
#  'ठेप',
#  'गार्ड',
#  'बजावणार',
#  'हलके',
#  'श',
#  'ओळख',
#  'रंग',
#  'नावा',
#  '्शियल',
#  'संदीग्धता',
#  'पयोगी',
#  'पारदर्शी',
#  'तुझ्या',
#  'खाल्ल्यान',
#  'उक्सण',
#  'य्त्न',
#  'लुबाड',
#  'नावाजले',
#  'मश्गूल',
#  'वैशिष्ट्य',
#  'लाभ',
#  'इंडस्ट्री',
#  'ुर्',
#  'सर्किट',
#  'बिघडव',
#  'सुध्दा',
#  'सांगितल्या',
#  'पर्यटक',
#  'ed',
#  'प्रतीक्षा',
#  'घडवत',
#  'दरवळ',
#  'घेत',
#  'अप',
#  'स्थान',
#  'बाङेर',
#  'दडप',
#  'कर्',
#  '‘संशोधन’',
#  'दिसता',
#  'भिती',
#  'अंड्या',
#  'संपादन',
#  'झळका',
#  'फाटा',
#  'भयानक',
#  'प्या',
#  'ऱया',
#  'दोषी',
#  'वर्ष',
#  'कारक',
#  'झडत',
#  'असतं',
#  'सटल्नेस',
#  'फसले',
#  'लोळ',
#  'जा',
#  'बस',
#  'उमटव',
#  'सलोमी',
#  'बसल्या',
#  'श्रध्दा',
#  'ण्या',
#  'सुरुवात',
#  'वाढवत',
#  'गुंतागुंत',
#  'दूर',
#  'निरिक्षण',
#  'येण्या',
#  'उत',
#  'फिट',
#  'भानगड',
#  'श्रुंख',
#  'मोदक',
#  'घोर',
#  'कोलेस्ट्रॉल',
#  'दक्षता',
#  'वधार',
#  'होऊन',
#  'उजळ',
#  'करांनी',
#  'ासह',
#  'कां',
#  'माढ्यात',
#  'सळसळत',
#  'जर्न',
#  'पाँटिंग',
#  'शक्',
#  'बारबाला',
#  'मंदा',
#  'आत',
#  'ढाक',
#  'समर्थन',
#  'ाच्छ',
#  'अख',
#  'चॅनेल',
#  'कायद्या',
#  'हेतू',
#  'ळा',
#  'सबब',
#  'फुल्ल',
#  'गाय',
#  'बुड',
#  ...}

# %%
len(collected["ADJ"])
# Out:
# 2438

# %%
len(collected["NSUFF"])
# Out:
# 2239

# %%
collected["ADP"]
# Out:
# {'विरूद्ध',
#  '्सना',
#  'भरकटली',
#  'समस्या',
#  'मरिन',
#  'प्रकियेत',
#  'ंचं',
#  'खी',
#  'ऱ्यांनी',
#  'महिला',
#  'धिक',
#  'सेंट्रीफ्यूज',
#  'स्क',
#  'कचरा',
#  'काळी',
#  'टन',
#  'विरोधात',
#  'वरील',
#  'यांना',
#  'पदाच्या',
#  'ंच्या',
#  'क्विंटल',
#  'नेत्या',
#  'अभावी',
#  'दिवे',
#  'मुद्दा',
#  'टुणकन',
#  'भोवती',
#  'ीतील',
#  'घडामोडी',
#  'पुरते',
#  'रेल्वेस्थानक',
#  'साठी',
#  'समवेत',
#  'ंनाही',
#  'तारी',
#  'दाम',
#  'यांमुळे',
#  'उपचार',
#  'योग्य',
#  'गॅल',
#  '्स',
#  'लंडन',
#  'ल्यानंतर',
#  'वायला',
#  'भाडे',
#  'साठ',
#  'यावरील',
#  'ठा',
#  'डीहाईड',
#  'चिंकारा',
#  'फूट',
#  'काढण्',
#  'ज',
#  'ांशी',
#  'मधल्या',
#  '‘आरटीई’',
#  'ंचा',
#  'द्वारे',
#  'हाक',
#  'बंधु',
#  'भ्रृण',
#  'ाबद्दल',
#  'नुरूपच',
#  'कंडक्टर',
#  'विजे',
#  'ांतर्गत',
#  'S',
#  'वर्षे',
#  'राधना',
#  '्याने',
#  'ग्रेग',
#  'ं',
#  'ावरून',
#  'ापर्यंत',
#  'पदावर',
#  'गिरी',
#  'सविस्तर',
#  'अभिनेत्री',
#  'कॅप्टन',
#  'वेळेस',
#  'खिंड',
#  'ासारख्या',
#  'वसा',
#  'ंशी',
#  'रिअर',
#  'सफारी',
#  'महानगर',
#  'ांची',
#  'अगोदर',
#  'मतदार',
#  'वाल्या',
#  'वाड्या',
#  '31',
#  'ड्रीम',
#  'जिह्यात',
#  'पर्यंत',
#  'डेटा',
#  'ऑर्डर',
#  'व्यवस्थित',
#  '’चे',
#  'कुणा',
#  'यांची',
#  'शी',
#  'डेव्हलपमेंट',
#  'सक्रिय',
#  'पुरस्',
#  'एवढय़ा',
#  'प्रस्तुत',
#  '’ने',
#  'अकाऊंट',
#  '’च्या',
#  'ांचं',
#  'सारखा',
#  'बार',
#  '्गो’',
#  'बर्या',
#  'लीटर',
#  'ions',
#  'यांचे',
#  'लिया',
#  'ना',
#  'तूम',
#  'अखिल',
#  'भत्',
#  'इतक्या',
#  'ओकुनी',
#  'तासात',
#  'ब्रिज',
#  'नजीक',
#  'ाकडील',
#  'असोसिएट',
#  'बंधू',
#  '्ल',
#  'नु',
#  'मीडिया',
#  'विषयक',
#  'नरक',
#  'साक्षर',
#  'वी',
#  'खन्ना',
#  'शिवाय',
#  'कैपिटल',
#  'ासमोरील',
#  'विरुध्द',
#  'Mu',
#  'ंतर्गत',
#  'आठवा',
#  'गन',
#  '.9',
#  'वाचक',
#  'ओळखी',
#  'मुळं',
#  'ाशी',
#  'ांनंतर',
#  'रेल',
#  'ंवरील',
#  'जंक्शन',
#  'एमए',
#  'जवळ',
#  'ये',
#  'समर्थ',
#  'MMENT',
#  'निबंध',
#  'यांसाठी',
#  'ोणतीस',
#  'प्रमाणेच',
#  ')',
#  'भले',
#  'ापोटी',
#  'एकर',
#  'दळ',
#  'भौ',
#  'नाशक',
#  '‘जमान्',
#  'फॉर्म',
#  'सेवा',
#  'सेप',
#  'डो',
#  'शे',
#  'विलिनीकरण',
#  'निदर्शक',
#  'सेन्सॉर',
#  'पिणारच',
#  'कफल्लक',
#  'आठवणी',
#  'रपारपा',
#  'द्रुत',
#  'अखेर',
#  'गृहात',
#  'जयापज',
#  'ओळी',
#  'ावत',
#  'डिसेंबर',
#  'व्युत्',
#  'नाण्',
#  'डर',
#  'शाबूत',
#  'संग्रह',
#  'पार्टनर',
#  'ंद्र',
#  'ंमधे',
#  'काेर्ट',
#  'व्याप्त',
#  'ैद',
#  'कृती',
#  'भागात',
#  'गोळा',
#  'तही',
#  'खंडेरा',
#  'यांवर',
#  'संपल्या',
#  'ंविरोधात',
#  'लिना',
#  'ीसाठी',
#  'प्लास्टिक',
#  'कारं',
#  'वर्षात',
#  'कामा',
#  'चं',
#  'आत्मविश्वास',
#  'बागेत',
#  'बोअरवेल',
#  'विज्ञान',
#  'जागा',
#  '000',
#  'ंनंतर',
#  'ऑडिट',
#  'होस्ट',
#  'कॅफ़िन',
#  'नतंर',
#  'बाबतची',
#  'ेड',
#  'ैतिज',
#  'अंतर्गत',
#  'मॅच',
#  'आजी',
#  'टाईप',
#  'लॉजिस्ट',
#  'ंतर',
#  'ढे',
#  'सलमान',
#  'इथे',
#  'च्या',
#  'हंगाम',
#  'गायब',
#  'रन्स',
#  'मानांकन',
#  'दुपैषा',
#  '्सने',
#  'र्थ',
#  'ांमधे',
#  'वण्याचा',
#  'घरा',
#  'कांस्य',
#  'नुसार',
#  'ाचार्य',
#  'चा',
#  'जो',
#  'बरोबर',
#  'नमोनम',
#  'उष्',
#  'मैल',
#  'आड',
#  'यांत',
#  '्षोपीय',
#  'नं',
#  'कुटुंब',
#  'व्यापा',
#  'लिटर',
#  'भाद्रपद',
#  'शोषण',
#  '’ची',
#  'वासीयांना',
#  'पदाची',
#  'त',
#  'वून',
#  'ांद्वारे',
#  'म्हणून',
#  'रोजंदारी',
#  'नव',
#  'ांमधून',
#  'मेहंदी',
#  'बचाव',
#  'रागा',
#  'नख',
#  'करवी',
#  'यांचं',
#  'वाडीतील',
#  'तरुण',
#  'राजी',
#  'वरुन',
#  'घरी',
#  '्यांमध्ये',
#  'लं',
#  'विधानसभा',
#  'वाटे',
#  'गार्डन',
#  'ंतून',
#  'शाही',
#  'क्लायंट',
#  'ंच',
#  'ेट',
#  'देशद्रोह',
#  'बसेस',
#  'शैक्षणीक',
#  'भोक',
#  'ंस',
#  '२३',
#  'पटीने',
#  'आंबे',
#  'टेलि',
#  'मधील',
#  'दलघफू',
#  'विश्वचषक',
#  'पासूनच',
#  'मण',
#  'हसू',
#  'पूर्व',
#  'क्नॉक',
#  'प्लॅटफॉर्म',
#  'फराळ',
#  'राई',
#  'ंसोबत',
#  'ांकडून',
#  'येते',
#  'बॉलिवूड',
#  'ंबाबत',
#  'ओपन',
#  'क्लब',
#  'पेक्षा',
#  'गियर',
#  'ब्लॉक',
#  'खोर',
#  '००',
#  'जुलै',
#  'कन्',
#  'ला',
#  'दगा',
#  'फोर',
#  'दाते',
#  'दुमदु',
#  'सुड',
#  'कदापी',
#  'बागा',
#  'कैफ',
#  'कॅमेर्',
#  'थॉमस',
#  'देणगी',
#  'नंतर',
#  'लक्ष्मी',
#  'थोर',
#  'भगिनी',
#  'सभा',
#  'डझन',
#  'जोश',
#  'बहिणी',
#  'आद',
#  'सद्',
#  'ांसाठी',
#  'नियंत्रण',
#  'कोणा',
#  'ांदरम्यान',
#  'गॅलरी',
#  'फीज',
#  '’मधून',
#  'थेट',
#  'वंदना',
#  'बोटी',
#  'वर',
#  '’चा',
#  'िटोमा',
#  'रूप',
#  '/',
#  'तिघी',
#  'डिंग',
#  '्याचा',
#  'ाचे',
#  'फॅरेनहाइट',
#  'उदासीन',
#  'मित्र',
#  'शहर',
#  'मोफत',
#  'ोपयोगी',
#  'ायची',
#  'नेतेपद',
#  'सिल',
#  'दलघमी',
#  'ंबरोबरच',
#  'प्रदेश',
#  'फाय',
#  'स्त्री',
#  'युआरएल',
#  'हा',
#  'पाटर्य़ा',
#  'ंसाठी',
#  'सर्च',
#  'जसे',
#  'QIA',
#  'मधली',
#  'पाजार',
#  'सुध्दा',
#  'वं',
#  'मोबाइल',
#  'कनेरि',
#  'ायझर',
#  'मधोमध',
#  'स्थान',
#  'समि',
#  'कुठल्या',
#  'फाटा',
#  'पैसे',
#  'CBT',
#  '04',
#  'प्या',
#  'वर्ष',
#  'अतिक्रमण',
#  'दोन',
#  'दिव्यांग',
#  'dis',
#  'माउली',
#  'ांबरोबर',
#  '%',
#  'हवाल',
#  'सोबतच',
#  'ांपेक्षा',
#  'जा',
#  'ंब',
#  'ांवरून',
#  'बसल्या',
#  'ky',
#  'क्यू',
#  'रद्द',
#  'वटि',
#  'काही',
#  'घोर',
#  'अखेरीस',
#  'सेविका',
#  'परीक्षण',
#  'हत्या',
#  'शिष्य',
#  'होऊन',
#  'घोटाळेबाज',
#  'करांनी',
#  'ग्रॅम',
#  'बॉरेन',
#  'ापैकी',
#  'टीएमसी',
#  'रशियन',
#  'लीग',
#  'शरद',
#  'चहल',
#  'बा',
#  'पोलिओ',
#  'जाणार',
#  'पाळणा',
#  'वष्रे',
#  'प्रेम',
#  'ंजर',
#  'कौन्सिल',
#  'आणि',
#  'ेर',
#  'बद्दल',
#  'ातून',
#  'उत्तेजक',
#  'सीरिज',
#  'द्रमुक',
#  'हरय्वना',
#  'ेतून',
#  'भाट',
#  'मते',
#  'शरण',
#  'एवढा',
#  'पळाल',
#  'अर्ज',
#  'सीएम',
#  'ंती',
#  'आतंकवाद',
#  '70',
#  'कोष',
#  'चे',
#  'पायी',
#  'चौकात',
#  'डाटा',
#  'डोप',
#  'िस',
#  'फक्त',
#  'प्रती',
#  'स',
#  'ायला',
#  'ायिक',
#  'पॅरिस',
#  'कॉर्नर',
#  'कडून',
#  'जिवाणू',
#  'तिक',
#  'गणिक',
#  'वरून',
#  'त्मक',
#  'र्सनी',
#  'ांसोबत',
#  'पीएचडी',
#  'ंमधून',
#  'ामुळे',
#  '12',
#  'तंतुवाद्य',
#  '्हा',
#  'करून',
#  'ल्यास',
#  'व्दारे',
#  'युद्ध',
#  'मशिन',
#  'बाबतीत',
#  'जी',
#  'मय',
#  'ंतील',
#  'व्यावसाय',
#  '्सनी',
#  'ासोबत',
#  'आंतर',
#  'समयी',
#  'भावना',
#  'शाक्त',
#  'जगन्नाथ',
#  'लॉबी',
#  'लाही',
#  'पोटी',
#  'जवळील',
#  'प्रणित',
#  'य़ात',
#  'वाटप',
#  'तिहासा',
#  'सांताक्लॉज',
#  'ल',
#  'पाच',
#  '्यातील',
#  'ाचा',
#  'बघितल्',
#  'करीता',
#  'ंना',
#  'मिळेना',
#  'जप्त',
#  'समाप्त',
#  'रेडिओ',
#  'डीएस',
#  'नोव्हेंबर',
#  'लाख',
#  'one',
#  '150',
#  'बानो',
#  'बँक',
#  'फटक',
#  'ांचे',
#  'विसीं',
#  'कडील',
#  'िद्र्य',
#  'गोर',
#  'कर्म',
#  'कडुन',
#  'ंपैकी',
#  'मधून',
#  'सूप',
#  'णा',
#  'ोधडीस',
#  'यांच्या',
#  'मागचं',
#  'पीटीआय',
#  'ऑपरेट',
#  '्रीक',
#  'मनी',
#  '१४',
#  'खास',
#  'लॉजी',
#  'समोरील',
#  'विरुद्ध',
#  'पुरतं',
#  '्सच्या',
#  'रचना',
#  'किलोमीटर',
#  'बाळ',
#  'थँक',
#  'खडे',
#  'एमएम',
#  'कडम्े',
#  'नूल',
#  'पगार',
#  'मूठ',
#  'मुले',
#  'व्',
#  'ऑफ',
#  'सहित',
#  'ंपासून',
#  'श्वर',
#  'ेकडील',
#  'मल्टी',
#  'कडे',
#  'हरा',
#  'सीमा',
#  'धारक',
#  'घरात',
#  'नोकर',
#  'कॅलरी',
#  'फ्र्ण्ट',
#  'लस',
#  'हुशार',
#  'जिंकणार',
#  'डिस्',
#  'ानंतर',
#  '़्यांची',
#  'पदासाठी',
#  'उत्तीर्ण',
#  'नफा',
#  '्',
#  'ांवर',
#  'आयपी',
#  'मंडळी',
#  'तेची',
#  'कमिटी',
#  'ताठ',
#  'उपक्रम',
#  'दापूर',
#  'राणा',
#  'भरल्या',
#  'रिष्टर',
#  'सरकार',
#  'कले',
#  'गरजू',
#  'पाशी',
#  'आमदार',
#  'गॅस',
#  'मधलं',
#  'बडे',
#  'यशस्वी',
#  'लाकूड',
#  'वारी',
#  '६०',
#  'बाजूने',
#  'ूड',
#  'ाला',
#  'ऐवजी',
#  'डिलिव्हरी',
#  'जीत',
#  'पाठी',
#  'आपलं',
#  'वाहन',
#  'वसाहत',
#  'स्मार्टफोन',
#  '–',
#  'ठिकाणी',
#  'ासाठी',
#  'सॅन',
#  'वाजता',
#  'मेगावॅट',
#  'पलिकडे',
#  'संदर्भातील',
#  'टूथ',
#  'रंगी',
#  'ंवर',
#  'लाच',
#  'मान',
#  'आर्मी',
#  'ँप',
#  'पहायला',
#  'वादन',
#  'बक्षीस',
#  'ंमागे',
#  'ंविषयी',
#  'शिलालेख',
#  'प्राय',
#  'खालून',
#  'द्रव्य',
#  'तील',
#  'ांपैकी',
#  'भेट',
#  'ंगण',
#  'इमारती',
#  'मुठ',
#  'गोष्टी',
#  'मंत्र्यांना',
#  'ीच्या',
#  'नाविन्य',
#  'ऱयांनी',
#  'र्य',
#  'ब्लू',
#  'रोंडगे',
#  'सुविधा',
#  'कोपऱ्',
#  'सिः—',
#  'खूप',
#  '्याच्या',
#  'लॉबेरा',
#  'पिढी',
#  'इंधन',
#  'टक्के',
#  'पुरती',
#  'ीमुळे',
#  'ंसह',
#  'मोड',
#  '‘गुलाम’',
#  'िद्ग्य',
#  '्मोठ्ठे',
#  'प्रश्नी',
#  'ांचा',
#  'ंरनी',
#  'ांच्या',
#  'विवाहित',
#  'दिश',
#  'रोड',
#  'माला',
#  'वॉट',
#  'ामध्ये',
#  'शॅडो',
#  'ंवरुन',
#  'बहुल',
#  'याने',
#  'असे',
#  'बिन',
#  'जानेवारी',
#  'रूब्बल',
#  'ंनो',
#  'प्रकरणात',
#  'सामुहीक',
#  'मधू',
#  'वर्षी',
#  '्टॉलीक',
#  'येथील',
#  'स्थापण्',
#  'प्रणीत',
#  'रेग्युलेटर',
#  'ट्रम्प',
#  '्यांची',
#  'रिया',
#  'मूग',
#  'असताना',
#  'यासह',
#  '्ती',
#  'यां',
#  'मलिक',
#  'ाने',
#  'प्रसंगी',
#  '25',
#  'दरम्यान',
#  'ांनी',
#  'नारे',
#  'युरो',
#  'अद्याप',
#  'ग्टन',
#  'सीता',
#  'ध्यक्ष',
#  'Mon',
#  'लढवाव्या',
#  'निटिजन्स्नी',
#  'जनता',
#  '‘जीएसटी’',
#  'वासी',
#  'काकती',
#  'बेरीज',
#  'न्वये',
#  'पर्यन्त',
#  'का',
#  'नीच',
#  'ांस',
#  'व्हेरिफिकेशन',
#  'एसए',
#  'करंदी',
#  'यांबाबत',
#  'सकट',
#  'ामधून',
#  'यांनी',
#  'पूर्वीच',
#  '’',
#  'तुन',
#  'थिलेनि',
#  'जगता',
#  'जिह्',
#  'इस्',
#  'सर्वो',
#  '°',
#  'दशलक्ष',
#  'यानुसार',
#  'अजुन',
#  'इन्स्टि',
#  'मीटर',
#  'ठिक',
#  'अजम',
#  'परिक्षे',
#  'मालमत्ता',
#  'ांवरील',
#  'वतील',
#  'विरूध्द',
#  'ाबरोबर',
#  'विकृती',
#  'पंक्ति',
#  'कटि',
#  'होतात',
#  'मंतर',
#  'सुर्य',
#  'सख्ख्या',
#  'अॅम',
#  'पट',
#  '्याचे',
#  'एनिग्मा',
#  'वारंवार',
#  'ांमध्ये',
#  'क्षेप',
#  'ावश्यक',
#  'पब्लिक',
#  'मुळ',
#  '15',
#  'तालुका',
#  'शत्रू',
#  'साईबाबा',
#  'बिबटे',
#  'ाकडून',
#  'बाहेर',
#  'सारस्वत',
#  'पैकी',
#  'एन',
#  'गावात',
#  'रेझिस्टन्स',
#  'ानेच',
#  ',',
#  'ावरील',
#  'हिन',
#  'यांसह',
#  'जिया',
#  'ाबरोबरच',
#  'णारी',
#  'धारकांना',
#  'वस्तू',
#  'अवघड',
#  'ांसह',
#  'मीन',
#  'साहेब',
#  'गाणी',
#  'ांमधील',
#  'येथे',
#  'औद्योगिक',
#  'मुळेच',
#  '्यांसाठी',
#  'उशीरा',
#  'दौऱ्',
#  'भाज्या',
#  'कु',
#  'गाण्',
#  'तळप',
#  '=',
#  'नवा',
#  'थियोफीलस',
#  'परि',
#  'ंमध्ये',
#  'वरही',
#  'आझाद',
#  'सनई',
#  'हार',
#  'िमल',
#  'मुळे',
#  '्लर',
#  'ांपुढे',
#  'पुरता',
#  'पासून',
#  'शाखा',
#  'ण्याचे',
#  'प्रदुषण',
#  'ीक',
#  'मजल्',
#  'दिनी',
#  'कापड',
#  'रसिक',
#  'ाखाली',
#  'बरोबरच',
#  'शॉ',
#  'इतका',
#  'प्लॉट',
#  'मेगन',
#  'फिती',
#  'मटका',
#  'पदवी',
#  'पलीकडे',
#  'ऋतू',
#  'डिश',
#  'पास',
#  'गड',
#  'न्यास',
#  'पुढील',
#  'सभेत',
#  'वेळी',
#  'शिव',
#  'लसूण',
#  'बाबत',
#  'अधीच',
#  'मनमानी',
#  'संहिता',
#  'वली',
#  'सूचना',
#  'मागील',
#  'प्राईम',
#  'ातल्या',
#  'ांकडे',
#  'कॉन',
#  'नारळ',
#  'कलादर्पण',
#  'खोल्या',
#  'oats',
#  'में',
#  'ाकडे',
#  'सोडविण्',
#  'ांमुळे',
#  'कंडिशन्स',
#  'ापुढे',
#  'प्लस',
#  'त्रि',
#  'सेंटर',
#  'दाब',
#  'ंकडून',
#  'हून',
#  'ण्याचा',
#  'तर्फे',
#  'प्रादेशिक',
#  'माíगका',
#  'घरे',
#  'जाती',
#  '्सची',
#  'ामागे',
#  'ास',
#  'हट',
#  '‘अवे’',
#  'खालील',
#  'सरंजाम',
#  'अध्य',
#  'परवानग्या',
#  'ने',
#  'चि',
#  'निंब',
#  'समालोचक',
#  'सारखी',
#  'पुर्वी',
#  'वाणी',
#  'ंत',
#  '्यांचा',
#  'महिना',
#  'घेऊन',
#  'वरळी',
#  'वेळा',
#  'तले',
#  'चालक',
#  'ंमधील',
#  'ांहून',
#  'ोदीन',
#  'प्रविष्ट',
#  '10',
#  'कृत्रिम',
#  'पटांगण',
#  'पातळीवर',
#  'ीची',
#  'क्यु',
#  'बांधकाम',
#  'ग्राहक',
#  'प्र',
#  'ळी',
#  'विसीहि',
#  'उल्लघन',
#  'स्तरीय',
#  '्यांना',
#  'एमएस',
#  'धाम',
#  'मेरी',
#  'रॉयल्स',
#  'जिल्ह',
#  'मापन',
#  'गाड',
#  'यदृच्छा',
#  'पर्रिकर',
#  'फर',
#  'यानी',
#  'पसून',
#  'वल्',
#  'जागे',
#  'चषक',
#  'अमित',
#  'मागची',
#  'कब्जा',
#  'गुरूवार',
#  'ाप',
#  'यान',
#  'बळी',
#  'स़ृ',
#  'प्रकारे',
#  '्यांकडून',
#  'कप',
#  'स्थळी',
#  'गाठी',
#  'इतकी',
#  '.81',
#  'उलट',
#  'देखील',
#  'ल्या',
#  'खिल्लार',
#  '26',
#  'ती',
#  ...}

# %%
collected["VSUFF"]
# Out:
# {'199',
#  '29.54103',
#  '3',
#  '33',
#  '45',
#  '82',
#  'MIG',
#  'SPG',
#  'V',
#  'ंगडे',
#  'ंच',
#  'ंट',
#  'ंड',
#  'ंती',
#  'ंदर',
#  'ंब',
#  'अ',
#  'अंतिम',
#  'अंबानी',
#  'अचंबित',
#  'अच्छे',
#  'अजेंडा',
#  'अजो',
#  'अटक',
#  'अडचणी',
#  'अत्य',
#  'अधिक',
#  'अफजल',
#  'अभि',
#  'अभिमान',
#  'अभ्यागत',
#  'अरियाना',
#  'अवश्य',
#  'असता',
#  'अस्पृश्य',
#  'आकर्षण',
#  'आकारणी',
#  'आगमन',
#  'आठवडा',
#  'आधुनिक',
#  'आमंत्रित',
#  'आवश्यक',
#  'आह',
#  'इंक',
#  'इख्तियार',
#  'इनकम',
#  'इयत्ता',
#  'इस',
#  'ई',
#  'ईल',
#  'उ',
#  'उजनी',
#  'उतार',
#  'उन',
#  'उपलब्ध',
#  'उस्मानाबाद',
#  'ऊतक',
#  'ऍट',
#  'एंजट',
#  'एआय',
#  'एनपीड',
#  'एवढी',
#  'ऑपर',
#  'औष्णिक',
#  'कक्ष',
#  'कत',
#  'करणाऱया',
#  'करताना',
#  'करमणूक',
#  'करी',
#  'करुन',
#  'करू',
#  'करून',
#  'कर्जमाफी',
#  'कर्मी',
#  'कसा',
#  'कसे',
#  'कस्टमर',
#  'कांबळी',
#  'काऊंट',
#  'कागद',
#  'किसान',
#  'कुटे',
#  'कुवत',
#  'कृति',
#  'कॅलिफोर्निया',
#  'केळकर',
#  'कैंटीन',
#  'कॉल',
#  'क्या',
#  'क्व',
#  'खाना',
#  'खिल',
#  'खिलाफ',
#  'खुर्द',
#  'खेड',
#  'गच्च',
#  'गढ',
#  'गर्द',
#  'गांधी',
#  'गाड',
#  'गाडगीळ',
#  'गामी',
#  'गार्ड',
#  'गीते',
#  'गूड',
#  'गेला',
#  'गोंगाट',
#  'गोंधळ',
#  'गोळी',
#  'गोळीबार',
#  'ग्रह',
#  'ग्राउंड',
#  'ग्रामपंचायत',
#  'घटस्फोट',
#  'घम',
#  'घात',
#  'ङ्गट्रान्सपोर्टशन',
#  'चक',
#  'चमत्कार',
#  'चव्हाण',
#  'चिठ',
#  'चिठ्ठी',
#  'चेंडू',
#  'छाती',
#  'छात्र',
#  'जम',
#  'जमा',
#  'जरा',
#  'जलतरण',
#  'जळगाव',
#  'जस्ट',
#  'जाए',
#  'जुन्या',
#  'जोगा',
#  'जोगी',
#  'झगडे',
#  'झळकत',
#  'झा',
#  'झाप',
#  'झोप',
#  'टक्कर',
#  'टक्केवारी',
#  'टाइल',
#  'टिकव',
#  'टिप',
#  'टें',
#  'टैक्सी',
#  'टोन',
#  'टोमाम्',
#  'ट्राय',
#  'ट्रोल',
#  'ठ',
#  'ठाऊक',
#  'ठाक',
#  'ठिबक',
#  'ठ्',
#  'ड',
#  'डणे',
#  'डर',
#  'डिस्क',
#  'डू',
#  'डोण',
#  'ड्या',
#  'णं',
#  'णाÚया',
#  'णार',
#  'णाऱ्या',
#  'णारा',
#  'णार्या',
#  'णी',
#  'णीची',
#  'णे',
#  'ण्',
#  'ण्या',
#  'ण्याकरिता',
#  'ण्याचा',
#  'ण्याची',
#  'ण्यात',
#  'ण्यावर',
#  'ण्यास',
#  'ण्यासाठी',
#  'त',
#  'तं',
#  'तंय',
#  'तणाव',
#  'तपास',
#  'तहसील',
#  'तही',
#  'ता',
#  'ताठ',
#  'ताण',
#  'तात',
#  'ताना',
#  'ताय',
#  'तितकी',
#  'तितक्या',
#  'तिल',
#  'ती',
#  'तीक्ष्ण',
#  'तीर',
#  'तु',
#  'तुका',
#  'तेचा',
#  'तेचे',
#  'तेच्या',
#  'तेत',
#  'तेने',
#  'तेमुळे',
#  'तेय',
#  'तेवढं',
#  'तेवढे',
#  'तेसाठी',
#  'तो',
#  'तोय',
#  'तौर',
#  'त्तर',
#  'त्ये',
#  'दबा',
#  'दय',
#  'दल',
#  'दहा',
#  'दाद',
#  'दाम्पत्य',
#  'दिनक्रम',
#  'दे',
#  'देणार',
#  'देशपांडे',
#  'दैनिक',
#  'दोषी',
#  'द्यायला',
#  'द्रोही',
#  'धन्वं',
#  'धाक',
#  'धारा',
#  'ध्येय',
#  'नमन',
#  'नागपूर',
#  'नामा',
#  'नायर',
#  'नार',
#  'नाल',
#  'नाश',
#  'नाहि',
#  'नियंत्रित',
#  'निवांत',
#  'नीय',
#  'नेरुर',
#  'न्ट',
#  'न्यास',
#  'पचन',
#  'पटी',
#  'पडणार',
#  'पडताळणी',
#  'पडदा',
#  'पडून',
#  'पति',
#  'परिश्रम',
#  'पर्यत',
#  'पर्यन्त',
#  'पही',
#  'पाचर',
#  'पाटे',
#  'पानटपरी',
#  'पास',
#  'पाहणार',
#  'पिंड',
#  'पित',
#  'पिन',
#  'पुं',
#  'पुर',
#  'पू',
#  'पॅकेज',
#  'पैसा',
#  'पॉ',
#  'पोळ',
#  'पोषक',
#  'पोह',
#  'प्रतिनिधी',
#  'प्रयोग',
#  'प्रसाद',
#  'प्रसिद्ध',
#  'प्रामुख्याने',
#  'प्रिंट',
#  'प्रिया',
#  'प्रोत्साहन',
#  'फलक',
#  'फाड',
#  'फिल्म',
#  'फैंस',
#  'फॉलोअर्स',
#  'फ्लॉवर',
#  'बँग',
#  'बंदी',
#  'बंधन',
#  'बचत',
#  'बच्',
#  'बच्चन',
#  'बडबड',
#  'बाज',
#  'बाद',
#  'बाबत',
#  'बाबी',
#  'बालरोग',
#  'बीएमसी',
#  'बुज',
#  'बूज',
#  'बेल्ट',
#  'बै',
#  'भंडा',
#  'भगवंत',
#  'भा',
#  'भारतात',
#  'भावे',
#  'भाषेत',
#  'भास',
#  'भिके',
#  'भीति',
#  'भुंकत',
#  'भूषण',
#  'भोक',
#  'भोपळे',
#  'मंदा',
#  'मकर',
#  'मजे',
#  'मतकरी',
#  'मतदान',
#  'मतपेढी',
#  'मद्देनजर',
#  'मधु',
#  'मध्यरात्री',
#  'मन्',
#  'मर्डर',
#  'मशरूम',
#  'मशिन',
#  'महाग',
#  'मांजरे',
#  'माझ',
#  'माट',
#  'माद्रिद',
#  'मावळ',
#  'मासळी',
#  'मुक्त',
#  'मुचलक्यावर',
#  'मुल्ला',
#  'मृतदेह',
#  'मेल',
#  'मोंगलासंन्निध',
#  'मोजणी',
#  'मोडी',
#  'मोरे',
#  'मौसम',
#  'य',
#  'यचंय',
#  'यचा',
#  'यलाच',
#  'याचं',
#  'याची',
#  'यामागे',
#  'यासंबंधी',
#  'यासारखी',
#  'युगात',
#  'येई',
#  'येत',
#  'योग्य',
#  'रमा',
#  'रल',
#  'रला',
#  'रवि',
#  'रहदारी',
#  'ऱया',
#  'राज्यभरात',
#  'राधना',
#  'रानी',
#  'राबल्य',
#  'राव',
#  'रावण',
#  'राहू',
#  'रिज',
#  'रिटी',
#  'री',
#  'रीती',
#  'रूढ',
#  'रॅकेट',
#  'रेखा',
#  'रेड',
#  'रेषा',
#  'रोह',
#  'रोहित',
#  'र्ग',
#  'र्ट',
#  'र्णिय',
#  'र्धा',
#  'ल',
#  'लंच',
#  'लंय',
#  'लक्',
#  'लय',
#  'लहान',
#  'ला',
#  'लाच',
#  'लाड',
#  'लाय',
#  'लायक',
#  'लि',
#  'लिंग',
#  'लिए',
#  'ली',
#  'लू',
#  'ले',
#  'लेख',
#  'लेन्स',
#  'लेलं',
#  'लेला',
#  'लो',
#  'लौकीक',
#  'ल्यावर',
#  'ळली',
#  'ळावे',
#  'वटा',
#  'वठणीवर',
#  'वड',
#  'वडा',
#  'वडेकर',
#  'वणं',
#  'वणार',
#  'वणारी',
#  'वणूक',
#  'वण्याचा',
#  'वत',
#  'वता',
#  'वयाचे',
#  'वयास',
#  'वरुन',
#  'वलं',
#  'वलकर',
#  'वली',
#  'वलेले',
#  'वल्या',
#  'वसुली',
#  'वस्ती',
#  'वाडा',
#  'वाढवत',
#  'वाढवित',
#  'वाणा',
#  'वादन',
#  'वापळवी',
#  'वाळ',
#  'वावे',
#  'वास',
#  'वासना',
#  'वासा',
#  'वाहनतळ',
#  'विंडीज',
#  'विंडो',
#  'विणारे',
#  'विणे',
#  'विण्याचे',
#  'वित',
#  'वित्त',
#  'विधान',
#  'विपणन',
#  'विमानतळ',
#  'विर',
#  'विराट',
#  'विरोध',
#  'विला',
#  'विली',
#  'विले',
#  'विल्',
#  'विल्यम',
#  'विवरणपत्र',
#  'विश्लेषण',
#  'विष्कार',
#  'वीत',
#  'वु',
#  'वुन',
#  'वू',
#  'वे',
#  'वेगळं',
#  'वेढ',
#  'वेत',
#  'वैयक्तिक',
#  'वैयक्तीक',
#  'वैष्णो',
#  'व्यायाम',
#  'व्यास',
#  'शः',
#  'शकते',
#  'शक्य',
#  'शस्त्र',
#  'शिंदे',
#  'शिका',
#  'शिफारस',
#  'शिर्डी',
#  'शिल्पा',
#  'शिशु',
#  'शीत',
#  'शीर',
#  'शील',
#  'शेकाप',
#  'शेन',
#  'शोपि',
#  'ष्टा',
#  'स',
#  'संगीता',
#  'संचार',
#  'संयोजन',
#  'सकता',
#  'सखूबाई',
#  'सख्ख्या',
#  'सदृश',
#  'समाप्त',
#  'समीप',
#  'सव',
#  'सवाल',
#  'सव्र्ह',
#  'सात',
#  'साथ',
#  'साद',
#  'सादर',
#  'साफसफाई',
#  'सामूहिक',
#  'सारखं',
#  'सारखा',
#  'सारखी',
#  'सारखे',
#  'साळ',
#  'सावध',
#  'साहित्य',
#  'सिड',
#  'सिद्धेश्वर',
#  'सीआर',
#  'सीझेर',
#  'सु',
#  'सुलेमान',
#  'सुवर्ण',
#  'सूड',
#  'सेवन',
#  'सेवा',
#  'सोई',
#  'सोनू',
#  'सोळा',
#  'स्कर',
#  'स्कोअर',
#  'स्क्रिन',
#  'स्टार्क',
#  'स्ट्रेट',
#  'स्तुती',
#  'स्थायी',
#  'स्पर्धक',
#  'स्पष्टीकरण',
#  'स्मारक',
#  'स्वभाव',
#  'स्वस्त',
#  'हजारे',
#  'हमी',
#  'हाण',
#  'हिंदू',
#  'हिर',
#  'हीन',
#  'हुडा',
#  'हुवेई',
#  'हॉस्टेस',
#  'होऊन',
#  'ह्य',
#  '़',
#  '़छाड़',
#  '़या',
#  '़लोत',
#  '़्यांची',
#  '़्यांना',
#  'ांकडून',
#  'ांकित',
#  'ांत',
#  'ांमधले',
#  'ाई',
#  'ाचे',
#  'ाट',
#  'ाड',
#  'ाडा',
#  'ादती’',
#  'ादित',
#  'ादी',
#  'ाधीन',
#  'ाना',
#  'ापुढे',
#  'ापूर्वी',
#  'ायचं',
#  'ायच्या',
#  'ारडी',
#  'ाऱया',
#  'ारी',
#  'ार्चन',
#  'ार्ह',
#  'ाल',
#  'ाव',
#  'ावं',
#  'ावली',
#  'ावळ',
#  'ावह',
#  'ावा',
#  'ावी',
#  'ावे',
#  'ासमोर',
#  'ाहेत',
#  'ाेचणारच',
#  'ा’',
#  'ि',
#  'िअम',
#  'िज',
#  'िट्युबुलर',
#  'िणार',
#  'िण्याचा',
#  'िण्यात',
#  'िण्यास',
#  'िपल',
#  'िम',
#  'िय',
#  'ियम',
#  'िया',
#  'िल',
#  'िली',
#  'िले',
#  'िवात',
#  'िशफारसीय',
#  'ी',
#  'ीचा',
#  'ीचे',
#  'ीत',
#  'ीन',
#  'ीमुळे',
#  'ीयर',
#  'ीर',
#  'ील',
#  'ीला',
#  'ीव',
#  'ीस',
#  'ु',
#  'ुडती',
#  'ुण',
#  'ुन',
#  'ू',
#  'ूण',
#  'ून',
#  'ूनच',
#  'ूल',
#  'ूळ',
#  'ृत',
#  'ृती',
#  'ॄत',
#  'ॅग',
#  'ॅप',
#  'े',
#  'ेंगे',
#  'ेची',
#  'ेतर',
#  'ेतून',
#  'ेन',
#  'ेना',
#  'ेपण',
#  'ेय',
#  'ेल',
#  'ेस',
#  'ेस्',
#  'ो',
#  'ोड',
#  'ोड्स',
#  'ोदरं',
#  'ोन',
#  'ोय',
#  'ोळा',
#  'ोळे',
#  'ोसा',
#  'ोसे',
#  '्ट',
#  '्ड',
#  '्ण',
#  '्त',
#  '्तं',
#  '्ता',
#  '्ते',
#  '्ब',
#  '्यांची',
#  '्याचं',
#  '्याची',
#  '्याजवळ',
#  '्यात',
#  '्यावर',
#  '्यास',
#  '्री',
#  '्रेज',
#  '्रेषण',
#  '्ली',
#  '्विक',
#  '्वे',
#  '्शन',
#  '्ष',
#  '्षिप्त',
#  '्षेत',
#  '्ह',
#  '्हा',
#  '२९',
#  '४५',
#  '६५',
#  '८५',
#  '‘क्वार्टरफायनल’',
#  '‘दे',
#  '‘धडक’',
#  '‘रालोआ’',
#  '‘वैद्यकी’',
#  '’महाभारता’',
#  '−'}

# %%
collected["PREF"]
# Out:
# {'विरूद्ध',
#  'सुब्रमण्यम',
#  'दापोडी',
#  'खाऊ',
#  'बीजा',
#  'शैलेश',
#  'tur',
#  'll',
#  'अमेरिकन',
#  'ऑर्',
#  'पद्मनाभ',
#  'आवंढा',
#  'गीता',
#  'मेक',
#  'गर्द',
#  'संजना',
#  'हुल',
#  'निशा',
#  'डिग्री',
#  'मातृ',
#  'अंडर',
#  'चिपळूण',
#  'महिला',
#  'गुड्डू',
#  'तन',
#  'शिंद',
#  'Is',
#  'सु',
#  '80',
#  'वाम',
#  'नौ',
#  'देग',
#  'संपत्ती',
#  'थेरगाव',
#  'ॅनिकल',
#  'फुटी',
#  'मोदी',
#  'शॅम्',
#  'दादा',
#  'नयना',
#  'hy',
#  'वधू',
#  'राजू',
#  'वरील',
#  'स्टंट',
#  'गोप',
#  'vi',
#  'मॅक',
#  '@',
#  'दिप',
#  'काकोडकर',
#  'मेळाव्',
#  'हिल',
#  'वल्लभ',
#  'तस्मात्सर्वप्रकारेण',
#  'हिजबुल',
#  'नेत्या',
#  'फ्लॉवर',
#  'अभियंता',
#  'ग्',
#  'पराग',
#  'पॉल',
#  'आण्णा',
#  'उषा',
#  'देवरुख',
#  'ट्यून',
#  'वैभव',
#  'ंदा',
#  'समवेत',
#  'किसन',
#  'अव्वल',
#  'ंनाही',
#  'T',
#  'सांस्कृतिक',
#  'खुर्च्या',
#  'प्राचार्य',
#  'गॅल',
#  'कॉल',
#  'तौसिफ',
#  'संतती',
#  'ऑफर',
#  'प्रेरक',
#  'निव',
#  'रं',
#  'ep',
#  'विवेकानंद',
#  'अॅप',
#  'ट्रेन',
#  'राष्ट्रीय',
#  'चौकीदार',
#  'अक्षय',
#  'सैफ',
#  'आलि',
#  'र्',
#  'झ',
#  'थिंक',
#  'पूढे',
#  'झणझणीत',
#  'आंवाकणें',
#  'सिफ़र',
#  'क्रू',
#  'बाळू',
#  'बंगळूर',
#  'fr',
#  'इत्तेहा',
#  'अन्न',
#  'बदक',
#  'निरीक्षक',
#  '‘तु',
#  'इलियास',
#  'बिंदु',
#  'सलामीवीर',
#  'cy',
#  'कुतुब',
#  'एक्स',
#  'ach',
#  'बार्',
#  'SPbGEU',
#  'बंधु',
#  'देवा',
#  'पिंपळ',
#  'पठाण',
#  'दुर्',
#  'ऊर',
#  'अशुर्णासिर',
#  'ट्रेड',
#  'कल्प',
#  'S',
#  'नवरात्र',
#  'FS',
#  'ऑटो',
#  'अवलिया',
#  '४३',
#  'कन्व्हेंशन',
#  'तान्',
#  '‘हमशकल',
#  'नितीन',
#  'परमपूज्य',
#  'ब्रेस',
#  'नौका',
#  'लव्ह',
#  'तारा',
#  'व्हाईट',
#  'पितृ',
#  'राफेल',
#  '84',
#  'संगीत',
#  'वाव',
#  'नवाज',
#  'जैविक',
#  'HIV',
#  'सविस्तर',
#  'अभिनेत्री',
#  'जबलपूर',
#  'अमरावती',
#  'एफ',
#  'कॅप्टन',
#  'वेळेस',
#  'स्पेस',
#  'अंक',
#  'ट्रि',
#  'डेमो',
#  'सिने',
#  'भोंड',
#  'भूषण',
#  'महा',
#  'आयडी',
#  'माथेरान',
#  'सोलापूर',
#  'ग्रंथ',
#  'गारेगार',
#  'कराड',
#  'केदार',
#  'झडप',
#  'पोफळज',
#  'mo',
#  'माणिक',
#  'गुड',
#  'नितीश',
#  'योगी',
#  'डॅनियल',
#  'राईट',
#  'चॉकलेट',
#  'पंकज',
#  'चॅरी',
#  'हिंदु',
#  'fluo',
#  'कार्',
#  'अरुण',
#  'ab',
#  'कं',
#  'आउटलेट',
#  'रँ',
#  'माया',
#  'डोनाल्ड',
#  'तक्रारी',
#  'खूश',
#  'उडान',
#  'ड्रीम',
#  'अतुल',
#  'फायर',
#  'पत्रिका',
#  'शस्त्रास्त्र',
#  'ऋतु',
#  'पुरस्',
#  'टर्',
#  'कॅश',
#  'ड्रग',
#  'दानिश',
#  'दिनेश',
#  'प्रस्तुत',
#  'गुलाब',
#  'तर्',
#  'बिदानद',
#  'झहीर',
#  'स्वयंचलित',
#  'पूनम',
#  'गॅस्ट्रो',
#  'li',
#  'एग्',
#  'त्यात',
#  'घियासुद्',
#  'इगत',
#  'हरी',
#  'अवीतेश',
#  'PHOT',
#  'गायन',
#  'मायकेल',
#  'राणी',
#  'नर',
#  'पार्वती',
#  'हरळ',
#  'रोल',
#  'कॅडेट',
#  'दसऱ्',
#  'महेश',
#  'वाल्',
#  'लिव्ह',
#  'यै',
#  'कथा',
#  'मोहन',
#  'रेन',
#  're',
#  'लेग',
#  'ना',
#  'स्वर',
#  'Tu',
#  'काट्',
#  'झी',
#  'म्हा',
#  '—',
#  'रमा',
#  'वरुण',
#  'मैं',
#  'हु',
#  'पिन',
#  'हंस',
#  'शफाकत',
#  'अह',
#  'छोटा',
#  'decoc',
#  'सेडीशन',
#  'आँसू',
#  'तं',
#  'शेतकरी',
#  'लोखंड',
#  'पेमेंट',
#  'कोच',
#  'ब्रू',
#  'मनीष',
#  'शाय',
#  'जड',
#  'व्हॉ',
#  'राजु',
#  'ग्राईं',
#  'पाळ',
#  'व्हो',
#  'रुपी',
#  'ढोल',
#  'स्लाव',
#  'रघू',
#  'कबड्डी',
#  'कुलगुरू',
#  'रुक्मी',
#  'एचडी',
#  'M',
#  'कुच',
#  'निर्मळ',
#  'येकाटेरिं',
#  '‘रुम्सटूनाईट’',
#  'साधू',
#  'एक्झॉ',
#  'कबिर',
#  'तिला',
#  'आपट',
#  'सिद्धेश्वर',
#  'ब्लो',
#  'Mu',
#  'सर्जन',
#  'म्योदेनच',
#  'रूढ',
#  'पीएम',
#  'एम',
#  'वास्तु',
#  'डिप्लोमा',
#  'सीआयए',
#  'शिल्पा',
#  'वनपरि',
#  'बर्मिंगहम',
#  'सुरज',
#  'दीपिका',
#  'वाळू',
#  'लग्गेच',
#  'प्रदेशाध्यक्ष',
#  'वाली',
#  'Tho',
#  'निकाल',
#  'रिझर्व्ह',
#  'फलटण',
#  'मेट्रो',
#  'पृष्ठ',
#  'कोिथबीर',
#  'गणपत',
#  'वाडिया',
#  'एम्',
#  'ह्युमन',
#  'वर्क',
#  'प्रभू',
#  'मुल',
#  'वो',
#  'नायजे',
#  'नको',
#  'ंडुरा’',
#  'शालिनी',
#  'अरर्शिन',
#  'फलंदाज',
#  'प्रमाणेच',
#  'स्टार',
#  'मृग',
#  'स्पाईस',
#  'बुधवार',
#  'एनडीए',
#  'पप्पू',
#  'चालन',
#  'निखील',
#  'फि',
#  'साय',
#  'रोमान्स',
#  'संकेत',
#  'रेड',
#  'हिज',
#  'मूत्र',
#  '९१',
#  'प्रदर्शन',
#  'बाल',
#  'युनि',
#  'फेडर',
#  'Fo',
#  'ऍसिड',
#  'रोकड',
#  'मारो',
#  'नेहरु',
#  'भा',
#  'निवृत्ती',
#  'टेक्स',
#  'तुकोबा',
#  'लोह',
#  'सर्',
#  'डो',
#  'शे',
#  'हिमोग्लो',
#  'रघुनाथ',
#  'रजत',
#  'सेन्सॉर',
#  'सरोगेसी',
#  'सायन',
#  'आंशूमन',
#  'निरोगी',
#  'पिता',
#  'महात्मा',
#  'शद',
#  'ग्रेट',
#  'वृत्त',
#  'लक्ष्मण',
#  'मिस्टर',
#  'कॅम्प',
#  'दीप',
#  'रद्ध',
#  'बेस्ट',
#  'आॅक्सिनज',
#  'Bvl',
#  'Go',
#  'शिओमी',
#  'द्वितीय',
#  'यशवंत',
#  'CM',
#  'Tur',
#  'तबला',
#  'युनायटेड',
#  'कम',
#  'सेव्ह',
#  'ऋष',
#  'पर',
#  '४५',
#  'भल्या',
#  'ज्ञान',
#  'मोना',
#  'चतुर',
#  'नासिक',
#  'हॉस्टेल',
#  'लिम्फो',
#  'युनिव्हर्सिटी',
#  'सतीश',
#  'मुकेश',
#  'भागात',
#  'सॅटर',
#  'cl',
#  'ओस्टिओचंडो',
#  'बॉईज',
#  'Ko',
#  'कर्ते',
#  '‘किकि',
#  'एटीएम',
#  'CC',
#  'अशोक',
#  'गोविंद',
#  'प्रगती',
#  'ह',
#  'एमआयडीसी',
#  'Thyr',
#  'अकी',
#  '‘कणकण’',
#  'जोती',
#  'दुर्गा',
#  'बल',
#  'सत्ता',
#  'भानु',
#  'लेझर',
#  'शिखर',
#  'वर्षात',
#  'बॉश',
#  'sy',
#  'श्रीदेवी',
#  'तिघे',
#  'सोवि',
#  'her',
#  'मोसादेक',
#  'sampl',
#  'अमेरिका',
#  'हाँगकाँग',
#  'नालासोपा',
#  'व्यवसाय',
#  'जैश',
#  'aj',
#  'ट्वीट',
#  'राधे',
#  'Big',
#  'श्रीराम',
#  'पेठ',
#  'विजा',
#  'ऑडिट',
#  'फत्ते',
#  'स्टीव्ह',
#  'सिमरन',
#  'आरटी',
#  'कीटकनाशक',
#  'प्रणय',
#  'पुठ्ठा',
#  'क्रूझ',
#  'अनुप',
#  'पाद',
#  'ब्री',
#  'रिसर्च',
#  'काॅ',
#  'लॅटरल',
#  'नेत्र',
#  'आयुर्वेद',
#  'मार्केट',
#  'काटा',
#  'ट्रे',
#  'फां',
#  'गॅ',
#  'विक्रेता',
#  'कुमठ',
#  'सदा',
#  'स्टुडंट',
#  '#',
#  'टाईप',
#  'व्लादिमिर',
#  'ड्',
#  'Me',
#  'बिउन्से',
#  'इंद्र',
#  'सलमान',
#  'राक्षस',
#  'लाईन',
#  'सिटि',
#  '21',
#  'भाई',
#  'HC',
#  'पुणे',
#  'जयंत',
#  'निल',
#  'मौसोलयम',
#  'शिताफ',
#  'पंतप्रधान',
#  'कांदळ',
#  'निरा',
#  'हू',
#  'क्रा',
#  'नुसता',
#  'रिपोर्ट',
#  'पौर्णि',
#  'उष्',
#  'मैल',
#  'ठीक',
#  'शिवाजी',
#  'मध्य',
#  'आड',
#  'व्हॉट्स',
#  'स्काय',
#  'वनडे',
#  'काऊन्सिल',
#  'लॅपटॉप',
#  'तिळ',
#  'रणबीर',
#  'व्यापा',
#  'रूपा',
#  'भाद्रपद',
#  'याकडे',
#  'अलि',
#  'दाव्',
#  'हेर',
#  'वासीयांना',
#  'मुलगी',
#  'एशिया',
#  'paras',
#  'इको',
#  'सिया',
#  'माडे',
#  'बॉंम्बे',
#  'ब्रह्म',
#  'बचाव',
#  'टीका',
#  'चाईल्ड',
#  'यापूर्वी',
#  'नाईट',
#  'हॉट',
#  'ट्राय',
#  'काझ',
#  'बल्गे',
#  'फोर्स',
#  'आकांक',
#  'हनी',
#  'तरुण',
#  'विविध',
#  'दांड',
#  'ग्रि',
#  'इश',
#  'दाय',
#  'R',
#  'विराट',
#  'गाडगे',
#  'पोवेद्',
#  'अरुणाचल',
#  'हाड',
#  'आदि',
#  'जवान',
#  'बेगम',
#  'विधानसभा',
#  'गोल',
#  'माट',
#  'राय',
#  'बिंदू',
#  'अल्',
#  'युजर',
#  'याच',
#  'मुझसे',
#  'दौड',
#  'जवाहर',
#  'हिरो',
#  'जां',
#  'चोख',
#  'आयपीपी',
#  'टेलि',
#  'आरे',
#  'Otriv',
#  'अभिनय',
#  'सुंदर',
#  'भुवनेश्वर',
#  'bul',
#  'जम्मू',
#  'दरी',
#  'बहुसंख्य',
#  'डू',
#  'ऋन्मेष',
#  'टप्प',
#  'कत',
#  'यो',
#  'कल्पना',
#  'rad',
#  'सेरटव',
#  'अर्पिता',
#  'कसोटी',
#  'अमिताभ',
#  'पेट्रोल',
#  'जेक',
#  '28',
#  'नरेंद',
#  'ब्रिटीश',
#  'पा',
#  'हंबी',
#  'ऑ',
#  'Am',
#  'कार',
#  'एकता',
#  'दु',
#  'gl',
#  'आयुष',
#  'बापू',
#  'म्हस',
#  'आगा',
#  'क्लब',
#  'रत',
#  'गियर',
#  'हाे',
#  'शें',
#  'करिष्',
#  'प्रोजेक्ट',
#  'बृहन्',
#  'मंडा',
#  'टोयोटा',
#  'कन्',
#  'हेमा',
#  'न्यायाधीश',
#  'अंत',
#  'स्टँड',
#  'फॅम',
#  'एनईए',
#  'ख्य',
#  'शहेजाद',
#  'उमा',
#  'खानदानी',
#  'un',
#  'मंग',
#  'लिटी',
#  'फोर',
#  'रॉकेट',
#  'मयांक',
#  '‘राज',
#  'क्रिस',
#  'पशू',
#  'जीएस',
#  'दुमदु',
#  'दरवाजा',
#  'इंदा',
#  'उपाध्यक्ष',
#  'सुड',
#  'गुंड',
#  'एव्ह',
#  'नाच',
#  'लायक',
#  'वॅन',
#  'ॉग्',
#  'मॉन्',
#  'मायक्रो',
#  'रमेश',
#  'थॉमस',
#  'राजे',
#  'मैत्री',
#  'lo',
#  'जेस',
#  'डॉक',
#  '‘दावणीस',
#  'लक्ष्मी',
#  'E',
#  'बबन',
#  'सिंधु',
#  'रख',
#  'थ्री',
#  'महान',
#  'इरायड',
#  'नॉ',
#  'जोश',
#  'बरं',
#  'C',
#  'कोर्ट',
#  'तुळ',
#  'प्रवीण',
#  'एमपी',
#  'Su',
#  'ग्रा',
#  'CD',
#  'एएन',
#  'तारे',
#  'सद्',
#  'वाशी',
#  'ट्युब',
#  'गिर्यारोहक',
#  'Fe',
#  'Ensi',
#  '😦',
#  'डय़',
#  'Tyk',
#  'ऍल',
#  'सुधीर',
#  'शक्ती',
#  '‘टेम्पल',
#  'वास',
#  'ऑफिसर',
#  'सश',
#  'काजू',
#  'डोळा',
#  'रोमँ',
#  'वेट',
#  'इन्व्हेस्ट',
#  'micr',
#  'श्रेय',
#  'बहू',
#  'गॅलरी',
#  '२',
#  'फीज',
#  'थेट',
#  'क्रो',
#  'विठ्ठल',
#  'रेडी',
#  'मॉडेल',
#  'ev',
#  'लाईफ',
#  'मृण्मयी',
#  'वन',
#  'वंदना',
#  'हुकुम',
#  'सदानंद',
#  'kno',
#  'ब',
#  'अननुभवी',
#  'नय्',
#  'मेहबूब',
#  'ग्रीन',
#  'समीर',
#  'आळंदी',
#  'थि',
#  'मेरे',
#  'शहर',
#  'प्रँच',
#  'मोफत',
#  'लवासाका',
#  'मिस',
#  'व्हॅलेंटाइन',
#  'गुरु',
#  'हिंदी',
#  'अक्षर',
#  'क्लाइंब',
#  'पत्रात',
#  'अश्रु',
#  'D',
#  'पॉर्न',
#  'ुलिनम',
#  'मी',
#  'गळती',
#  'ch',
#  'हँडल',
#  'Pro',
#  'बोरी',
#  'Ju',
#  'अभि',
#  'गरसमंध',
#  'स्त्री',
#  'ओरि',
#  'हळद',
#  'सिड',
#  'बुरुज',
#  'एमबी',
#  'वेपसि',
#  'श्री',
#  'तुह्',
#  'युरे',
#  'कुठलं',
#  'अर्जुन',
#  'अच्छे',
#  'You',
#  '43',
#  'दिरंगाई',
#  'क्लीन',
#  'शबद',
#  'FRU',
#  'विरहित',
#  'मेंढ',
#  'गुहागर',
#  'प्रतीक्षा',
#  'कटीबध्द्',
#  'मिरज',
#  'मास्क',
#  'साम',
#  'nyud',
#  'कर्',
#  'थॅँक',
#  'हास्य',
#  'गगन',
#  'पर्यवेक्षक',
#  'संजीव',
#  '04',
#  'फिल्टर',
#  'भगत',
#  'पीटर',
#  'माळी',
#  'मलमपट्टी',
#  'शाम',
#  'स्पिनर',
#  'सरदार',
#  'दिव्यांग',
#  'dis',
#  'जादू',
#  'सोबतच',
#  'कॉफी',
#  'चिकोडी',
#  'प्रदीप',
#  'श्रध्दा',
#  'मिताली',
#  'खतरा',
#  'रायल',
#  'राजापूर',
#  'क्यू',
#  'अंतर',
#  'मनोहर',
#  'पॉलिश',
#  'तलाह',
#  'भित्रं',
#  'बे',
#  'स्टीक',
#  'दक्षता',
#  'पुजा',
#  'एफए',
#  'पर्',
#  'चाळ',
#  'ऐ',
#  'कां',
#  'शक्',
#  'ग्रॅम',
#  'मंदा',
#  'आत',
#  'ढाक',
#  'सलग',
#  'अझ्',
#  'Lo',
#  'रशियन',
#  'हुं',
#  'वेंकटेश',
#  'श्रीमद्',
#  'अरविंद',
#  'Di',
#  'आख',
#  'निट',
#  'अनुभव',
#  'इंजिन',
#  'राजेश',
#  'बाबु',
#  'सेगमेण्',
#  'टेंट',
#  'सारथी',
#  'लांजा',
#  'Nik',
#  'अफरीन',
#  'चॅरि',
#  'J',
#  'da',
#  'एडि',
#  'संकल्प',
#  'ममता',
#  'चिरंजीव',
#  'बाबू',
#  'अमृत',
#  'किशोर',
#  'ईंग्र',
#  'ईडी',
#  'ro',
#  'जान्हवी',
#  'वद',
#  'इ',
#  'पर्वत',
#  'ईव्हीएम',
#  'वजा',
#  'टाऊन',
#  'मते',
#  'IIT',
#  'कोथ',
#  '37',
#  'कॉन्स्टेबल',
#  'दत्ता',
#  'शॉपिंग',
#  'रिइंब',
#  'ऍॅक्',
#  'वृष',
#  'हिमाचल',
#  'ham',
#  'ओल्ड',
#  'ज्यू',
#  'सीएम',
#  'मुघल',
#  'सीईओ',
#  'ऍङ',
#  'प्रताप',
#  'kul',
#  'रीअल',
#  'सीबीआय',
#  'एआय',
#  'पायी',
#  'तह',
#  'साव',
#  'मंगल',
#  'खरीखुरी',
#  'अध्यात्म',
#  'विनि',
#  'राधा',
#  'शाहू',
#  'िस',
#  'धीर',
#  'अना',
#  'शिका',
#  'pl',
#  'बलबीर',
#  'कॅल',
#  'my',
#  'भाय',
#  'एडवेंचर',
#  'मॅक्स',
#  'माँ',
#  'चतुर्',
#  'संघर्ष',
#  'भैर',
#  'अंबा',
#  'Da',
#  'वेस्ट',
#  'Mak',
#  '५७',
#  'सिरी',
#  'हिंदू',
#  'रॅन्सम',
#  'रवींद्र',
#  'सासऱ',
#  'रितेश',
#  'मटा',
#  'शास्त्री',
#  'जिवाणू',
#  'तेजस',
#  'केमिकल',
#  'रंजन',
#  'शांताराम',
#  'खरतर',
#  'हैदराबाद',
#  'मॉड्यूल',
#  'ऑल',
#  'तसं',
#  'ंमधून',
#  'हॉलिवूड',
#  'वकील',
#  'हळदी',
#  'बेंगळूर',
#  'dn',
#  'फ्युचर',
#  '‘मुक्काबाज’',
#  'बिर',
#  'अस्थि',
#  'मशिन',
#  'तेव्हा',
#  'ट्रिपल',
#  'गच्च',
#  'बाबतीत',
#  '२७',
#  'W',
#  'मेडि',
#  'X',
#  'Ma',
#  'अभय',
#  'सिंधुदुर्ग',
#  'मंगोल',
#  'किंग',
#  'आंदोनकर्त',
#  'सामना',
#  'भावना',
#  'भाकरी',
#  'जगन्नाथ',
#  'आयो',
#  'केतन',
#  'पब्',
#  'सिं',
#  'सिध्द',
#  '९०',
#  'bra',
#  'पालघर',
#  'विक्रेते',
#  'स्पा',
#  'Keyt',
#  'स्मृति',
#  'ग्रुप',
#  'वेन',
#  '‘नो',
#  'बटण',
#  'सुलोचना',
#  ...}

# %%
collected["ADV"]
# Out:
# {'विरूद्ध',
#  'जेएनयु',
#  'शुक्राणू',
#  'आरती',
#  'हिंसाचार',
#  'ITR',
#  'गिक',
#  'ट',
#  'गिरगाव',
#  'तपासणी',
#  'खाऊ',
#  'चॅलन',
#  'समस्या',
#  'संशियत',
#  'इयत्ता',
#  'कामगिरी',
#  'राहुन',
#  'खेळ',
#  'निषेध',
#  'भरण',
#  'गीता',
#  'वेल',
#  'हुल',
#  '‘सिद्धांत’',
#  'आई',
#  'ऱ्यांनी',
#  'महिला',
#  'गुड्डू',
#  'डोंबिवली',
#  'वणं',
#  'अम्बुबी',
#  'ओस',
#  'हँड',
#  'खाल्ले',
#  '85',
#  'नौ',
#  'संपत्ती',
#  'नियम',
#  'सेंट्रीफ्यूज',
#  'लुभाणा',
#  'सापडले',
#  'आतिषबाजी',
#  'थंडी',
#  'कचरा',
#  'कामकाज',
#  'फरीदा',
#  'टन',
#  'काळी',
#  'वधू',
#  'उर्मिला',
#  'विरोधात',
#  'स्टंट',
#  'मॅक',
#  '‘स्पेल’',
#  'समाजकारण',
#  'थर',
#  'मासिक',
#  'धावपटू',
#  'धकधक',
#  'ऐत',
#  'आॅलिम्',
#  'प्रतिक',
#  'अलगद',
#  'ठाऊक',
#  'नेत्या',
#  'फ्लॉवर',
#  'बरे',
#  'अभावी',
#  'दिवे',
#  'ग्',
#  'उत्पादन',
#  'महसूल',
#  'स्मिथ',
#  '‘आत्मा’',
#  'ूण',
#  'वरिष्ठ',
#  'मॅनेजर',
#  'संकते',
#  'उकळ्या',
#  'धुपारती',
#  'कन',
#  'समडोळी',
#  'आवाज',
#  '‘मोक्ष’',
#  'बरोबरी',
#  'जॅकेट',
#  'मोबदल्',
#  'चणचण',
#  'कारगिल',
#  'मकरसंक्रा',
#  'सार्वत्रिक',
#  'समवेत',
#  'अव्वल',
#  'आजारपण',
#  'अणु',
#  'ऑपेरशन',
#  'स्मृती',
#  'गदा',
#  'कॅन्सर',
#  'शूटिंग',
#  'उपचार',
#  'योग्य',
#  'कॉल',
#  'यासंबंधी',
#  'वाईट',
#  'निमंत्रण',
#  'कमेंट',
#  'टाइप',
#  'अट',
#  'ऑफर',
#  'विषाणू',
#  'झडती',
#  'गिते',
#  'सारी',
#  'डिशेस',
#  'वायला',
#  'जत्रोत्सव',
#  'विवेकानंद',
#  'भाडे',
#  'सिल्',
#  'ट्रेन',
#  'तळ',
#  'म्हशी',
#  'उकाडा',
#  'राष्ट्रीय',
#  'सावज',
#  'ठा',
#  'झ',
#  'पारा',
#  'पेशंट',
#  'समाचार',
#  'हॉर्न',
#  '83',
#  'ज्वलंत',
#  'रात्र',
#  'फायदा',
#  'समलैंगिक',
#  '418',
#  'बुरूज',
#  'तुळजाभवानी',
#  'अन्न',
#  'भास',
#  '‘तु',
#  'थाळी',
#  'सलामीवीर',
#  'बॉम्ब',
#  'पाऊल',
#  'भूल',
#  'सीईटी',
#  'पुरवठा',
#  'देऊ',
#  'हाक',
#  'वर्चस्व',
#  'पारायण',
#  '‘पकडले’',
#  'बंधु',
#  'फायब्रिन',
#  'दुर्',
#  'लॉटरी',
#  'धिंड',
#  'बाप',
#  'विजे',
#  'अंमल',
#  'गांड',
#  'शंका',
#  'मणक्',
#  'गल्लोगल्ली',
#  'युक्रेन',
#  'वध',
#  'दजा्र',
#  'कसल्या',
#  'ट्रफिक',
#  'शिक्षा',
#  'आस्पन',
#  'मतमोजणी',
#  'बळीराजा',
#  'इटॉफ',
#  'नौका',
#  'तारा',
#  'SDG',
#  'रोबोट',
#  'उन्',
#  'ुन',
#  'किमंत',
#  'पाचट',
#  'बेभरवशाच',
#  'संगीत',
#  'आवाक्या',
#  'चेल्सी',
#  'सविस्तर',
#  'धनगर',
#  '७०',
#  'कुठे',
#  'आंदण',
#  'अभिनेत्री',
#  'अमरावती',
#  'होन',
#  'शाओमी',
#  'निलंबित',
#  'चढाई',
#  'घंटा',
#  'सदिच्छा',
#  'वेळेस',
#  'स्पेस',
#  'लठ्ठपणा',
#  'भयभीत',
#  'गॅजेट्स',
#  'बांदि',
#  'आक्षेप',
#  'वैचारिक',
#  'पाटण',
#  'उपसभापती',
#  'सहमती',
#  'डॉयलॉग',
#  'प्राण',
#  'निर्मित',
#  'दुटप्पी',
#  'संवर्ग',
#  'कराड',
#  'वसा',
#  'रचने',
#  'बाले',
#  'घोट',
#  'पॅन',
#  'कोमट',
#  'खार',
#  'नियंत्रित',
#  'ड्रेस',
#  'रिव्होल्युशनरी',
#  'नितीश',
#  'बिरा',
#  'डॅनियल',
#  'विघ्न',
#  'खेबुडकर',
#  'अगोदर',
#  'ग्रामस्थ',
#  'पार्सल',
#  'ऎवज',
#  'सहाय्य',
#  'उकल',
#  'प्राणि',
#  'हिंदु',
#  'नऊ',
#  'सिमेंट',
#  'संग',
#  'आवर्त',
#  'गाळेधारक',
#  'घमासान',
#  'किल्ले',
#  'बोट',
#  'तक्रारी',
#  'श्रीलंके',
#  'मीलन',
#  'थकबाकी',
#  'खूश',
#  'मोशन',
#  'फायर',
#  'BSCRIBE',
#  'ऑर्डर',
#  'हत्ती',
#  'आशिर्वाद',
#  'जाहिराती',
#  'शी',
#  'पख',
#  'सक्रिय',
#  'जरा',
#  'बाहुल',
#  'कॅश',
#  'माल',
#  'काबाड',
#  'इंजेक्शन',
#  'आॅस्ट्रेलिया',
#  'रणनीती',
#  'तहकूब',
#  'अधिक',
#  'सारखा',
#  'अस्ताव्यस्त',
#  'गायन',
#  'कारभार',
#  'पद्मावत',
#  'राणी',
#  'इनकम',
#  'गांभीर्य',
#  'रोल',
#  'प्रादुर्भाव',
#  'वर्तणूक',
#  'साम्राज्य',
#  'पोकेमोन',
#  'गाडया',
#  'पलायन',
#  'अजब',
#  'उल्लेख',
#  'सर्वां',
#  'लीटर',
#  'जयघोष',
#  'पुण्य',
#  'लावले',
#  'निमंत्रित',
#  'हस्तक्षेप',
#  'पिक्सेल',
#  'झलक',
#  'स्वर',
#  'अंतिम',
#  'वस्त्र',
#  'तरतूद',
#  'विंडीज',
#  'अखिल',
#  'म्हटल',
#  'गुंडा',
#  'हप्',
#  'ठेऊ',
#  'दुहेरी',
#  'निरोप',
#  'सहान',
#  'तासात',
#  'कोटय़वधी',
#  'कळवि',
#  'ब्रिज',
#  'pe',
#  'धूम्रपान',
#  'सातत्य',
#  'नजीक',
#  'उद्दिष्ट',
#  'असोसिएट',
#  'ट्रॉफी',
#  'शेतकरी',
#  'जिवंत',
#  'सिद्दकी',
#  'खुट्टा',
#  'व्याख्येत',
#  'बंधू',
#  '‘असर’',
#  'पोषक',
#  'सनराईज',
#  'सन्मान',
#  '‘स्वाभिमान’',
#  'संशय',
#  'इज्जत',
#  'फायली',
#  'स्तनपान',
#  'काढणी',
#  'दांडी',
#  'स्नान',
#  'खारी',
#  'नरक',
#  'आजार',
#  'तोंड',
#  'वागण्या',
#  'कुलगुरू',
#  'साक्षर',
#  'मेजवानी',
#  'जीन्स',
#  'मरुवन',
#  'नागरीक',
#  'पं',
#  'फ्लॉप',
#  'झटापट',
#  'ससे',
#  'निर्मळ',
#  'तिजोरी',
#  'दखल',
#  'वचपा',
#  'तिला',
#  'प्रूव्ह',
#  'सिद्धेश्वर',
#  'गुंग',
#  'अनभिषिक्त',
#  'सीडी',
#  'विरुध्द',
#  'कौमार्य',
#  'अद्',
#  'भीषण',
#  'प्लान',
#  'संख्याबळ',
#  'गन',
#  'समाध',
#  'झुंज',
#  'वंशज',
#  'दीपिका',
#  'प्रदेशाध्यक्ष',
#  'वाली',
#  'आव्',
#  'सहस्र',
#  'द्रोलकर',
#  'निकाल',
#  'ओळखी',
#  'मोठय़ा',
#  'कँ',
#  'रणकंदन',
#  'जेवणा',
#  'मुत्सद्देगिरी',
#  'वाडिया',
#  'साद्यंत',
#  'हवा',
#  'लाँच',
#  'लक्ष्य',
#  'रेल',
#  'रिसेप्शन',
#  'सुरुंग',
#  'खरेदी',
#  'जवळ',
#  'शिलेदार',
#  'नायजे',
#  'वयाचे',
#  'गणित',
#  'शड्डू',
#  'कंत्राट',
#  'फलंदाज',
#  'सहकार्य',
#  'भ्रष्ट',
#  'वू',
#  '‘झोपडपट्टी’',
#  'प्रमाणेच',
#  'फड',
#  'भूगोल',
#  'अफरातफर',
#  'येऊन',
#  'ऍप',
#  'अण्वस्त्र',
#  'स्टीफन',
#  'शु',
#  'नियमन',
#  'शुध्द',
#  'व्हर्जन',
#  'तिघां',
#  'नर्गिस',
#  'फि',
#  'प्रेरणा',
#  'वषी',
#  'भ्याड',
#  'संकेत',
#  'सौजन्य',
#  'दूकानात',
#  '‘नमो',
#  'रेड',
#  'प्रदर्शन',
#  'मूत्र',
#  'जनरल',
#  'अटक',
#  'बक',
#  'प्रवेश',
#  'रोकड',
#  'नेतृत्व',
#  'स्मशाम',
#  'यशो',
#  'भा',
#  'सेवा',
#  'निवृत्ती',
#  'प्रकल्पग्रस्त',
#  'घटस्फोट',
#  'उधळण',
#  'शे',
#  'आर्थिक',
#  'विलिनीकरण',
#  'नसा',
#  'प्रतिबिंब',
#  'घायाळ',
#  'विवाह',
#  'संकलन',
#  'सुपूर्द',
#  'पाकिट',
#  'निरोगी',
#  'पिता',
#  'आठवणी',
#  'रुग्ण',
#  'फ्युअ',
#  'चुरमुरे',
#  'राष्ट्रवादी',
#  'पॅरे',
#  'िल',
#  'डील',
#  'वृत्त',
#  'लक्ष्मण',
#  'वाघीण',
#  'दुनिया',
#  'करंडक',
#  'बिस्कीट',
#  'नोटीस',
#  'इव्हेंट',
#  'यार्ड',
#  'रिक्त',
#  'कुष्ठरोग',
#  'संर्वां',
#  'लहरी',
#  'थो',
#  'फंड',
#  'सुवर्ण',
#  'गदारोळ',
#  'येत',
#  'भाकीत',
#  'संग्रह',
#  'तबला',
#  'घाम',
#  'सेव्ह',
#  'नेत्रा',
#  'पाया',
#  'टोक',
#  'रिळं',
#  'पैलू',
#  'जळगाव',
#  'ऐहिक',
#  'कारवाई',
#  'मुकेश',
#  'गोळा',
#  'सर्वेक्षण',
#  'विकास',
#  'जमाव',
#  'स्वप्न',
#  'बचत',
#  'लाडू',
#  'पाय',
#  'गोविंद',
#  'प्रगती',
#  'ह',
#  'नावे',
#  'परस्पर',
#  'प्रथा',
#  'विहीत',
#  'प्राध्यापक',
#  'दर्जा',
#  'धडक',
#  'पेल',
#  'सत्ता',
#  'तिने',
#  'शिखर',
#  'चकीत',
#  'बेत',
#  'आत्मविश्वास',
#  '्म',
#  'जमा',
#  'सदस्य',
#  'आकर्षित',
#  'छळ',
#  'चालणार',
#  'बागेत',
#  'महिमा',
#  'अमेरिका',
#  'हिपॅटायटीस',
#  'घसर',
#  'श्रृंगेरी',
#  'मिच',
#  'जागा',
#  'निलंबन',
#  'अधिपत्य',
#  'त्रुटी',
#  'अंदाज',
#  'फॅमिली',
#  'होस्ट',
#  'गोष',
#  'शृंगार',
#  'क्ल्पना',
#  'ड्युटी',
#  'बिबटया',
#  'तंटयाब',
#  'पत्ता',
#  'नेतृत्त्व',
#  'युवती',
#  'अस्त',
#  'काटा',
#  'धारण',
#  'अंतर्गत',
#  'निशि',
#  'बि',
#  'क्लाऊड',
#  'मॅच',
#  'आठवडा',
#  'थो़डी',
#  'नगरी',
#  'जावे',
#  'अविस्मरणीय',
#  'ंतर',
#  'सलमान',
#  'खातेवाटप',
#  'पीआर',
#  'गायब',
#  'स्टाफ',
#  'खदखद',
#  'मर्यादित',
#  'दाद',
#  'SDA',
#  'डागडुजी',
#  'सव्वा',
#  'गरज',
#  'पाठवा',
#  'सावट',
#  'शिवनेरी',
#  'भाई',
#  'पुणे',
#  'ळणी',
#  'संभा',
#  'कशेळे',
#  'उलाढाल',
#  'बुंदी',
#  'लगबग',
#  'ऑडिशन',
#  'कांस्य',
#  'सूतोवाच',
#  'पंतप्रधान',
#  'बाजू',
#  'लेखिका',
#  'आक्रमक',
#  'स्वीकार',
#  'प्रयोजन',
#  '‘व्यवस्था’',
#  'निरा',
#  'इरीडा',
#  'बाचाबाची',
#  'निकटवर्ती',
#  'जीभेवर',
#  'ब्ल',
#  'काडी',
#  'सिंगापूर',
#  'हल्ला',
#  'पावित्र्य',
#  'ठीक',
#  'आड',
#  'धिंगाणा',
#  'चिवट',
#  'रस्ता',
#  'सुटी',
#  'वनडे',
#  'मूस',
#  'हत्ये',
#  'कुटुंब',
#  'एकत्र',
#  'द्या',
#  'हरकत',
#  'मयुरी',
#  'इहतशाम',
#  'तंतुमय',
#  'रणबीर',
#  'भ्रमणध्वनी',
#  'शोषण',
#  'थार',
#  'घुस',
#  'मुलगी',
#  '‘नाम’',
#  'चेंगराचेंगरी',
#  'वून',
#  'मुद्दे',
#  'प्रभा',
#  'जागावाटपावर',
#  'बंगल्',
#  'उपोषण',
#  'तारण',
#  'पूर्वा',
#  'अधीक्षक',
#  'इराण',
#  'माडे',
#  'फोटोशूट',
#  'नव',
#  'ांमधून',
#  'बचाव',
#  'वुंगडूडी',
#  'टीका',
#  'यापूर्वी',
#  'उल्लू',
#  'भंगार',
#  'बॉस',
#  'ट्राय',
#  'झुंबड',
#  'हमीभाव',
#  'पूजन',
#  'मांजा',
#  'अली',
#  'झोपडपट्टय़ा',
#  'दारिद्रय',
#  'वाडीतील',
#  'राजौरी',
#  'सौ',
#  'विजेतेपद',
#  'आवक',
#  'मीठ',
#  'आस',
#  'साक्ष',
#  'मेसेज',
#  'फाळणी',
#  'उत्तर',
#  'सेलेब्रिटी',
#  'घरी',
#  'ओझ्य',
#  'शपथ',
#  'कसले',
#  'गोल',
#  'मध्यरात्री',
#  'माट',
#  'गरळ',
#  'शाही',
#  'शपथविधी',
#  'केडीएमसी',
#  'इति',
#  'ंच',
#  'बसेस',
#  'दौड',
#  'कॉन्ट्रॅक्ट',
#  'मोठी',
#  'यळवट',
#  '‘बा',
#  'सॅलरी',
#  'माथ्यावर',
#  'मिष्टान्न',
#  'म्होरक्या',
#  'बीएमसी',
#  'वर्ल्डकप',
#  'ताबडतोब',
#  'चोख',
#  'अफवा',
#  'आरे',
#  'बक्षिस',
#  'अभिनय',
#  'भोव',
#  'भुवनेश्वर',
#  'अब्जाधीश',
#  'खून',
#  'जम्मू',
#  'अर्थव्यवस्थे',
#  'ऍण्टोईन',
#  '४८',
#  'त्रूटी',
#  'हरमनप्रीत',
#  'गाठ',
#  'कल्पना',
#  'कोका',
#  'ष्मा',
#  'फूल',
#  '१',
#  'चौकटी',
#  'रिपरिप',
#  'पेट्रोल',
#  'डिझेल',
#  '28',
#  '63',
#  'परब',
#  'ताब्यात',
#  'सौराष्ट्र',
#  'ऑप्शन',
#  'घडयाळ',
#  'गन्नम',
#  'डायव्हिंग',
#  'एकता',
#  'संचार',
#  'कालावधी',
#  'मतदान',
#  'गियर',
#  'गोळ',
#  'इंस्टाग्राम',
#  'प्रोजेक्ट',
#  'वैविध्य',
#  'अंत',
#  'अनुवाद',
#  'पुष्कळ',
#  'न्यायाधीश',
#  'फोर्ट',
#  'जाँटी',
#  'वाढदिवस',
#  'टेप',
#  'समारोप',
#  'टवासीय',
#  'क्लासेस',
#  'दगा',
#  'फडतुस',
#  'व्हिडीओ',
#  'पार',
#  '‘राज',
#  'क्रिस',
#  'गळा',
#  'कैद',
#  'फाइल',
#  'दरवाजा',
#  'व्याजदर',
#  'उपाध्यक्ष',
#  'आघाडी',
#  'गुंड',
#  'बल्लभ',
#  'तत्पर',
#  'ब्रेन',
#  'सुक',
#  'नेक्सस',
#  'वॉशिंग्टन',
#  'अडॅप्टर',
#  'भूगर्भ',
#  'सल',
#  'गायी',
#  'सरप्राईज',
#  'विलीनीकरण',
#  'गुन्ह्',
#  'देणगी',
#  'सुलभ',
#  'मैत्री',
#  'चिन',
#  'मासे',
#  'बळेच',
#  'कोणती',
#  'नंतर',
#  'साहुकार',
#  'डॉक',
#  'पोद्दार',
#  'गांधी',
#  'वितरण',
#  'ख्रिस',
#  'आवड',
#  'विनयभंग',
#  'क्लु',
#  'नजर',
#  'पैस',
#  'खोड',
#  'कुडाळ',
#  'नरसो',
#  'अराध्य',
#  'सभा',
#  'सांता',
#  'डझन',
#  'हुडहुडी',
#  'संशोधन',
#  'जोश',
#  'तारे',
#  'दिव',
#  'वेगळे',
#  'सद्',
#  'ट्युब',
#  'नियंत्रण',
#  'काव',
#  'प्रसुती',
#  'हिंमत',
#  'वास',
#  'डोळा',
#  'बुध',
#  'रोमँ',
#  'स्ट्रोक',
#  'श्रेय',
#  'गॅलरी',
#  '२',
#  'थेट',
#  'बाधा',
#  'पाउल',
#  'प्रतिसाद',
#  'घेतले',
#  'रेडी',
#  'लाईफ',
#  'वन',
#  'टिपण',
#  'मिजास',
#  'सत्रात',
#  'आपला',
#  'हुकुम',
#  '‘सोसल’',
#  'बोना',
#  'खरिप',
#  'भोजन',
#  'रूप',
#  'नेकलेस',
#  'अनिगेरा',
#  'छाय',
#  'टंचाई',
#  'खांद्यावर',
#  'आकलना',
#  'पकड',
#  'केक',
#  'टप्प्या',
#  'आसमंत',
#  'भवितव्य',
#  'घाला',
#  'क्लिक',
#  'टेकडी',
#  'कॉस',
#  'शौर्य',
#  'निर्यात',
#  'पुढे',
#  'सुट',
#  'नूर',
#  'समीर',
#  '‘षटकार’',
#  'कर्करोग',
#  'खटाटोप',
#  'णार',
#  'दृष्टि',
#  'आव',
#  'संस्था',
#  'कॉकटेल',
#  'सत्या',
#  'प्रकृती',
#  'जन्म',
#  'नर्स',
#  '‘फेरा’',
#  'मोफत',
#  'वाटा',
#  'स्टाईल',
#  'पत्रात',
#  'लिखाण',
#  'दहन',
#  'टोमॅटो',
#  'मी',
#  'गळती',
#  'तरतुद',
#  'लाठीमार',
#  'दंगल',
#  'बोरी',
#  'जास्त',
#  'अपिल',
#  'तेथून',
#  'तऱ्हे',
#  'दुबोती',
#  'ंच्छन',
#  'हळद',
#  'गुंतवणूक',
#  'नायनाट',
#  'अभ्युदय',
#  'श',
#  'अखत्यारित',
#  'तुह्',
#  'विहिरी',
#  'फटाके',
#  'जखमी',
#  'फरटिटि',
#  'खापर',
#  'दिरंगाई',
#  'अवनी',
#  'क्लीन',
#  'दबाव',
#  'लाभ',
#  'गॅरेज',
#  'हायड्रेट',
#  'व्यक्तीमत्व',
#  'सांगितल्या',
#  'मेंढ',
#  'आश्रय',
#  'भडाग्नी',
#  'गारव्',
#  'वंचित',
#  'प्रतीक्षा',
#  'कारवाया',
#  'फ्लो',
#  'दुष्ट',
#  'शह',
#  'सुरक्षीत',
#  'मोर्चा',
#  'स्थान',
#  'केळी',
#  'जलाशय',
#  'क्लैरी',
#  'फटका',
#  'शहाणपणा',
#  'निर्देश',
#  'समि',
#  'भिती',
#  'समतोल',
#  'सेवाज्येष्ठते',
#  'फाटा',
#  'पैसे',
#  'एकूण',
#  'भयानक',
#  'प्या',
#  'दोषी',
#  'मुकुट',
#  'कनेक्शन',
#  'गृहकर्ज',
#  'अतिक्रमण',
#  'Hy',
#  '‘अग्निस',
#  'भोई',
#  'व्हॉट्सअॅप',
#  'मासळी',
#  'मेळावा',
#  'तिरसट',
#  'लोळ',
#  'काऊंट',
#  'फेल',
#  'पोषण',
#  'श्रध्दा',
#  'बसल्या',
#  'गणेशोत्सव',
#  'सुरुवात',
#  'कालवण',
#  'दूर',
#  'अंतर',
#  'म्हाडा',
#  'आदान',
#  'निवडणूक',
#  'बैर',
#  'खंड',
#  'र्म',
#  'काही',
#  'फिट',
#  'दौरे',
#  'पापण',
#  'झोमॅटो',
#  'मोदक',
#  '‘पाकडे’',
#  '‘शाबाश',
#  'जैतापूर',
#  'अखेरीस',
#  'दक्षता',
#  'कनेक्ट',
#  'परीक्षण',
#  'िम्',
#  'जुन्नर',
#  'हत्या',
#  'पुजा',
#  'इव्हान',
#  'उजळ',
#  ...}

# %%
tag_dist = {s:dict() for s in symbols}
for morph in symbols:
    tag_dist[morph] = {tag:collected[tag].get(morph,0) for tag in tags}

# %%
count = 0
for morph in list(symbols):

    x=sorted(list(tag_dist[morph].items()), key = lambda x: x[1], reverse=True)
    if x[0][1]>10:
        print(morph)
        print(x)
        count+=1
        print("\n\n\n")
# Out:
# ्सना
# [('ADP', 12), ('PROPN', 2), ('X', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# लाखां
# [('NUM', 80), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# गोखल
# [('NOUN', 15), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सार्वत्रिक
# [('DET', 19), ('ADV', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# अव्वल
# [('PART', 19), ('ADV', 17), ('CCONJ', 2), ('PREF', 2), ('NSUFF', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# विश्वसनीय
# [('VERB', 15), ('AJSUFF', 8), ('X', 4), ('SCONJ', 3), ('ADJ', 2), ('NSUFF', 1), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# झ
# [('X', 35), ('PROPN', 24), ('ADV', 7), ('VERB', 3), ('PREF', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# स्वाभाविक
# [('X', 11), ('ADJ', 10), ('VERB', 6), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कोठडी
# [('NSUFF', 23), ('VERB', 10), ('PRON', 5), ('PART', 4), ('NUM', 2), ('NOUN', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# पाऊल
# [('PART', 37), ('ADV', 17), ('NOUN', 9), ('VERB', 5), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# निरीक्षण
# [('NOUN', 13), ('AJSUFF', 8), ('SCONJ', 7), ('PART', 6), ('X', 5), ('NSUFF', 2), ('ADJ', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मनोरंजन
# [('PART', 27), ('NOUN', 17), ('X', 4), ('DET', 3), ('ADJ', 1), ('PUNCT', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# नागपूर
# [('PROPN', 66), ('PRON', 36), ('DET', 22), ('NOUN', 3), ('NUM', 2), ('VSUFF', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# धनगर
# [('DET', 30), ('PRON', 3), ('PROPN', 2), ('ADV', 1), ('AUX', 1), ('NOUN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# चरबी
# [('PRON', 16), ('PART', 12), ('AJSUFF', 7), ('NUM', 2), ('NSUFF', 1), ('PROPN', 1), ('DET', 1), ('PUNCT', 1), ('VERB', 1), ('ADJ', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# कराड
# [('PROPN', 13), ('PREF', 6), ('NOUN', 5), ('NSUFF', 3), ('ADV', 2), ('NUM', 1), ('ADJ', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पंकज
# [('NOUN', 59), ('PREF', 6), ('PROPN', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# चॉकलेट
# [('X', 13), ('ADJ', 9), ('PRON', 6), ('PROPN', 2), ('SCONJ', 1), ('PREF', 1), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0)]
#
#
#
#
# ha
# [('CCONJ', 23), ('PUNCT', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कं
# [('X', 26), ('CCONJ', 6), ('NSUFF', 4), ('AJSUFF', 1), ('PROPN', 1), ('PREF', 1), ('ADJ', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ’चे
# [('ADP', 22), ('CCONJ', 7), ('NUM', 2), ('AJSUFF', 1), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# माल
# [('PART', 48), ('PROPN', 20), ('X', 19), ('ADV', 17), ('ADJ', 13), ('DET', 8), ('NOUN', 5), ('VERB', 1), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# अकाऊंट
# [('PRON', 11), ('VERB', 2), ('ADP', 2), ('PROPN', 1), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0)]
#
#
#
#
# अधिक
# [('PART', 204), ('ADV', 185), ('ADJ', 101), ('DET', 88), ('NOUN', 59), ('NSUFF', 25), ('VERB', 16), ('X', 15), ('VSUFF', 2), ('CCONJ', 1), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('PUNCT', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ’च्या
# [('CCONJ', 39), ('ADP', 16), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# र्जी
# [('PROPN', 15), ('SCONJ', 4), ('PRON', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# पन्न
# [('SCONJ', 16), ('PART', 7), ('VERB', 6), ('NOUN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ळकर
# [('X', 19), ('NOUN', 9), ('AUX', 7), ('PRON', 5), ('PROPN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# प्रादुर्भाव
# [('ADV', 11), ('ADJ', 1), ('PART', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# वस्त्र
# [('NOUN', 20), ('X', 9), ('ADV', 1), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# निघ
# [('VERB', 157), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# राण
# [('X', 17), ('SCONJ', 9), ('PRON', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# संघां
# [('PRON', 20), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# डॉलर्स
# [('NUM', 20), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बंधू
# [('PRON', 14), ('CCONJ', 12), ('PROPN', 7), ('X', 5), ('ADV', 3), ('AJSUFF', 1), ('ADP', 1), ('ADJ', 0), ('NSUFF', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0)]
#
#
#
#
# कार्यक्षम
# [('VERB', 21), ('ADJ', 10), ('X', 6), ('AJSUFF', 5), ('PART', 1), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# घटक
# [('PART', 116), ('NOUN', 70), ('AJSUFF', 23), ('VERB', 6), ('PUNCT', 5), ('PRON', 5), ('X', 3), ('ADJ', 1), ('AUX', 1), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# रांग
# [('NOUN', 35), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सायन्स
# [('CCONJ', 11), ('X', 2), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# शियम
# [('PROPN', 11), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बुक
# [('X', 24), ('NOUN', 11), ('PROPN', 5), ('PART', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मोठय़ा
# [('DET', 90), ('PRON', 3), ('ADV', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# रिझर्व्ह
# [('DET', 19), ('CCONJ', 5), ('AJSUFF', 4), ('PREF', 3), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# एमए
# [('PROPN', 14), ('DET', 4), ('ADP', 4), ('NUM', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# जवळ
# [('PRON', 275), ('ADP', 211), ('ADV', 54), ('SCONJ', 23), ('VERB', 17), ('PART', 12), ('NOUN', 10), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0)]
#
#
#
#
# ठाकरे
# [('PROPN', 434), ('X', 2), ('PRON', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# रोम
# [('PROPN', 19), ('X', 19), ('NOUN', 5), ('SCONJ', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# भा
# [('PROPN', 36), ('PRON', 15), ('PREF', 11), ('X', 8), ('NSUFF', 4), ('NUM', 3), ('VERB', 3), ('PART', 3), ('SCONJ', 2), ('ADV', 1), ('VSUFF', 1), ('ADJ', 0), ('AJSUFF', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('ADP', 0)]
#
#
#
#
# पिता
# [('CCONJ', 11), ('PROPN', 4), ('ADJ', 2), ('ADV', 1), ('SCONJ', 1), ('PREF', 1), ('NSUFF', 0), ('AJSUFF', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# रुग्ण
# [('NOUN', 108), ('PRON', 99), ('NUM', 17), ('ADV', 3), ('ADJ', 2), ('DET', 2), ('PUNCT', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# राणे
# [('PROPN', 109), ('PRON', 14), ('CCONJ', 2), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# माणसं
# [('DET', 15), ('PART', 5), ('X', 2), ('PUNCT', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# द्वितीय
# [('PROPN', 18), ('SCONJ', 17), ('DET', 9), ('VERB', 8), ('PREF', 4), ('CCONJ', 1), ('NOUN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पूर्त
# [('VERB', 25), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# व्हर
# [('X', 46), ('NOUN', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बचत
# [('ADV', 20), ('PART', 8), ('AJSUFF', 6), ('SCONJ', 6), ('VERB', 5), ('PROPN', 1), ('VSUFF', 1), ('ADJ', 0), ('NSUFF', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# संपल्या
# [('PRON', 12), ('NOUN', 4), ('DET', 1), ('ADP', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0)]
#
#
#
#
# ंविरोधात
# [('PART', 19), ('ADP', 7), ('VERB', 2), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# प्रथा
# [('PART', 11), ('VERB', 5), ('ADV', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# नावे
# [('ADV', 38), ('VERB', 27), ('PART', 25), ('PRON', 3), ('NOUN', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# विरार
# [('PROPN', 19), ('DET', 6), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# करताना
# [('PART', 260), ('NSUFF', 59), ('VERB', 8), ('VSUFF', 8), ('CCONJ', 7), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# घेतल्या
# [('VERB', 85), ('PRON', 76), ('NUM', 6), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# कमांड
# [('PROPN', 16), ('X', 5), ('ADJ', 1), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ऑस्ट्र
# [('NOUN', 22), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# उत्पन्न
# [('ADJ', 81), ('NOUN', 28), ('NUM', 12), ('VERB', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तर
# [('DET', 2718), ('X', 246), ('NUM', 103), ('ADJ', 31), ('PROPN', 31), ('PART', 26), ('VERB', 12), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ३
# [('NUM', 359), ('PROPN', 15), ('ADJ', 6), ('DET', 6), ('PUNCT', 4), ('AUX', 2), ('NSUFF', 1), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# चमक
# [('NOUN', 28), ('VERB', 10), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आठवडा
# [('PART', 21), ('AJSUFF', 6), ('ADV', 4), ('NUM', 3), ('VSUFF', 2), ('PRON', 2), ('DET', 1), ('VERB', 1), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# साडे
# [('NUM', 57), ('PROPN', 1), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# 9
# [('NUM', 297), ('X', 2), ('AUX', 1), ('NOUN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# फोटो
# [('ADJ', 203), ('PRON', 51), ('PROPN', 10), ('NOUN', 9), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# दिनांक
# [('NUM', 11), ('NSUFF', 5), ('NOUN', 2), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ग्रस्त
# [('AJSUFF', 84), ('VERB', 17), ('NSUFF', 10), ('PART', 8), ('SCONJ', 6), ('X', 2), ('ADJ', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# हार्बर
# [('DET', 23), ('PROPN', 7), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# 44
# [('NUM', 28), ('DET', 4), ('NSUFF', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# घुस
# [('VERB', 45), ('ADV', 1), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# क्रिये
# [('PRON', 17), ('VERB', 5), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# आवाजा
# [('NOUN', 46), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# दांड
# [('NOUN', 18), ('PREF', 5), ('CCONJ', 3), ('PROPN', 1), ('X', 1), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# wi
# [('PROPN', 11), ('NSUFF', 1), ('ADJ', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तुमच्या
# [('ADJ', 147), ('NOUN', 39), ('CCONJ', 7), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# जवान
# [('NOUN', 61), ('PRON', 27), ('NUM', 10), ('AJSUFF', 2), ('PROPN', 2), ('PUNCT', 1), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0)]
#
#
#
#
# ापेक्षा
# [('NSUFF', 32), ('AJSUFF', 2), ('ADJ', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कोरिया
# [('PRON', 26), ('PROPN', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# जां
# [('X', 11), ('PREF', 2), ('PROPN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मांड
# [('NOUN', 317), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मिळवणार
# [('NOUN', 13), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# फिर
# [('VERB', 107), ('X', 14), ('PRON', 3), ('PROPN', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# गेल
# [('VERB', 320), ('ADJ', 21), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बघ
# [('VERB', 209), ('NOUN', 71), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# महान
# [('ADJ', 30), ('PART', 20), ('PREF', 15), ('PUNCT', 1), ('VERB', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आद
# [('ADP', 19), ('PRON', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0)]
#
#
#
#
# करतो
# [('VERB', 148), ('AUX', 23), ('X', 13), ('NSUFF', 4), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# रजनीकांत
# [('PRON', 14), ('PROPN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# वर
# [('ADP', 4241), ('ADJ', 394), ('X', 104), ('PROPN', 27), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# पंचनाम
# [('NOUN', 32), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# /
# [('PROPN', 361), ('PUNCT', 118), ('ADP', 47), ('ADJ', 5), ('X', 5), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# खांद्यावर
# [('PART', 17), ('VERB', 5), ('ADV', 4), ('DET', 2), ('PRON', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# टप्प्या
# [('PRON', 106), ('VERB', 17), ('NOUN', 7), ('ADV', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# वास्तव
# [('NOUN', 72), ('X', 9), ('VERB', 9), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सन
# [('PROPN', 41), ('NUM', 39), ('X', 20), ('NOUN', 2), ('PART', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ेंद्र
# [('AJSUFF', 403), ('CCONJ', 95), ('PROPN', 21), ('NOUN', 2), ('NSUFF', 1), ('ADJ', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ीचं
# [('AJSUFF', 12), ('X', 3), ('CCONJ', 2), ('SCONJ', 1), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# गल
# [('X', 35), ('PRON', 4), ('CCONJ', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# खंडपीठ
# [('PRON', 18), ('NOUN', 16), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# सगळ्या
# [('PRON', 136), ('ADJ', 91), ('NOUN', 6), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# गि
# [('X', 18), ('NSUFF', 2), ('PROPN', 1), ('ADJ', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# _
# [('PART', 25), ('CCONJ', 1), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# संपादन
# [('SCONJ', 13), ('NSUFF', 11), ('NOUN', 5), ('X', 2), ('VERB', 2), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# नकळत
# [('DET', 12), ('X', 3), ('ADJ', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पट्ट्या
# [('PRON', 11), ('NSUFF', 3), ('NOUN', 3), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# भवन
# [('NOUN', 18), ('PROPN', 12), ('PRON', 10), ('NSUFF', 5), ('ADJ', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# गुंतागुंत
# [('PRON', 11), ('SCONJ', 5), ('X', 2), ('VERB', 2), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# धाकट
# [('NOUN', 15), ('AUX', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सुप्र
# [('NOUN', 39), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# फिट
# [('VERB', 13), ('PROPN', 4), ('PUNCT', 3), ('NSUFF', 2), ('ADV', 1), ('ADJ', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# लाभार्थ
# [('NOUN', 33), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# वाढविण्
# [('PART', 29), ('CCONJ', 3), ('NSUFF', 1), ('ADV', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# संयम
# [('NOUN', 11), ('PRON', 6), ('ADV', 4), ('SCONJ', 2), ('X', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# तितकी
# [('PART', 11), ('VSUFF', 5), ('DET', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# चॅनेल
# [('PRON', 19), ('X', 9), ('ADJ', 4), ('NSUFF', 1), ('ADV', 1), ('VERB', 1), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# अरविंद
# [('PREF', 40), ('PROPN', 6), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आख
# [('VERB', 57), ('NOUN', 5), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# हस्त
# [('NOUN', 121), ('X', 4), ('PROPN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# राहुल
# [('PROPN', 158), ('NSUFF', 39), ('DET', 10), ('PRON', 9), ('X', 4), ('ADV', 3), ('NUM', 2), ('ADJ', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# लो
# [('VSUFF', 179), ('X', 56), ('PROPN', 31), ('ADV', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पर्वत
# [('NOUN', 15), ('X', 8), ('PREF', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ho
# [('CCONJ', 11), ('PROPN', 2), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# hes
# [('PROPN', 14), ('PART', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मंत्र्यांनी
# [('PART', 25), ('DET', 11), ('ADJ', 4), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तु
# [('PRON', 71), ('VERB', 10), ('PROPN', 9), ('VSUFF', 3), ('DET', 2), ('X', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# ३९
# [('NUM', 19), ('DET', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# अना
# [('DET', 15), ('PART', 10), ('PRON', 6), ('PREF', 3), ('NOUN', 2), ('X', 2), ('CCONJ', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0)]
#
#
#
#
# फक्त
# [('DET', 529), ('ADJ', 112), ('X', 7), ('ADP', 2), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# िय
# [('NSUFF', 14), ('X', 3), ('VSUFF', 3), ('CCONJ', 1), ('VERB', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# 13
# [('NUM', 125), ('CCONJ', 9), ('ADJ', 2), ('NSUFF', 1), ('AJSUFF', 1), ('DET', 1), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# मंत्रालय
# [('PRON', 56), ('NOUN', 55), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# प्राथमिक
# [('DET', 79), ('AJSUFF', 32), ('ADV', 17), ('ADJ', 7), ('NUM', 3), ('PART', 3), ('CCONJ', 2), ('VERB', 2), ('NSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तेव्हा
# [('PUNCT', 334), ('DET', 175), ('PRON', 48), ('PART', 4), ('NOUN', 3), ('X', 2), ('NSUFF', 1), ('CCONJ', 1), ('PREF', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('VERB', 0), ('VSUFF', 0), ('ADP', 0)]
#
#
#
#
# २७
# [('NUM', 20), ('DET', 6), ('AUX', 3), ('PREF', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पॅट
# [('PROPN', 11), ('X', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# यामुळे
# [('DET', 297), ('PROPN', 14), ('ADJ', 10), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कार्यक्रम
# [('NOUN', 410), ('ADJ', 22), ('ADV', 6), ('AUX', 5), ('PRON', 4), ('X', 3), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# वणी
# [('X', 14), ('NSUFF', 6), ('VERB', 4), ('SCONJ', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आरोप
# [('ADV', 142), ('PART', 112), ('SCONJ', 10), ('VERB', 9), ('ADJ', 4), ('PUNCT', 4), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# रहिवाश
# [('PRON', 18), ('NOUN', 15), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# ण्याकरिता
# [('VSUFF', 25), ('DET', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ओढ
# [('VERB', 51), ('NOUN', 43), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# भूषव
# [('VERB', 11), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तलवार
# [('PART', 12), ('VERB', 2), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# गव्ह
# [('NOUN', 11), ('PREF', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कौशल्य
# [('NOUN', 36), ('PART', 15), ('X', 11), ('NSUFF', 3), ('AUX', 1), ('VERB', 1), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पाच
# [('ADJ', 224), ('NUM', 190), ('DET', 61), ('PROPN', 9), ('ADP', 2), ('PART', 1), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# कोयना
# [('DET', 13), ('PROPN', 2), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# चहा
# [('ADJ', 19), ('PRON', 18), ('PART', 16), ('X', 14), ('NOUN', 3), ('ADV', 2), ('AJSUFF', 1), ('NUM', 1), ('NSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# प्रशिक्षणा
# [('PRON', 11), ('ADV', 1), ('VERB', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# ांचे
# [('ADP', 694), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# कडील
# [('ADP', 28), ('DET', 10), ('X', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# मतभेद
# [('PART', 12), ('ADV', 6), ('VERB', 4), ('PRON', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# बेडरूम
# [('PRON', 11), ('NUM', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# हद्द
# [('NOUN', 42), ('PART', 4), ('ADV', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# झाड
# [('NOUN', 107), ('VERB', 22), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# तिमाही
# [('PRON', 18), ('NOUN', 12), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# वते
# [('AUX', 14), ('PUNCT', 2), ('VERB', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# वेकर
# [('PROPN', 15), ('NOUN', 2), ('AUX', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# व्याख्या
# [('PART', 12), ('ADV', 5), ('X', 3), ('VERB', 3), ('AJSUFF', 2), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पदार्थ
# [('PART', 133), ('NOUN', 58), ('X', 10), ('VERB', 6), ('PROPN', 5), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# असायच
# ...
#
#
#
#
# ्याकडे
# [('NSUFF', 13), ('SCONJ', 2), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# इन
# [('X', 73), ('PROPN', 49), ('NSUFF', 4), ('CCONJ', 3), ('PREF', 3), ('NOUN', 1), ('ADJ', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बंदर
# [('NOUN', 28), ('PROPN', 6), ('NSUFF', 1), ('PUNCT', 1), ('ADJ', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# वाग
# [('VERB', 41), ('X', 22), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# बिल
# [('NOUN', 46), ('X', 12), ('PROPN', 10), ('CCONJ', 9), ('SCONJ', 8), ('ADV', 3), ('NUM', 2), ('PART', 2), ('NSUFF', 1), ('ADJ', 0), ('AJSUFF', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आयसीसी
# [('PRON', 28), ('NUM', 11), ('ADV', 5), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# खासदार
# [('ADJ', 185), ('NOUN', 55), ('ADV', 16), ('NUM', 3), ('ADP', 3), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# पंत
# [('CCONJ', 16), ('PROPN', 14), ('PRON', 8), ('ADJ', 2), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# घो
# [('VERB', 12), ('NOUN', 3), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# प्रसिद्ध
# [('ADJ', 55), ('PART', 43), ('ADV', 42), ('PROPN', 31), ('SCONJ', 23), ('VERB', 22), ('VSUFF', 11), ('NSUFF', 0), ('AJSUFF', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# समावेश
# [('VERB', 182), ('ADJ', 100), ('X', 13), ('SCONJ', 3), ('PROPN', 1), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# प्रवाह
# [('NOUN', 75), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# दृष्टय़ा
# [('AJSUFF', 13), ('PART', 2), ('ADJ', 0), ('NSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# हस
# [('NOUN', 24), ('X', 21), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# विमा
# [('DET', 26), ('ADV', 12), ('AJSUFF', 9), ('SCONJ', 6), ('NSUFF', 3), ('PREF', 2), ('VERB', 1), ('ADJ', 0), ('PROPN', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# वंश
# [('NOUN', 39), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# दास
# [('PROPN', 66), ('SCONJ', 2), ('NOUN', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# १८
# [('NUM', 127), ('CCONJ', 2), ('DET', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पैसा
# [('PART', 58), ('X', 11), ('ADP', 9), ('ADJ', 8), ('VSUFF', 4), ('AUX', 2), ('VERB', 2), ('SCONJ', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# 42
# [('NUM', 26), ('DET', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# छोटी
# [('X', 18), ('ADJ', 12), ('VERB', 2), ('SCONJ', 1), ('DET', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सादरीकरण
# [('NOUN', 15), ('ADV', 8), ('ADJ', 1), ('SCONJ', 1), ('X', 1), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पोल
# [('PROPN', 24), ('X', 9), ('PART', 5), ('PRON', 3), ('NOUN', 2), ('AUX', 1), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# पुढ
# [('ADJ', 119), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कॉम्
# [('PREF', 15), ('CCONJ', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# विद्यार्थ्
# [('PRON', 286), ('NOUN', 42), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# सोल
# [('X', 32), ('NOUN', 6), ('VERB', 2), ('PROPN', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# फळे
# [('PROPN', 21), ('PART', 21), ('X', 8), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# दृष्ट्या
# [('AJSUFF', 23), ('PART', 16), ('NSUFF', 2), ('SCONJ', 2), ('ADJ', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# पाठोपाठ
# [('ADP', 17), ('PART', 7), ('PREF', 7), ('CCONJ', 1), ('NUM', 1), ('DET', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PRON', 0)]
#
#
#
#
# ्यु
# [('PROPN', 11), ('X', 11), ('VERB', 10), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# ही
# [('PART', 3931), ('DET', 2704), ('ADP', 508), ('X', 167), ('ADV', 153), ('VERB', 72), ('PREF', 44), ('NSUFF', 32), ('ADJ', 28), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VSUFF', 0), ('PRON', 0)]
#
#
#
#
# रिका
# [('ADJ', 16), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# d
# [('PROPN', 26), ('CCONJ', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# im
# [('PROPN', 11), ('PREF', 3), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# अनुषंग
# [('NOUN', 27), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# भाड
# [('NOUN', 26), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# “
# [('DET', 218), ('PROPN', 47), ('X', 30), ('PUNCT', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# हेड
# [('X', 29), ('PROPN', 5), ('PUNCT', 1), ('PRON', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# इत्यादी
# [('X', 26), ('PART', 14), ('CCONJ', 6), ('PRON', 6), ('NSUFF', 4), ('DET', 2), ('ADJ', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# वाज
# [('NOUN', 64), ('VERB', 51), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# सण
# [('PART', 35), ('X', 3), ('VERB', 3), ('PROPN', 1), ('PUNCT', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('VSUFF', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# z
# [('PROPN', 22), ('X', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# 24
# [('NUM', 75), ('DET', 7), ('PREF', 4), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# धोंड
# [('NOUN', 14), ('PROPN', 3), ('X', 2), ('PREF', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# गटार
# [('NOUN', 13), ('PRON', 5), ('ADV', 2), ('X', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0)]
#
#
#
#
# सचिन
# [('PREF', 57), ('PRON', 33), ('CCONJ', 20), ('PROPN', 11), ('ADV', 8), ('DET', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0)]
#
#
#
#
# णे
# [('VSUFF', 1379), ('X', 96), ('NUM', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# कांद
# [('NOUN', 114), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# आंतरराष्ट्री
# [('PROPN', 83), ('ADV', 59), ('X', 14), ('NUM', 5), ('ADP', 2), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# सासर
# [('ADJ', 30), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# दायी
# [('AJSUFF', 25), ('SCONJ', 14), ('VERB', 14), ('NSUFF', 1), ('ADJ', 0), ('PROPN', 0), ('ADV', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]
#
#
#
#
# जलतरण
# [('PART', 14), ('PREF', 3), ('VSUFF', 1), ('PRON', 1), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('NOUN', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('ADP', 0)]
#
#
#
#
# दुर्ग
# [('PREF', 23), ('NOUN', 16), ('ADJ', 7), ('PROPN', 5), ('PRON', 3), ('NSUFF', 0), ('AJSUFF', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('ADP', 0)]
#
#
#
#
# विजय
# [('NOUN', 309), ('PROPN', 92), ('ADV', 83), ('X', 21), ('ADJ', 1), ('ADP', 1), ('NSUFF', 0), ('AJSUFF', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('PRON', 0)]
#
#
#
#
# मोर्च
# [('NOUN', 11), ('ADJ', 0), ('NSUFF', 0), ('AJSUFF', 0), ('PROPN', 0), ('ADV', 0), ('SCONJ', 0), ('CCONJ', 0), ('NUM', 0), ('AUX', 0), ('SYM', 0), ('INTJ', 0), ('DET', 0), ('X', 0), ('PUNCT', 0), ('VERB', 0), ('VSUFF', 0), ('PART', 0), ('PREF', 0), ('ADP', 0), ('PRON', 0)]

# %%
count
# Out:
# 3013

# %%
count
# Out:
# 4032

# %%
count
# Out:
# 6248
